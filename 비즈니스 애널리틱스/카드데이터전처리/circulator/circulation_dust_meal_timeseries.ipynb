# %%
import pandas as pd
df = pd.read_csv('circulation_dust.csv', encoding='utf8')

# %%
soso_circulation = df.loc[df.dust=='안나쁨']

# %%
bad_circulation = df.loc[df.dust=='나쁨']

# %%
soso_circulation.to_csv("soso_circulation.csv", mode='w')

# %%
bad_circulation.to_csv("bad_circulation.csv", mode='w')

# %%
del df['Unnamed: 0']

# %%
del df['gu']

# %%
del df['dong']

# %%
df
# Out:
#            date   sales   meal  snack  drink home_living health_beauty hobby  \
# 0      20180401   73.7%  27.9%  30.0%  33.5%        1.6%          5.4%  0.0%
# 1      20180401  125.8%  23.7%  25.8%  35.0%        4.6%          9.3%  0.5%
# 2      20180401   67.4%  25.4%  24.7%  32.4%        6.5%          9.0%   NaN
# 3      20180401  101.1%  41.6%  21.8%  28.3%        2.7%          3.7%  0.6%
# 4      20180401  101.3%  31.1%  26.7%  26.2%        1.5%         13.5%   NaN
# 5      20180401  194.4%  34.2%  20.7%  36.0%        2.2%          4.9%  1.2%
# 6      20180401   88.0%  33.6%  26.1%  24.7%        7.7%          4.6%  1.0%
# 7      20180401   74.1%  23.8%  21.0%  41.3%        1.7%          9.0%  1.0%
# 8      20180401  125.5%  27.5%  21.0%  38.7%        2.4%          7.6%  0.6%
# 9      20180401   75.7%  25.3%  22.1%  39.8%        2.2%          4.6%  1.0%
# 10     20180401  118.2%  22.3%  21.8%  37.5%        4.6%         11.0%  0.4%
# ...

# %%
soso_circulation = df.loc[df.dust=='안나쁨']

# %%
bad_circulation = df.loc[df.dust=='나쁨']

# %%
soso_circulation.shape
# Out:
# (6901, 11)

# %%
bad_circulation.shape
# Out:
# (6224, 11)

# %%
del bad_circulation['dust']

# %%
del soso_circulation['dust']

# %%
bad_circulation.to_csv("bad_circulation.csv", mode='w')

# %%
soso_circulation.to_csv("soso_circulation.csv", mode='w')

# %%
bad_date = bad_circulation.date

# %%
meal = bad_circulation.meal

# %%
bad_meal = meal

# %%
soso_meal = soso_circulation.meal
soso_date = soso_circulation.date

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
bad_meal = pd.DataFrame(bad_meal)

# %%
soso_meal = pd.DataFrame(soso_meal)

# %%
bad_date = pd.DataFrame(bad_date)

# %%
soso_meal = pd.DataFrame(soso_meal)

# %%
bad_meal.shape
# Out:
# (6224, 1)

# %%
bad_date.shape
# Out:
# (6224, 1)

# %%
bad = pd.concat([bad_meal, bad_date], axis = 1)

# %%
bad_date = bad_date.as_matrix()
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   """Entry point for launching an IPython kernel.

# %%
bad_meal = bad_meal.as_matrix()
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   """Entry point for launching an IPython kernel.

# %%
bad_date.tolist()
bad_meal.tolist()
# Out:
# [['27.9%'],
#  ['23.7%'],
#  ['25.4%'],
#  ['41.6%'],
#  ['31.1%'],
#  ['34.2%'],
#  ['33.6%'],
#  ['23.8%'],
#  ['27.5%'],
#  ['25.3%'],
#  ['22.3%'],
#  ['31.7%'],
#  ['33.6%'],
#  ['42.5%'],
#  ['15.0%'],
#  ['35.2%'],
#  ['27.5%'],
#  ['33.2%'],
#  ['34.0%'],
#  ['24.9%'],
#  ['31.9%'],
#  ['31.7%'],
#  ['29.8%'],
#  ['31.5%'],
#  ['29.7%'],
#  ['26.3%'],
#  ['20.8%'],
#  ['32.5%'],
#  ['26.7%'],
#  ['29.5%'],
#  ['34.9%'],
#  ['31.6%'],
#  ['28.0%'],
#  ['33.9%'],
#  ['27.7%'],
#  ['31.3%'],
#  ['27.0%'],
#  ['25.3%'],
#  ['19.5%'],
#  ['41.0%'],
#  ['31.8%'],
#  ['27.5%'],
#  ['34.8%'],
#  ['24.8%'],
#  ['27.3%'],
#  ['24.6%'],
#  ['27.6%'],
#  ['32.7%'],
#  ['38.8%'],
#  ['46.0%'],
#  ['26.5%'],
#  ['38.0%'],
#  ['29.0%'],
#  ['34.1%'],
#  ['34.6%'],
#  ['26.7%'],
#  ['32.6%'],
#  ['29.8%'],
#  ['29.0%'],
#  ['30.2%'],
#  ['28.5%'],
#  ['30.1%'],
#  ['29.6%'],
#  ['32.6%'],
#  ['28.5%'],
#  ['33.5%'],
#  ['49.2%'],
#  ['37.4%'],
#  ['25.5%'],
#  ['28.1%'],
#  ['34.5%'],
# ...

# %%
bad_meal_result = []
for i in bad_meal:
    for j in i:
        bad_meal_result.append(j)

# %%
bad_meal_result
# Out:
# ['27.9%',
#  '23.7%',
#  '25.4%',
#  '41.6%',
#  '31.1%',
#  '34.2%',
#  '33.6%',
#  '23.8%',
#  '27.5%',
#  '25.3%',
#  '22.3%',
#  '31.7%',
#  '33.6%',
#  '42.5%',
#  '15.0%',
#  '35.2%',
#  '27.5%',
#  '33.2%',
#  '34.0%',
#  '24.9%',
#  '31.9%',
#  '31.7%',
#  '29.8%',
#  '31.5%',
#  '29.7%',
#  '26.3%',
#  '20.8%',
#  '32.5%',
#  '26.7%',
#  '29.5%',
#  '34.9%',
#  '31.6%',
#  '28.0%',
#  '33.9%',
#  '27.7%',
#  '31.3%',
#  '27.0%',
#  '25.3%',
#  '19.5%',
#  '41.0%',
#  '31.8%',
#  '27.5%',
#  '34.8%',
#  '24.8%',
#  '27.3%',
#  '24.6%',
#  '27.6%',
#  '32.7%',
#  '38.8%',
#  '46.0%',
#  '26.5%',
#  '38.0%',
#  '29.0%',
#  '34.1%',
#  '34.6%',
#  '26.7%',
#  '32.6%',
#  '29.8%',
#  '29.0%',
#  '30.2%',
#  '28.5%',
#  '30.1%',
#  '29.6%',
#  '32.6%',
#  '28.5%',
#  '33.5%',
#  '49.2%',
#  '37.4%',
#  '25.5%',
#  '28.1%',
#  '34.5%',
#  '28.6%',
#  '31.8%',
#  '26.6%',
#  '18.7%',
#  '42.2%',
#  '31.3%',
#  '32.3%',
#  '31.8%',
#  '26.1%',
#  '27.6%',
#  '28.1%',
#  '28.7%',
# ...

# %%
bad_date_result = []
for i in bad_date:
    for j in i:
        bad_date_result.append(j)

# %%
bad_date_result
# Out:
# [20180401,
#  20180401,
#  20180401,
#  20180401,
#  20180401,
#  20180401,
#  20180401,
#  20180401,
#  20180401,
#  20180401,
#  20180401,
#  20180401,
#  20180401,
#  20180401,
#  20180401,
#  20180401,
#  20180401,
#  20180401,
#  20180401,
#  20180401,
#  20180401,
#  20180401,
#  20180401,
#  20180401,
#  20180401,
#  20180401,
#  20180401,
#  20180401,
#  20180401,
#  20180401,
#  20180401,
#  20180401,
#  20180401,
#  20180401,
#  20180401,
#  20180401,
#  20180402,
#  20180402,
#  20180402,
#  20180402,
#  20180402,
#  20180402,
#  20180402,
#  20180402,
#  20180402,
#  20180402,
#  20180402,
#  20180402,
#  20180402,
#  20180402,
#  20180402,
#  20180402,
#  20180402,
#  20180402,
#  20180402,
#  20180402,
#  20180402,
#  20180402,
#  20180402,
#  20180402,
#  20180402,
#  20180402,
#  20180402,
#  20180402,
#  20180402,
#  20180402,
#  20180402,
#  20180402,
#  20180402,
#  20180402,
#  20180402,
#  20180402,
#  20180403,
#  20180403,
#  20180403,
#  20180403,
# ...

# %%
bad_201804 = bad_circulation['201804' in bad_circulation.date]
# Out:
# pandas.core.series.Series

# %%
bad_201804 = bad_circulation[bad_circulation['date']<20180500]

# %%
bad_column = bad_circulation.columns

# %%
soso_column = soso_circulation.columns

# %%
bad_circulation = bad_circulation.reset_index()

# %%
soso_circulation = soso_circulation.reset_index()

# %%
ha = {}
for i in bad_column:
    result = []
    test = bad_circulation[i]
    for j in range(0, test.size):
        text = str(test[j])
        text= text.replace("%","")
        if j % 100 == 0:
        result.append(text)
    ha[i] = result
# Out:
#   File "<ipython-input-44-880c0abd19a1>", line 9
#     result.append(text)
#          ^
# IndentationError: expected an indented block

# %%
ha_soso = {}
for i in soso_column:
    result = []
    test = soso_circulation[i]
    for j in range(0, test.size):
        text = str(test[j])
        text= text.replace("%","")
        if j % 100 == 0:
        result.append(text)
    ha_soso[i] = result
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# ...

# %%
date = ha['date']
sales = ha['sales']
meal = ha['meal']
snack = ha['snack']
drink = ha['drink']
home_living = ha['home_living']
health_beauty = ha['health_beauty']
hobby = ha['hobby']
social = ha['social']
infant = ha['infant']

# %%
date_soso = ha_soso['date']
sales_soso = ha_soso['sales']
meal_soso = ha_soso['meal']
snack_soso = ha_soso['snack']
drink_soso = ha_soso['drink']
home_living_soso = ha_soso['home_living']
health_beauty_soso = ha_soso['health_beauty']
hobby_soso = ha_soso['hobby']
social_soso = ha_soso['social']
infant_soso = ha_soso['infant']

# %%
test_ha = {}
result = []
for i in range(0, len(date)):
    result = []
    for j in range(i, len(date)):
        if i == j:
            if date[i] == date[j]:
                if(date[i] in test_ha):
                    if type(test_ha[date[i]]) != list:
                        result.append(test_ha[date[i]])
                    else:
                        result = test_ha[date[i]]
                    result.append(meal[i])
                    test_ha[date[i]] = result
                    pass
                else:
                    test_ha[date[i]] = meal[i]
            else:
                i = j
                break
        else:
            i = j
            break

# %%
meal_date = test_ha

# %%
date_key = list(meal_date.keys())

# %%
meal_aver = {}
meal_result_bad = []
meal_date_bad = []
for i in date_key:
    aver = 0
    for j in meal_date[i]:
        aver = aver + float(j)
    aver = aver / len(meal_date[i])
    meal_result_bad.append(aver)
    meal_date_bad.append(i)
    meal_aver[i] = aver

# %%
meal_aver
# Out:
# {'20180401': 29.772222222222222,
#  '20180402': 31.25833333333334,
#  '20180403': 32.15833333333334,
#  '20180406': 33.694444444444436,
#  '20180407': 31.058333333333344,
#  '20180410': 32.06944444444444,
#  '20180411': 32.59722222222222,
#  '20180412': 32.57222222222221,
#  '20180415': 31.20555555555556,
#  '20180416': 32.56944444444444,
#  '20180417': 32.758333333333326,
#  '20180418': 32.76111111111111,
#  '20180419': 32.56944444444446,
#  '20180420': 29.46388888888889,
#  '20180421': 26.366666666666667,
#  '20180426': 32.05277777777777,
#  '20180427': 30.505555555555564,
#  '20180428': 27.91388888888888,
#  '20180429': 29.372222222222224,
#  '20180430': 30.71944444444445,
#  '20180501': 29.624999999999993,
#  '20180504': 30.59444444444444,
#  '20180505': 25.755555555555556,
#  '20180510': 32.2111111111111,
#  '20180511': 31.400000000000002,
#  '20180514': 31.94444444444444,
#  '20180515': 28.922222222222224,
#  '20180523': 32.03611111111112,
#  '20180524': 31.46944444444444,
# ...

# %%
plt.plot(meal_date_bad, meal_result)
plt.rcParams["figure.figsize"] = [25,9]
plt.xticks(rotation=90)
plt.show()

# %%
test_ha = {}
result = []
for i in range(0, len(date_soso)):
    result = []
    for j in range(i, len(date_soso)):
        if i == j:
            if date_soso[i] == date_soso[j]:
                if(date_soso[i] in test_ha):
                    if type(test_ha[date_soso[i]]) != list:
                        result.append(test_ha[date_soso[i]])
                    else:
                        result = test_ha[date_soso[i]]
                    result.append(meal_soso[i])
                    test_ha[date_soso[i]] = result
                    pass
                else:
                    test_ha[date_soso[i]] = meal_soso[i]
            else:
                i = j
                break
        else:
            i = j
            break

# %%
meal_date_soso = test_ha

# %%
date_key_soso = list(meal_date_soso.keys())

# %%
meal_aver_soso = {}
meal_result_soso = []
meal_date_soso_2 = []
for i in date_key_soso:
    aver = 0
    for j in meal_date_soso[i]:
        aver = aver + float(j)
    aver = aver / len(meal_date_soso[i])
    meal_result_soso.append(aver)
    meal_date_soso_2.append(i)
    meal_aver_soso[i] = aver

# %%
meal_result_soso
# Out:
# [32.98055555555556,
#  35.37500000000001,
#  30.658333333333342,
#  34.28055555555556,
#  31.938888888888886,
#  31.91666666666667,
#  30.494444444444444,
#  36.761111111111106,
#  34.25277777777777,
#  30.991666666666656,
#  34.74166666666667,
#  33.31666666666667,
#  28.069444444444443,
#  27.236111111111107,
#  30.786111111111115,
#  31.072222222222226,
#  31.35833333333333,
#  29.0,
#  34.291666666666664,
#  34.38333333333334,
#  32.49722222222222,
#  27.219444444444445,
#  29.91944444444444,
#  30.825000000000006,
#  28.477777777777778,
#  31.605555555555547,
#  31.01944444444444,
#  26.14444444444444,
#  28.266666666666666,
#  32.0611111111111,
#  30.752777777777776,
#  27.166666666666668,
#  30.66944444444444,
#  34.15277777777778,
#  31.91944444444444,
#  30.02777777777778,
#  33.50555555555556,
#  31.047222222222235,
#  29.150000000000002,
#  31.036111111111104,
#  32.61388888888888,
#  32.37500000000001,
#  31.494444444444444,
#  30.588888888888885,
#  29.188888888888886,
# ...

# %%
plt.plot(meal_date_soso_2, meal_result_soso)
plt.rcParams["figure.figsize"] = [25,9]
plt.xticks(rotation=90)
plt.show()

# %%
meal_date_soso_temp = meal_date_soso_2
meal_result_soso_temp = meal_result_soso

# %%
meal_date_soso_temp = pd.DataFrame(meal_date_soso_temp)

# %%
meal_result_soso_temp = pd.DataFrame(meal_result_soso_temp)

# %%
soso_meal = pd.concat([meal_date_soso_temp, meal_result_soso_temp], axis=1)

# %%
soso_meal.columns = ['date', 'aver_soso']

# %%
meal_result_bad_temp = meal_result_bad
meal_date_bad_temp = meal_date_bad

# %%
meal_date_bad_temp = pd.DataFrame(meal_date_bad_temp)
meal_result_bad_temp = pd.DataFrame(meal_result_bad_temp)
bad_meal = pd.concat([meal_date_bad_temp, meal_result_bad_temp], axis=1)
bad_meal.columns = ['date', 'aver_bad']

# %%
bad_meal.head(5)
# Out:
#        date   aver_bad
# 0  20180401  29.772222
# 1  20180402  31.258333
# 2  20180403  32.158333
# 3  20180406  33.694444
# 4  20180407  31.058333

# %%
meal = pd.merge(soso_meal, bad_meal, how='outer')

# %%
meal = meal.sort_values(by = "date")
meal = meal.reset_index()

# %%
meal.columns
# Out:
# Index(['index', 'date', 'aver_soso', 'aver_bad'], dtype='object')

# %%
del meal['index']

# %%
meal_re = meal.set_index("date")

# %%
meal_re.plot()
plt.ylabel("Data")
plt.show()

# %%
meal_re
# Out:
#           aver_soso   aver_bad
# date
# 20180401        NaN  29.772222
# 20180402        NaN  31.258333
# 20180403        NaN  32.158333
# 20180404  32.980556        NaN
# 20180405  35.375000        NaN
# 20180406        NaN  33.694444
# 20180407        NaN  31.058333
# 20180408  30.658333        NaN
# 20180409  34.280556        NaN
# 20180410        NaN  32.069444
# 20180411        NaN  32.597222
# 20180412        NaN  32.572222
# 20180413  31.938889        NaN
# 20180414  31.916667        NaN
# 20180415        NaN  31.205556
# 20180416        NaN  32.569444
# 20180417        NaN  32.758333
# 20180418        NaN  32.761111
# 20180419        NaN  32.569444
# 20180420        NaN  29.463889
# 20180421        NaN  26.366667
# 20180422  30.494444        NaN
# 20180423  36.761111        NaN
# 20180424  34.252778        NaN
# 20180425  30.991667        NaN
# 20180426        NaN  32.052778
# 20180427        NaN  30.505556
# 20180428        NaN  27.913889
# 20180429        NaN  29.372222
# ...
