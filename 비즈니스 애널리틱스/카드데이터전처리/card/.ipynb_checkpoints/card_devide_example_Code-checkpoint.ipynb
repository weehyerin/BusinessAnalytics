# %%
import pandas as pd
import matplotlib.pyplot as plt

bad_card = pd.read_csv("./data/bad_card.csv")
soso_card = pd.read_csv("./data/soso_card.csv")

# %%
bad_rows = len(bad_card.index)
soso_rows = len(soso_card.index)

# %%
total = bad_rows +  soso_rows

# %%
result = {}
result['total'] = total
result['bad_dust'] = bad_rows
result['soso_dust'] = soso_rows

# %%
bad_card.columns
# Out:
# Index(['Unnamed: 0', 'MCT_CAT_CD', 'SEX_CD', 'AGE_CD', 'USE_CNT', 'USE_AMT'], dtype='object')

# %%
bad_card_F = bad_card[bad_card.SEX_CD == 'F']
bad_card_M = bad_card[bad_card.SEX_CD == 'M']
soso_card_F = soso_card[soso_card.SEX_CD == 'F']
soso_card_M = soso_card[soso_card.SEX_CD == 'M']

# %%
result['bad_Female'] = len(bad_card_F.index)
result['bad_Man'] = len(bad_card_M.index)
result['soso_Female'] = len(soso_card_F.index)
result['soso_Man'] = len(soso_card_M.index)

# %%
# 20, 25, 30, 35, 40, 45, 50, 55, 60, 65
bad_card_F_20 = bad_card_F[bad_card_F.AGE_CD == 20]
bad_card_F_25 = bad_card_F[bad_card_F.AGE_CD == 25]
bad_card_F_30 = bad_card_F[bad_card_F.AGE_CD == 30]
bad_card_F_35 = bad_card_F[bad_card_F.AGE_CD == 35]
bad_card_F_40 = bad_card_F[bad_card_F.AGE_CD == 40]
bad_card_F_45 = bad_card_F[bad_card_F.AGE_CD == 45]
bad_card_F_50 = bad_card_F[bad_card_F.AGE_CD == 50]
bad_card_F_55 = bad_card_F[bad_card_F.AGE_CD == 55]
bad_card_F_60 = bad_card_F[bad_card_F.AGE_CD == 60]
bad_card_F_65 = bad_card_F[bad_card_F.AGE_CD == 65]

# %%
result['bad_Female_20'] = len(bad_card_F_20.index)
result['bad_Female_25'] = len(bad_card_F_25.index)
result['bad_Female_30'] = len(bad_card_F_30.index)
result['bad_Female_35'] = len(bad_card_F_35.index)
result['bad_Female_40'] = len(bad_card_F_40.index)
result['bad_Female_45'] = len(bad_card_F_45.index)
result['bad_Female_50'] = len(bad_card_F_50.index)
result['bad_Female_55'] = len(bad_card_F_55.index)
result['bad_Female_60'] = len(bad_card_F_60.index)
result['bad_Female_65'] = len(bad_card_F_65.index)

# %%
bad_card_M_20 = bad_card_M[bad_card_M.AGE_CD == 20]
bad_card_M_25 = bad_card_M[bad_card_M.AGE_CD == 25]
bad_card_M_30 = bad_card_M[bad_card_M.AGE_CD == 30]
bad_card_M_35 = bad_card_M[bad_card_M.AGE_CD == 35]
bad_card_M_40 = bad_card_M[bad_card_M.AGE_CD == 40]
bad_card_M_45 = bad_card_M[bad_card_M.AGE_CD == 45]
bad_card_M_50 = bad_card_M[bad_card_M.AGE_CD == 50]
bad_card_M_55 = bad_card_M[bad_card_M.AGE_CD == 55]
bad_card_M_60 = bad_card_M[bad_card_M.AGE_CD == 60]
bad_card_M_65 = bad_card_M[bad_card_M.AGE_CD == 65]

result['bad_Man_20'] = len(bad_card_M_20.index)
result['bad_Man_25'] = len(bad_card_M_25.index)
result['bad_Man_30'] = len(bad_card_M_30.index)
result['bad_Man_35'] = len(bad_card_M_35.index)
result['bad_Man_40'] = len(bad_card_M_40.index)
result['bad_Man_45'] = len(bad_card_M_45.index)
result['bad_Man_50'] = len(bad_card_M_50.index)
result['bad_Man_55'] = len(bad_card_M_55.index)
result['bad_Man_60'] = len(bad_card_M_60.index)
result['bad_Man_65'] = len(bad_card_M_65.index)

# %%
soso_card_F_20 = soso_card_F[soso_card_F.AGE_CD == 20]
soso_card_F_25 = soso_card_F[soso_card_F.AGE_CD == 25]
soso_card_F_30 = soso_card_F[soso_card_F.AGE_CD == 30]
soso_card_F_35 = soso_card_F[soso_card_F.AGE_CD == 35]
soso_card_F_40 = soso_card_F[soso_card_F.AGE_CD == 40]
soso_card_F_45 = soso_card_F[soso_card_F.AGE_CD == 45]
soso_card_F_50 = soso_card_F[soso_card_F.AGE_CD == 50]
soso_card_F_55 = soso_card_F[soso_card_F.AGE_CD == 55]
soso_card_F_60 = soso_card_F[soso_card_F.AGE_CD == 60]
soso_card_F_65 = soso_card_F[soso_card_F.AGE_CD == 65]

result['soso_Female_20'] = len(soso_card_F_20.index)
result['soso_Female_25'] = len(soso_card_F_25.index)
result['soso_Female_30'] = len(soso_card_F_30.index)
result['soso_Female_35'] = len(soso_card_F_35.index)
result['soso_Female_40'] = len(soso_card_F_40.index)
result['soso_Female_45'] = len(soso_card_F_45.index)
result['soso_Female_50'] = len(soso_card_F_50.index)
result['soso_Female_55'] = len(soso_card_F_55.index)
result['soso_Female_60'] = len(soso_card_F_60.index)
result['soso_Female_65'] = len(soso_card_F_65.index)

# %%
soso_card_M_20 = soso_card_M[soso_card_M.AGE_CD == 20]
soso_card_M_25 = soso_card_M[soso_card_M.AGE_CD == 25]
soso_card_M_30 = soso_card_M[soso_card_M.AGE_CD == 30]
soso_card_M_35 = soso_card_M[soso_card_M.AGE_CD == 35]
soso_card_M_40 = soso_card_M[soso_card_M.AGE_CD == 40]
soso_card_M_45 = soso_card_M[soso_card_M.AGE_CD == 45]
soso_card_M_50 = soso_card_M[soso_card_M.AGE_CD == 50]
soso_card_M_55 = soso_card_M[soso_card_M.AGE_CD == 55]
soso_card_M_60 = soso_card_M[soso_card_M.AGE_CD == 60]
soso_card_M_65 = soso_card_M[soso_card_M.AGE_CD == 65]

result['soso_Man_20'] = len(soso_card_M_20.index)
result['soso_Man_25'] = len(soso_card_M_25.index)
result['soso_Man_30'] = len(soso_card_M_30.index)
result['soso_Man_35'] = len(soso_card_M_35.index)
result['soso_Man_40'] = len(soso_card_M_40.index)
result['soso_Man_45'] = len(soso_card_M_45.index)
result['soso_Man_50'] = len(soso_card_M_50.index)
result['soso_Man_55'] = len(soso_card_M_55.index)
result['soso_Man_60'] = len(soso_card_M_60.index)
result['soso_Man_65'] = len(soso_card_M_65.index)

# %%
result
# Out:
# {'total': 1998575,
#  'bad_dust': 948118,
#  'soso_dust': 1050457,
#  'bad_Female': 478331,
#  'bad_Man': 469787,
#  'soso_Female': 531031,
#  'soso_Man': 519426,
#  'bad_Female_20': 47954,
#  'bad_Female_25': 48818,
#  'bad_Female_30': 47287,
#  'bad_Female_35': 48527,
#  'bad_Female_40': 50385,
#  'bad_Female_45': 54718,
#  'bad_Female_50': 52372,
#  'bad_Female_55': 47908,
#  'bad_Female_60': 40984,
#  'bad_Female_65': 39378,
#  'bad_Man_20': 45052,
#  'bad_Man_25': 51300,
#  'bad_Man_30': 49051,
#  'bad_Man_35': 49739,
#  'bad_Man_40': 48500,
#  'bad_Man_45': 51193,
#  'bad_Man_50': 49744,
#  'bad_Man_55': 45450,
#  'bad_Man_60': 39503,
#  'bad_Man_65': 40255,
#  'soso_Female_20': 53930,
#  'soso_Female_25': 54307,
#  'soso_Female_30': 52740,
#  'soso_Female_35': 54154,
#  'soso_Female_40': 55950,
#  'soso_Female_45': 60838,
#  'soso_Female_50': 57882,
#  'soso_Female_55': 52947,
#  'soso_Female_60': 45176,
#  'soso_Female_65': 43107,
#  'soso_Man_20': 50761,
# ...

# %% [markdown]
# 10 20 21 22 30 31 32 33 34 35 40 42 43 44 50 52 60 62 70 71 80 81 92

# %%
bad_card_M_20_sectors_10 = bad_card_M_20[bad_card_M_20.MCT_CAT_CD == 10]
bad_card_M_20_sectors_20 = bad_card_M_20[bad_card_M_20.MCT_CAT_CD == 20]
bad_card_M_20_sectors_21 = bad_card_M_20[bad_card_M_20.MCT_CAT_CD == 21]
bad_card_M_20_sectors_22 = bad_card_M_20[bad_card_M_20.MCT_CAT_CD == 22]
bad_card_M_20_sectors_30 = bad_card_M_20[bad_card_M_20.MCT_CAT_CD == 30]
bad_card_M_20_sectors_31 = bad_card_M_20[bad_card_M_20.MCT_CAT_CD == 31]
bad_card_M_20_sectors_32 = bad_card_M_20[bad_card_M_20.MCT_CAT_CD == 32]
bad_card_M_20_sectors_33 = bad_card_M_20[bad_card_M_20.MCT_CAT_CD == 33]
bad_card_M_20_sectors_34 = bad_card_M_20[bad_card_M_20.MCT_CAT_CD == 34]
bad_card_M_20_sectors_35 = bad_card_M_20[bad_card_M_20.MCT_CAT_CD == 35]
bad_card_M_20_sectors_40 = bad_card_M_20[bad_card_M_20.MCT_CAT_CD == 40]
bad_card_M_20_sectors_42 = bad_card_M_20[bad_card_M_20.MCT_CAT_CD == 42]
bad_card_M_20_sectors_43 = bad_card_M_20[bad_card_M_20.MCT_CAT_CD == 43]
bad_card_M_20_sectors_44 = bad_card_M_20[bad_card_M_20.MCT_CAT_CD == 44]
bad_card_M_20_sectors_50 = bad_card_M_20[bad_card_M_20.MCT_CAT_CD == 50]
bad_card_M_20_sectors_52 = bad_card_M_20[bad_card_M_20.MCT_CAT_CD == 52]
bad_card_M_20_sectors_60 = bad_card_M_20[bad_card_M_20.MCT_CAT_CD == 60]
bad_card_M_20_sectors_62 = bad_card_M_20[bad_card_M_20.MCT_CAT_CD == 62]
bad_card_M_20_sectors_70 = bad_card_M_20[bad_card_M_20.MCT_CAT_CD == 70]
bad_card_M_20_sectors_71 = bad_card_M_20[bad_card_M_20.MCT_CAT_CD == 71]
bad_card_M_20_sectors_80 = bad_card_M_20[bad_card_M_20.MCT_CAT_CD == 80]
bad_card_M_20_sectors_81 = bad_card_M_20[bad_card_M_20.MCT_CAT_CD == 81]
bad_card_M_20_sectors_92 = bad_card_M_20[bad_card_M_20.MCT_CAT_CD == 92]

result['bad_Man_20_Sectors_10'] = len(bad_card_M_20_sectors_10.index)
result['bad_Man_20_Sectors_20'] = len(bad_card_M_20_sectors_20.index)
result['bad_Man_20_Sectors_21'] = len(bad_card_M_20_sectors_21.index)
result['bad_Man_20_Sectors_22'] = len(bad_card_M_20_sectors_22.index)
result['bad_Man_20_Sectors_30'] = len(bad_card_M_20_sectors_30.index)
result['bad_Man_20_Sectors_31'] = len(bad_card_M_20_sectors_31.index)
result['bad_Man_20_Sectors_32'] = len(bad_card_M_20_sectors_32.index)
result['bad_Man_20_Sectors_33'] = len(bad_card_M_20_sectors_33.index)
result['bad_Man_20_Sectors_34'] = len(bad_card_M_20_sectors_34.index)
result['bad_Man_20_Sectors_35'] = len(bad_card_M_20_sectors_35.index)
result['bad_Man_20_Sectors_40'] = len(bad_card_M_20_sectors_40.index)
result['bad_Man_20_Sectors_42'] = len(bad_card_M_20_sectors_42.index)
result['bad_Man_20_Sectors_43'] = len(bad_card_M_20_sectors_43.index)
result['bad_Man_20_Sectors_44'] = len(bad_card_M_20_sectors_44.index)
result['bad_Man_20_Sectors_50'] = len(bad_card_M_20_sectors_50.index)
result['bad_Man_20_Sectors_52'] = len(bad_card_M_20_sectors_52.index)
result['bad_Man_20_Sectors_60'] = len(bad_card_M_20_sectors_60.index)
result['bad_Man_20_Sectors_62'] = len(bad_card_M_20_sectors_62.index)
result['bad_Man_20_Sectors_70'] = len(bad_card_M_20_sectors_70.index)
result['bad_Man_20_Sectors_71'] = len(bad_card_M_20_sectors_71.index)
result['bad_Man_20_Sectors_80'] = len(bad_card_M_20_sectors_80.index)
result['bad_Man_20_Sectors_81'] = len(bad_card_M_20_sectors_81.index)
result['bad_Man_20_Sectors_92'] = len(bad_card_M_20_sectors_92.index)

# %%
result
# Out:
# {'total': 1998575,
#  'bad_dust': 948118,
#  'soso_dust': 1050457,
#  'bad_Female': 478331,
#  'bad_Man': 469787,
#  'soso_Female': 531031,
#  'soso_Man': 519426,
#  'bad_Female_20': 47954,
#  'bad_Female_25': 48818,
#  'bad_Female_30': 47287,
#  'bad_Female_35': 48527,
#  'bad_Female_40': 50385,
#  'bad_Female_45': 54718,
#  'bad_Female_50': 52372,
#  'bad_Female_55': 47908,
#  'bad_Female_60': 40984,
#  'bad_Female_65': 39378,
#  'bad_Man_20': 45052,
#  'bad_Man_25': 51300,
#  'bad_Man_30': 49051,
#  'bad_Man_35': 49739,
#  'bad_Man_40': 48500,
#  'bad_Man_45': 51193,
#  'bad_Man_50': 49744,
#  'bad_Man_55': 45450,
#  'bad_Man_60': 39503,
#  'bad_Man_65': 40255,
#  'soso_Female_20': 53930,
#  'soso_Female_25': 54307,
#  'soso_Female_30': 52740,
#  'soso_Female_35': 54154,
#  'soso_Female_40': 55950,
#  'soso_Female_45': 60838,
#  'soso_Female_50': 57882,
#  'soso_Female_55': 52947,
#  'soso_Female_60': 45176,
#  'soso_Female_65': 43107,
#  'soso_Man_20': 50761,
# ...

# %%
bad_card_M_25_sectors_10 = bad_card_M_25[bad_card_M_25.MCT_CAT_CD == 10]
bad_card_M_25_sectors_20 = bad_card_M_25[bad_card_M_25.MCT_CAT_CD == 20]
bad_card_M_25_sectors_21 = bad_card_M_25[bad_card_M_25.MCT_CAT_CD == 21]
bad_card_M_25_sectors_22 = bad_card_M_25[bad_card_M_25.MCT_CAT_CD == 22]
bad_card_M_25_sectors_30 = bad_card_M_25[bad_card_M_25.MCT_CAT_CD == 30]
bad_card_M_25_sectors_31 = bad_card_M_25[bad_card_M_25.MCT_CAT_CD == 31]
bad_card_M_25_sectors_32 = bad_card_M_25[bad_card_M_25.MCT_CAT_CD == 32]
bad_card_M_25_sectors_33 = bad_card_M_25[bad_card_M_25.MCT_CAT_CD == 33]
bad_card_M_25_sectors_34 = bad_card_M_25[bad_card_M_25.MCT_CAT_CD == 34]
bad_card_M_25_sectors_35 = bad_card_M_25[bad_card_M_25.MCT_CAT_CD == 35]
bad_card_M_25_sectors_40 = bad_card_M_25[bad_card_M_25.MCT_CAT_CD == 40]
bad_card_M_25_sectors_42 = bad_card_M_25[bad_card_M_25.MCT_CAT_CD == 42]
bad_card_M_25_sectors_43 = bad_card_M_25[bad_card_M_25.MCT_CAT_CD == 43]
bad_card_M_25_sectors_44 = bad_card_M_25[bad_card_M_25.MCT_CAT_CD == 44]
bad_card_M_25_sectors_50 = bad_card_M_25[bad_card_M_25.MCT_CAT_CD == 50]
bad_card_M_25_sectors_52 = bad_card_M_25[bad_card_M_25.MCT_CAT_CD == 52]
bad_card_M_25_sectors_60 = bad_card_M_25[bad_card_M_25.MCT_CAT_CD == 60]
bad_card_M_25_sectors_62 = bad_card_M_25[bad_card_M_25.MCT_CAT_CD == 62]
bad_card_M_25_sectors_70 = bad_card_M_25[bad_card_M_25.MCT_CAT_CD == 70]
bad_card_M_25_sectors_71 = bad_card_M_25[bad_card_M_25.MCT_CAT_CD == 71]
bad_card_M_25_sectors_80 = bad_card_M_25[bad_card_M_25.MCT_CAT_CD == 80]
bad_card_M_25_sectors_81 = bad_card_M_25[bad_card_M_25.MCT_CAT_CD == 81]
bad_card_M_25_sectors_92 = bad_card_M_25[bad_card_M_25.MCT_CAT_CD == 92]

result['bad_Man_25_Sectors_10'] = len(bad_card_M_25_sectors_10.index)
result['bad_Man_25_Sectors_20'] = len(bad_card_M_25_sectors_20.index)
result['bad_Man_25_Sectors_21'] = len(bad_card_M_25_sectors_21.index)
result['bad_Man_25_Sectors_22'] = len(bad_card_M_25_sectors_22.index)
result['bad_Man_25_Sectors_30'] = len(bad_card_M_25_sectors_30.index)
result['bad_Man_25_Sectors_31'] = len(bad_card_M_25_sectors_31.index)
result['bad_Man_25_Sectors_32'] = len(bad_card_M_25_sectors_32.index)
result['bad_Man_25_Sectors_33'] = len(bad_card_M_25_sectors_33.index)
result['bad_Man_25_Sectors_34'] = len(bad_card_M_25_sectors_34.index)
result['bad_Man_25_Sectors_35'] = len(bad_card_M_25_sectors_35.index)
result['bad_Man_25_Sectors_40'] = len(bad_card_M_25_sectors_40.index)
result['bad_Man_25_Sectors_42'] = len(bad_card_M_25_sectors_42.index)
result['bad_Man_25_Sectors_43'] = len(bad_card_M_25_sectors_43.index)
result['bad_Man_25_Sectors_44'] = len(bad_card_M_25_sectors_44.index)
result['bad_Man_25_Sectors_50'] = len(bad_card_M_25_sectors_50.index)
result['bad_Man_25_Sectors_52'] = len(bad_card_M_25_sectors_52.index)
result['bad_Man_25_Sectors_60'] = len(bad_card_M_25_sectors_60.index)
result['bad_Man_25_Sectors_62'] = len(bad_card_M_25_sectors_62.index)
result['bad_Man_25_Sectors_70'] = len(bad_card_M_25_sectors_70.index)
result['bad_Man_25_Sectors_71'] = len(bad_card_M_25_sectors_71.index)
result['bad_Man_25_Sectors_80'] = len(bad_card_M_25_sectors_80.index)
result['bad_Man_25_Sectors_81'] = len(bad_card_M_25_sectors_81.index)
result['bad_Man_25_Sectors_92'] = len(bad_card_M_25_sectors_92.index)

# %%
bad_card_M_30_sectors_10 = bad_card_M_30[bad_card_M_30.MCT_CAT_CD == 10]
bad_card_M_30_sectors_20 = bad_card_M_30[bad_card_M_30.MCT_CAT_CD == 20]
bad_card_M_30_sectors_21 = bad_card_M_30[bad_card_M_30.MCT_CAT_CD == 21]
bad_card_M_30_sectors_22 = bad_card_M_30[bad_card_M_30.MCT_CAT_CD == 22]
bad_card_M_30_sectors_30 = bad_card_M_30[bad_card_M_30.MCT_CAT_CD == 30]
bad_card_M_30_sectors_31 = bad_card_M_30[bad_card_M_30.MCT_CAT_CD == 31]
bad_card_M_30_sectors_32 = bad_card_M_30[bad_card_M_30.MCT_CAT_CD == 32]
bad_card_M_30_sectors_33 = bad_card_M_30[bad_card_M_30.MCT_CAT_CD == 33]
bad_card_M_30_sectors_34 = bad_card_M_30[bad_card_M_30.MCT_CAT_CD == 34]
bad_card_M_30_sectors_35 = bad_card_M_30[bad_card_M_30.MCT_CAT_CD == 35]
bad_card_M_30_sectors_40 = bad_card_M_30[bad_card_M_30.MCT_CAT_CD == 40]
bad_card_M_30_sectors_42 = bad_card_M_30[bad_card_M_30.MCT_CAT_CD == 42]
bad_card_M_30_sectors_43 = bad_card_M_30[bad_card_M_30.MCT_CAT_CD == 43]
bad_card_M_30_sectors_44 = bad_card_M_30[bad_card_M_30.MCT_CAT_CD == 44]
bad_card_M_30_sectors_50 = bad_card_M_30[bad_card_M_30.MCT_CAT_CD == 50]
bad_card_M_30_sectors_52 = bad_card_M_30[bad_card_M_30.MCT_CAT_CD == 52]
bad_card_M_30_sectors_60 = bad_card_M_30[bad_card_M_30.MCT_CAT_CD == 60]
bad_card_M_30_sectors_62 = bad_card_M_30[bad_card_M_30.MCT_CAT_CD == 62]
bad_card_M_30_sectors_70 = bad_card_M_30[bad_card_M_30.MCT_CAT_CD == 70]
bad_card_M_30_sectors_71 = bad_card_M_30[bad_card_M_30.MCT_CAT_CD == 71]
bad_card_M_30_sectors_80 = bad_card_M_30[bad_card_M_30.MCT_CAT_CD == 80]
bad_card_M_30_sectors_81 = bad_card_M_30[bad_card_M_30.MCT_CAT_CD == 81]
bad_card_M_30_sectors_92 = bad_card_M_30[bad_card_M_30.MCT_CAT_CD == 92]

result['bad_Man_30_Sectors_10'] = len(bad_card_M_30_sectors_10.index)
result['bad_Man_30_Sectors_20'] = len(bad_card_M_30_sectors_20.index)
result['bad_Man_30_Sectors_21'] = len(bad_card_M_30_sectors_21.index)
result['bad_Man_30_Sectors_22'] = len(bad_card_M_30_sectors_22.index)
result['bad_Man_30_Sectors_30'] = len(bad_card_M_30_sectors_30.index)
result['bad_Man_30_Sectors_31'] = len(bad_card_M_30_sectors_31.index)
result['bad_Man_30_Sectors_32'] = len(bad_card_M_30_sectors_32.index)
result['bad_Man_30_Sectors_33'] = len(bad_card_M_30_sectors_33.index)
result['bad_Man_30_Sectors_34'] = len(bad_card_M_30_sectors_34.index)
result['bad_Man_30_Sectors_35'] = len(bad_card_M_30_sectors_35.index)
result['bad_Man_30_Sectors_40'] = len(bad_card_M_30_sectors_40.index)
result['bad_Man_30_Sectors_42'] = len(bad_card_M_30_sectors_42.index)
result['bad_Man_30_Sectors_43'] = len(bad_card_M_30_sectors_43.index)
result['bad_Man_30_Sectors_44'] = len(bad_card_M_30_sectors_44.index)
result['bad_Man_30_Sectors_50'] = len(bad_card_M_30_sectors_50.index)
result['bad_Man_30_Sectors_52'] = len(bad_card_M_30_sectors_52.index)
result['bad_Man_30_Sectors_60'] = len(bad_card_M_30_sectors_60.index)
result['bad_Man_30_Sectors_62'] = len(bad_card_M_30_sectors_62.index)
result['bad_Man_30_Sectors_70'] = len(bad_card_M_30_sectors_70.index)
result['bad_Man_30_Sectors_71'] = len(bad_card_M_30_sectors_71.index)
result['bad_Man_30_Sectors_80'] = len(bad_card_M_30_sectors_80.index)
result['bad_Man_30_Sectors_81'] = len(bad_card_M_30_sectors_81.index)
result['bad_Man_30_Sectors_92'] = len(bad_card_M_30_sectors_92.index)

# %%
bad_card_M_35_sectors_10 = bad_card_M_35[bad_card_M_35.MCT_CAT_CD == 10]
bad_card_M_35_sectors_20 = bad_card_M_35[bad_card_M_35.MCT_CAT_CD == 20]
bad_card_M_35_sectors_21 = bad_card_M_35[bad_card_M_35.MCT_CAT_CD == 21]
bad_card_M_35_sectors_22 = bad_card_M_35[bad_card_M_35.MCT_CAT_CD == 22]
bad_card_M_35_sectors_30 = bad_card_M_35[bad_card_M_35.MCT_CAT_CD == 30]
bad_card_M_35_sectors_31 = bad_card_M_35[bad_card_M_35.MCT_CAT_CD == 31]
bad_card_M_35_sectors_32 = bad_card_M_35[bad_card_M_35.MCT_CAT_CD == 32]
bad_card_M_35_sectors_33 = bad_card_M_35[bad_card_M_35.MCT_CAT_CD == 33]
bad_card_M_35_sectors_34 = bad_card_M_35[bad_card_M_35.MCT_CAT_CD == 34]
bad_card_M_35_sectors_35 = bad_card_M_35[bad_card_M_35.MCT_CAT_CD == 35]
bad_card_M_35_sectors_40 = bad_card_M_35[bad_card_M_35.MCT_CAT_CD == 40]
bad_card_M_35_sectors_42 = bad_card_M_35[bad_card_M_35.MCT_CAT_CD == 42]
bad_card_M_35_sectors_43 = bad_card_M_35[bad_card_M_35.MCT_CAT_CD == 43]
bad_card_M_35_sectors_44 = bad_card_M_35[bad_card_M_35.MCT_CAT_CD == 44]
bad_card_M_35_sectors_50 = bad_card_M_35[bad_card_M_35.MCT_CAT_CD == 50]
bad_card_M_35_sectors_52 = bad_card_M_35[bad_card_M_35.MCT_CAT_CD == 52]
bad_card_M_35_sectors_60 = bad_card_M_35[bad_card_M_35.MCT_CAT_CD == 60]
bad_card_M_35_sectors_62 = bad_card_M_35[bad_card_M_35.MCT_CAT_CD == 62]
bad_card_M_35_sectors_70 = bad_card_M_35[bad_card_M_35.MCT_CAT_CD == 70]
bad_card_M_35_sectors_71 = bad_card_M_35[bad_card_M_35.MCT_CAT_CD == 71]
bad_card_M_35_sectors_80 = bad_card_M_35[bad_card_M_35.MCT_CAT_CD == 80]
bad_card_M_35_sectors_81 = bad_card_M_35[bad_card_M_35.MCT_CAT_CD == 81]
bad_card_M_35_sectors_92 = bad_card_M_35[bad_card_M_35.MCT_CAT_CD == 92]

result['bad_Man_35_Sectors_10'] = len(bad_card_M_35_sectors_10.index)
result['bad_Man_35_Sectors_20'] = len(bad_card_M_35_sectors_20.index)
result['bad_Man_35_Sectors_21'] = len(bad_card_M_35_sectors_21.index)
result['bad_Man_35_Sectors_22'] = len(bad_card_M_35_sectors_22.index)
result['bad_Man_35_Sectors_30'] = len(bad_card_M_35_sectors_30.index)
result['bad_Man_35_Sectors_31'] = len(bad_card_M_35_sectors_31.index)
result['bad_Man_35_Sectors_32'] = len(bad_card_M_35_sectors_32.index)
result['bad_Man_35_Sectors_33'] = len(bad_card_M_35_sectors_33.index)
result['bad_Man_35_Sectors_34'] = len(bad_card_M_35_sectors_34.index)
result['bad_Man_35_Sectors_35'] = len(bad_card_M_35_sectors_35.index)
result['bad_Man_35_Sectors_40'] = len(bad_card_M_35_sectors_40.index)
result['bad_Man_35_Sectors_42'] = len(bad_card_M_35_sectors_42.index)
result['bad_Man_35_Sectors_43'] = len(bad_card_M_35_sectors_43.index)
result['bad_Man_35_Sectors_44'] = len(bad_card_M_35_sectors_44.index)
result['bad_Man_35_Sectors_50'] = len(bad_card_M_35_sectors_50.index)
result['bad_Man_35_Sectors_52'] = len(bad_card_M_35_sectors_52.index)
result['bad_Man_35_Sectors_60'] = len(bad_card_M_35_sectors_60.index)
result['bad_Man_35_Sectors_62'] = len(bad_card_M_35_sectors_62.index)
result['bad_Man_35_Sectors_70'] = len(bad_card_M_35_sectors_70.index)
result['bad_Man_35_Sectors_71'] = len(bad_card_M_35_sectors_71.index)
result['bad_Man_35_Sectors_80'] = len(bad_card_M_35_sectors_80.index)
result['bad_Man_35_Sectors_81'] = len(bad_card_M_35_sectors_81.index)
result['bad_Man_35_Sectors_92'] = len(bad_card_M_35_sectors_92.index)

# %%
bad_card_M_40_sectors_10 = bad_card_M_40[bad_card_M_40.MCT_CAT_CD == 10]
bad_card_M_40_sectors_20 = bad_card_M_40[bad_card_M_40.MCT_CAT_CD == 20]
bad_card_M_40_sectors_21 = bad_card_M_40[bad_card_M_40.MCT_CAT_CD == 21]
bad_card_M_40_sectors_22 = bad_card_M_40[bad_card_M_40.MCT_CAT_CD == 22]
bad_card_M_40_sectors_30 = bad_card_M_40[bad_card_M_40.MCT_CAT_CD == 30]
bad_card_M_40_sectors_31 = bad_card_M_40[bad_card_M_40.MCT_CAT_CD == 31]
bad_card_M_40_sectors_32 = bad_card_M_40[bad_card_M_40.MCT_CAT_CD == 32]
bad_card_M_40_sectors_33 = bad_card_M_40[bad_card_M_40.MCT_CAT_CD == 33]
bad_card_M_40_sectors_34 = bad_card_M_40[bad_card_M_40.MCT_CAT_CD == 34]
bad_card_M_40_sectors_35 = bad_card_M_40[bad_card_M_40.MCT_CAT_CD == 35]
bad_card_M_40_sectors_40 = bad_card_M_40[bad_card_M_40.MCT_CAT_CD == 40]
bad_card_M_40_sectors_42 = bad_card_M_40[bad_card_M_40.MCT_CAT_CD == 42]
bad_card_M_40_sectors_43 = bad_card_M_40[bad_card_M_40.MCT_CAT_CD == 43]
bad_card_M_40_sectors_44 = bad_card_M_40[bad_card_M_40.MCT_CAT_CD == 44]
bad_card_M_40_sectors_50 = bad_card_M_40[bad_card_M_40.MCT_CAT_CD == 50]
bad_card_M_40_sectors_52 = bad_card_M_40[bad_card_M_40.MCT_CAT_CD == 52]
bad_card_M_40_sectors_60 = bad_card_M_40[bad_card_M_40.MCT_CAT_CD == 60]
bad_card_M_40_sectors_62 = bad_card_M_40[bad_card_M_40.MCT_CAT_CD == 62]
bad_card_M_40_sectors_70 = bad_card_M_40[bad_card_M_40.MCT_CAT_CD == 70]
bad_card_M_40_sectors_71 = bad_card_M_40[bad_card_M_40.MCT_CAT_CD == 71]
bad_card_M_40_sectors_80 = bad_card_M_40[bad_card_M_40.MCT_CAT_CD == 80]
bad_card_M_40_sectors_81 = bad_card_M_40[bad_card_M_40.MCT_CAT_CD == 81]
bad_card_M_40_sectors_92 = bad_card_M_40[bad_card_M_40.MCT_CAT_CD == 92]

result['bad_Man_40_Sectors_10'] = len(bad_card_M_40_sectors_10.index)
result['bad_Man_40_Sectors_20'] = len(bad_card_M_40_sectors_20.index)
result['bad_Man_40_Sectors_21'] = len(bad_card_M_40_sectors_21.index)
result['bad_Man_40_Sectors_22'] = len(bad_card_M_40_sectors_22.index)
result['bad_Man_40_Sectors_30'] = len(bad_card_M_40_sectors_30.index)
result['bad_Man_40_Sectors_31'] = len(bad_card_M_40_sectors_31.index)
result['bad_Man_40_Sectors_32'] = len(bad_card_M_40_sectors_32.index)
result['bad_Man_40_Sectors_33'] = len(bad_card_M_40_sectors_33.index)
result['bad_Man_40_Sectors_34'] = len(bad_card_M_40_sectors_34.index)
result['bad_Man_40_Sectors_35'] = len(bad_card_M_40_sectors_35.index)
result['bad_Man_40_Sectors_40'] = len(bad_card_M_40_sectors_40.index)
result['bad_Man_40_Sectors_42'] = len(bad_card_M_40_sectors_42.index)
result['bad_Man_40_Sectors_43'] = len(bad_card_M_40_sectors_43.index)
result['bad_Man_40_Sectors_44'] = len(bad_card_M_40_sectors_44.index)
result['bad_Man_40_Sectors_50'] = len(bad_card_M_40_sectors_50.index)
result['bad_Man_40_Sectors_52'] = len(bad_card_M_40_sectors_52.index)
result['bad_Man_40_Sectors_60'] = len(bad_card_M_40_sectors_60.index)
result['bad_Man_40_Sectors_62'] = len(bad_card_M_40_sectors_62.index)
result['bad_Man_40_Sectors_70'] = len(bad_card_M_40_sectors_70.index)
result['bad_Man_40_Sectors_71'] = len(bad_card_M_40_sectors_71.index)
result['bad_Man_40_Sectors_80'] = len(bad_card_M_40_sectors_80.index)
result['bad_Man_40_Sectors_81'] = len(bad_card_M_40_sectors_81.index)
result['bad_Man_40_Sectors_92'] = len(bad_card_M_40_sectors_92.index)

bad_card_M_45_sectors_10 = bad_card_M_45[bad_card_M_45.MCT_CAT_CD == 10]
bad_card_M_45_sectors_20 = bad_card_M_45[bad_card_M_45.MCT_CAT_CD == 20]
bad_card_M_45_sectors_21 = bad_card_M_45[bad_card_M_45.MCT_CAT_CD == 21]
bad_card_M_45_sectors_22 = bad_card_M_45[bad_card_M_45.MCT_CAT_CD == 22]
bad_card_M_45_sectors_30 = bad_card_M_45[bad_card_M_45.MCT_CAT_CD == 30]
bad_card_M_45_sectors_31 = bad_card_M_45[bad_card_M_45.MCT_CAT_CD == 31]
bad_card_M_45_sectors_32 = bad_card_M_45[bad_card_M_45.MCT_CAT_CD == 32]
bad_card_M_45_sectors_33 = bad_card_M_45[bad_card_M_45.MCT_CAT_CD == 33]
bad_card_M_45_sectors_34 = bad_card_M_45[bad_card_M_45.MCT_CAT_CD == 34]
bad_card_M_45_sectors_35 = bad_card_M_45[bad_card_M_45.MCT_CAT_CD == 35]
bad_card_M_45_sectors_40 = bad_card_M_45[bad_card_M_45.MCT_CAT_CD == 40]
bad_card_M_45_sectors_42 = bad_card_M_45[bad_card_M_45.MCT_CAT_CD == 42]
bad_card_M_45_sectors_43 = bad_card_M_45[bad_card_M_45.MCT_CAT_CD == 43]
bad_card_M_45_sectors_44 = bad_card_M_45[bad_card_M_45.MCT_CAT_CD == 44]
bad_card_M_45_sectors_50 = bad_card_M_45[bad_card_M_45.MCT_CAT_CD == 50]
bad_card_M_45_sectors_52 = bad_card_M_45[bad_card_M_45.MCT_CAT_CD == 52]
bad_card_M_45_sectors_60 = bad_card_M_45[bad_card_M_45.MCT_CAT_CD == 60]
bad_card_M_45_sectors_62 = bad_card_M_45[bad_card_M_45.MCT_CAT_CD == 62]
bad_card_M_45_sectors_70 = bad_card_M_45[bad_card_M_45.MCT_CAT_CD == 70]
bad_card_M_45_sectors_71 = bad_card_M_45[bad_card_M_45.MCT_CAT_CD == 71]
bad_card_M_45_sectors_80 = bad_card_M_45[bad_card_M_45.MCT_CAT_CD == 80]
bad_card_M_45_sectors_81 = bad_card_M_45[bad_card_M_45.MCT_CAT_CD == 81]
bad_card_M_45_sectors_92 = bad_card_M_45[bad_card_M_45.MCT_CAT_CD == 92]

result['bad_Man_45_Sectors_10'] = len(bad_card_M_45_sectors_10.index)
result['bad_Man_45_Sectors_20'] = len(bad_card_M_45_sectors_20.index)
result['bad_Man_45_Sectors_21'] = len(bad_card_M_45_sectors_21.index)
result['bad_Man_45_Sectors_22'] = len(bad_card_M_45_sectors_22.index)
result['bad_Man_45_Sectors_30'] = len(bad_card_M_45_sectors_30.index)
result['bad_Man_45_Sectors_31'] = len(bad_card_M_45_sectors_31.index)
result['bad_Man_45_Sectors_32'] = len(bad_card_M_45_sectors_32.index)
result['bad_Man_45_Sectors_33'] = len(bad_card_M_45_sectors_33.index)
result['bad_Man_45_Sectors_34'] = len(bad_card_M_45_sectors_34.index)
result['bad_Man_45_Sectors_35'] = len(bad_card_M_45_sectors_35.index)
result['bad_Man_45_Sectors_40'] = len(bad_card_M_45_sectors_40.index)
result['bad_Man_45_Sectors_42'] = len(bad_card_M_45_sectors_42.index)
result['bad_Man_45_Sectors_43'] = len(bad_card_M_45_sectors_43.index)
result['bad_Man_45_Sectors_44'] = len(bad_card_M_45_sectors_44.index)
result['bad_Man_45_Sectors_50'] = len(bad_card_M_45_sectors_50.index)
result['bad_Man_45_Sectors_52'] = len(bad_card_M_45_sectors_52.index)
result['bad_Man_45_Sectors_60'] = len(bad_card_M_45_sectors_60.index)
result['bad_Man_45_Sectors_62'] = len(bad_card_M_45_sectors_62.index)
result['bad_Man_45_Sectors_70'] = len(bad_card_M_45_sectors_70.index)
result['bad_Man_45_Sectors_71'] = len(bad_card_M_45_sectors_71.index)
result['bad_Man_45_Sectors_80'] = len(bad_card_M_45_sectors_80.index)
result['bad_Man_45_Sectors_81'] = len(bad_card_M_45_sectors_81.index)
result['bad_Man_45_Sectors_92'] = len(bad_card_M_45_sectors_92.index)

bad_card_M_50_sectors_10 = bad_card_M_50[bad_card_M_50.MCT_CAT_CD == 10]
bad_card_M_50_sectors_20 = bad_card_M_50[bad_card_M_50.MCT_CAT_CD == 20]
bad_card_M_50_sectors_21 = bad_card_M_50[bad_card_M_50.MCT_CAT_CD == 21]
bad_card_M_50_sectors_22 = bad_card_M_50[bad_card_M_50.MCT_CAT_CD == 22]
bad_card_M_50_sectors_30 = bad_card_M_50[bad_card_M_50.MCT_CAT_CD == 30]
bad_card_M_50_sectors_31 = bad_card_M_50[bad_card_M_50.MCT_CAT_CD == 31]
bad_card_M_50_sectors_32 = bad_card_M_50[bad_card_M_50.MCT_CAT_CD == 32]
bad_card_M_50_sectors_33 = bad_card_M_50[bad_card_M_50.MCT_CAT_CD == 33]
bad_card_M_50_sectors_34 = bad_card_M_50[bad_card_M_50.MCT_CAT_CD == 34]
bad_card_M_50_sectors_35 = bad_card_M_50[bad_card_M_50.MCT_CAT_CD == 35]
bad_card_M_50_sectors_40 = bad_card_M_50[bad_card_M_50.MCT_CAT_CD == 40]
bad_card_M_50_sectors_42 = bad_card_M_50[bad_card_M_50.MCT_CAT_CD == 42]
bad_card_M_50_sectors_43 = bad_card_M_50[bad_card_M_50.MCT_CAT_CD == 43]
bad_card_M_50_sectors_44 = bad_card_M_50[bad_card_M_50.MCT_CAT_CD == 44]
bad_card_M_50_sectors_50 = bad_card_M_50[bad_card_M_50.MCT_CAT_CD == 50]
bad_card_M_50_sectors_52 = bad_card_M_50[bad_card_M_50.MCT_CAT_CD == 52]
bad_card_M_50_sectors_60 = bad_card_M_50[bad_card_M_50.MCT_CAT_CD == 60]
bad_card_M_50_sectors_62 = bad_card_M_50[bad_card_M_50.MCT_CAT_CD == 62]
bad_card_M_50_sectors_70 = bad_card_M_50[bad_card_M_50.MCT_CAT_CD == 70]
bad_card_M_50_sectors_71 = bad_card_M_50[bad_card_M_50.MCT_CAT_CD == 71]
bad_card_M_50_sectors_80 = bad_card_M_50[bad_card_M_50.MCT_CAT_CD == 80]
bad_card_M_50_sectors_81 = bad_card_M_50[bad_card_M_50.MCT_CAT_CD == 81]
bad_card_M_50_sectors_92 = bad_card_M_50[bad_card_M_50.MCT_CAT_CD == 92]

result['bad_Man_50_Sectors_10'] = len(bad_card_M_50_sectors_10.index)
result['bad_Man_50_Sectors_20'] = len(bad_card_M_50_sectors_20.index)
result['bad_Man_50_Sectors_21'] = len(bad_card_M_50_sectors_21.index)
result['bad_Man_50_Sectors_22'] = len(bad_card_M_50_sectors_22.index)
result['bad_Man_50_Sectors_30'] = len(bad_card_M_50_sectors_30.index)
result['bad_Man_50_Sectors_31'] = len(bad_card_M_50_sectors_31.index)
result['bad_Man_50_Sectors_32'] = len(bad_card_M_50_sectors_32.index)
result['bad_Man_50_Sectors_33'] = len(bad_card_M_50_sectors_33.index)
result['bad_Man_50_Sectors_34'] = len(bad_card_M_50_sectors_34.index)
result['bad_Man_50_Sectors_35'] = len(bad_card_M_50_sectors_35.index)
result['bad_Man_50_Sectors_40'] = len(bad_card_M_50_sectors_40.index)
result['bad_Man_50_Sectors_42'] = len(bad_card_M_50_sectors_42.index)
result['bad_Man_50_Sectors_43'] = len(bad_card_M_50_sectors_43.index)
result['bad_Man_50_Sectors_44'] = len(bad_card_M_50_sectors_44.index)
result['bad_Man_50_Sectors_50'] = len(bad_card_M_50_sectors_50.index)
result['bad_Man_50_Sectors_52'] = len(bad_card_M_50_sectors_52.index)
result['bad_Man_50_Sectors_60'] = len(bad_card_M_50_sectors_60.index)
result['bad_Man_50_Sectors_62'] = len(bad_card_M_50_sectors_62.index)
result['bad_Man_50_Sectors_70'] = len(bad_card_M_50_sectors_70.index)
result['bad_Man_50_Sectors_71'] = len(bad_card_M_50_sectors_71.index)
result['bad_Man_50_Sectors_80'] = len(bad_card_M_50_sectors_80.index)
result['bad_Man_50_Sectors_81'] = len(bad_card_M_50_sectors_81.index)
result['bad_Man_50_Sectors_92'] = len(bad_card_M_50_sectors_92.index)

bad_card_M_55_sectors_10 = bad_card_M_55[bad_card_M_55.MCT_CAT_CD == 10]
bad_card_M_55_sectors_20 = bad_card_M_55[bad_card_M_55.MCT_CAT_CD == 20]
bad_card_M_55_sectors_21 = bad_card_M_55[bad_card_M_55.MCT_CAT_CD == 21]
bad_card_M_55_sectors_22 = bad_card_M_55[bad_card_M_55.MCT_CAT_CD == 22]
bad_card_M_55_sectors_30 = bad_card_M_55[bad_card_M_55.MCT_CAT_CD == 30]
bad_card_M_55_sectors_31 = bad_card_M_55[bad_card_M_55.MCT_CAT_CD == 31]
bad_card_M_55_sectors_32 = bad_card_M_55[bad_card_M_55.MCT_CAT_CD == 32]
bad_card_M_55_sectors_33 = bad_card_M_55[bad_card_M_55.MCT_CAT_CD == 33]
bad_card_M_55_sectors_34 = bad_card_M_55[bad_card_M_55.MCT_CAT_CD == 34]
bad_card_M_55_sectors_35 = bad_card_M_55[bad_card_M_55.MCT_CAT_CD == 35]
bad_card_M_55_sectors_40 = bad_card_M_55[bad_card_M_55.MCT_CAT_CD == 40]
bad_card_M_55_sectors_42 = bad_card_M_55[bad_card_M_55.MCT_CAT_CD == 42]
bad_card_M_55_sectors_43 = bad_card_M_55[bad_card_M_55.MCT_CAT_CD == 43]
bad_card_M_55_sectors_44 = bad_card_M_55[bad_card_M_55.MCT_CAT_CD == 44]
bad_card_M_55_sectors_50 = bad_card_M_55[bad_card_M_55.MCT_CAT_CD == 50]
bad_card_M_55_sectors_52 = bad_card_M_55[bad_card_M_55.MCT_CAT_CD == 52]
bad_card_M_55_sectors_60 = bad_card_M_55[bad_card_M_55.MCT_CAT_CD == 60]
bad_card_M_55_sectors_62 = bad_card_M_55[bad_card_M_55.MCT_CAT_CD == 62]
bad_card_M_55_sectors_70 = bad_card_M_55[bad_card_M_55.MCT_CAT_CD == 70]
bad_card_M_55_sectors_71 = bad_card_M_55[bad_card_M_55.MCT_CAT_CD == 71]
bad_card_M_55_sectors_80 = bad_card_M_55[bad_card_M_55.MCT_CAT_CD == 80]
bad_card_M_55_sectors_81 = bad_card_M_55[bad_card_M_55.MCT_CAT_CD == 81]
bad_card_M_55_sectors_92 = bad_card_M_55[bad_card_M_55.MCT_CAT_CD == 92]

result['bad_Man_55_Sectors_10'] = len(bad_card_M_55_sectors_10.index)
result['bad_Man_55_Sectors_20'] = len(bad_card_M_55_sectors_20.index)
result['bad_Man_55_Sectors_21'] = len(bad_card_M_55_sectors_21.index)
result['bad_Man_55_Sectors_22'] = len(bad_card_M_55_sectors_22.index)
result['bad_Man_55_Sectors_30'] = len(bad_card_M_55_sectors_30.index)
result['bad_Man_55_Sectors_31'] = len(bad_card_M_55_sectors_31.index)
result['bad_Man_55_Sectors_32'] = len(bad_card_M_55_sectors_32.index)
result['bad_Man_55_Sectors_33'] = len(bad_card_M_55_sectors_33.index)
result['bad_Man_55_Sectors_34'] = len(bad_card_M_55_sectors_34.index)
result['bad_Man_55_Sectors_35'] = len(bad_card_M_55_sectors_35.index)
result['bad_Man_55_Sectors_40'] = len(bad_card_M_55_sectors_40.index)
result['bad_Man_55_Sectors_42'] = len(bad_card_M_55_sectors_42.index)
result['bad_Man_55_Sectors_43'] = len(bad_card_M_55_sectors_43.index)
result['bad_Man_55_Sectors_44'] = len(bad_card_M_55_sectors_44.index)
result['bad_Man_55_Sectors_50'] = len(bad_card_M_55_sectors_50.index)
result['bad_Man_55_Sectors_52'] = len(bad_card_M_55_sectors_52.index)
result['bad_Man_55_Sectors_60'] = len(bad_card_M_55_sectors_60.index)
result['bad_Man_55_Sectors_62'] = len(bad_card_M_55_sectors_62.index)
result['bad_Man_55_Sectors_70'] = len(bad_card_M_55_sectors_70.index)
result['bad_Man_55_Sectors_71'] = len(bad_card_M_55_sectors_71.index)
result['bad_Man_55_Sectors_80'] = len(bad_card_M_55_sectors_80.index)
result['bad_Man_55_Sectors_81'] = len(bad_card_M_55_sectors_81.index)
result['bad_Man_55_Sectors_92'] = len(bad_card_M_55_sectors_92.index)

bad_card_M_60_sectors_10 = bad_card_M_60[bad_card_M_60.MCT_CAT_CD == 10]
bad_card_M_60_sectors_20 = bad_card_M_60[bad_card_M_60.MCT_CAT_CD == 20]
bad_card_M_60_sectors_21 = bad_card_M_60[bad_card_M_60.MCT_CAT_CD == 21]
bad_card_M_60_sectors_22 = bad_card_M_60[bad_card_M_60.MCT_CAT_CD == 22]
bad_card_M_60_sectors_30 = bad_card_M_60[bad_card_M_60.MCT_CAT_CD == 30]
bad_card_M_60_sectors_31 = bad_card_M_60[bad_card_M_60.MCT_CAT_CD == 31]
bad_card_M_60_sectors_32 = bad_card_M_60[bad_card_M_60.MCT_CAT_CD == 32]
bad_card_M_60_sectors_33 = bad_card_M_60[bad_card_M_60.MCT_CAT_CD == 33]
bad_card_M_60_sectors_34 = bad_card_M_60[bad_card_M_60.MCT_CAT_CD == 34]
bad_card_M_60_sectors_35 = bad_card_M_60[bad_card_M_60.MCT_CAT_CD == 35]
bad_card_M_60_sectors_40 = bad_card_M_60[bad_card_M_60.MCT_CAT_CD == 40]
bad_card_M_60_sectors_42 = bad_card_M_60[bad_card_M_60.MCT_CAT_CD == 42]
bad_card_M_60_sectors_43 = bad_card_M_60[bad_card_M_60.MCT_CAT_CD == 43]
bad_card_M_60_sectors_44 = bad_card_M_60[bad_card_M_60.MCT_CAT_CD == 44]
bad_card_M_60_sectors_50 = bad_card_M_60[bad_card_M_60.MCT_CAT_CD == 50]
bad_card_M_60_sectors_52 = bad_card_M_60[bad_card_M_60.MCT_CAT_CD == 52]
bad_card_M_60_sectors_60 = bad_card_M_60[bad_card_M_60.MCT_CAT_CD == 60]
bad_card_M_60_sectors_62 = bad_card_M_60[bad_card_M_60.MCT_CAT_CD == 62]
bad_card_M_60_sectors_70 = bad_card_M_60[bad_card_M_60.MCT_CAT_CD == 70]
bad_card_M_60_sectors_71 = bad_card_M_60[bad_card_M_60.MCT_CAT_CD == 71]
bad_card_M_60_sectors_80 = bad_card_M_60[bad_card_M_60.MCT_CAT_CD == 80]
bad_card_M_60_sectors_81 = bad_card_M_60[bad_card_M_60.MCT_CAT_CD == 81]
bad_card_M_60_sectors_92 = bad_card_M_60[bad_card_M_60.MCT_CAT_CD == 92]

result['bad_Man_60_Sectors_10'] = len(bad_card_M_60_sectors_10.index)
result['bad_Man_60_Sectors_20'] = len(bad_card_M_60_sectors_20.index)
result['bad_Man_60_Sectors_21'] = len(bad_card_M_60_sectors_21.index)
result['bad_Man_60_Sectors_22'] = len(bad_card_M_60_sectors_22.index)
result['bad_Man_60_Sectors_30'] = len(bad_card_M_60_sectors_30.index)
result['bad_Man_60_Sectors_31'] = len(bad_card_M_60_sectors_31.index)
result['bad_Man_60_Sectors_32'] = len(bad_card_M_60_sectors_32.index)
result['bad_Man_60_Sectors_33'] = len(bad_card_M_60_sectors_33.index)
result['bad_Man_60_Sectors_34'] = len(bad_card_M_60_sectors_34.index)
result['bad_Man_60_Sectors_35'] = len(bad_card_M_60_sectors_35.index)
result['bad_Man_60_Sectors_40'] = len(bad_card_M_60_sectors_40.index)
result['bad_Man_60_Sectors_42'] = len(bad_card_M_60_sectors_42.index)
result['bad_Man_60_Sectors_43'] = len(bad_card_M_60_sectors_43.index)
result['bad_Man_60_Sectors_44'] = len(bad_card_M_60_sectors_44.index)
result['bad_Man_60_Sectors_50'] = len(bad_card_M_60_sectors_50.index)
result['bad_Man_60_Sectors_52'] = len(bad_card_M_60_sectors_52.index)
result['bad_Man_60_Sectors_60'] = len(bad_card_M_60_sectors_60.index)
result['bad_Man_60_Sectors_62'] = len(bad_card_M_60_sectors_62.index)
result['bad_Man_60_Sectors_70'] = len(bad_card_M_60_sectors_70.index)
result['bad_Man_60_Sectors_71'] = len(bad_card_M_60_sectors_71.index)
result['bad_Man_60_Sectors_80'] = len(bad_card_M_60_sectors_80.index)
result['bad_Man_60_Sectors_81'] = len(bad_card_M_60_sectors_81.index)
result['bad_Man_60_Sectors_92'] = len(bad_card_M_60_sectors_92.index)

bad_card_M_65_sectors_10 = bad_card_M_65[bad_card_M_65.MCT_CAT_CD == 10]
bad_card_M_65_sectors_20 = bad_card_M_65[bad_card_M_65.MCT_CAT_CD == 20]
bad_card_M_65_sectors_21 = bad_card_M_65[bad_card_M_65.MCT_CAT_CD == 21]
bad_card_M_65_sectors_22 = bad_card_M_65[bad_card_M_65.MCT_CAT_CD == 22]
bad_card_M_65_sectors_30 = bad_card_M_65[bad_card_M_65.MCT_CAT_CD == 30]
bad_card_M_65_sectors_31 = bad_card_M_65[bad_card_M_65.MCT_CAT_CD == 31]
bad_card_M_65_sectors_32 = bad_card_M_65[bad_card_M_65.MCT_CAT_CD == 32]
bad_card_M_65_sectors_33 = bad_card_M_65[bad_card_M_65.MCT_CAT_CD == 33]
bad_card_M_65_sectors_34 = bad_card_M_65[bad_card_M_65.MCT_CAT_CD == 34]
bad_card_M_65_sectors_35 = bad_card_M_65[bad_card_M_65.MCT_CAT_CD == 35]
bad_card_M_65_sectors_40 = bad_card_M_65[bad_card_M_65.MCT_CAT_CD == 40]
bad_card_M_65_sectors_42 = bad_card_M_65[bad_card_M_65.MCT_CAT_CD == 42]
bad_card_M_65_sectors_43 = bad_card_M_65[bad_card_M_65.MCT_CAT_CD == 43]
bad_card_M_65_sectors_44 = bad_card_M_65[bad_card_M_65.MCT_CAT_CD == 44]
bad_card_M_65_sectors_50 = bad_card_M_65[bad_card_M_65.MCT_CAT_CD == 50]
bad_card_M_65_sectors_52 = bad_card_M_65[bad_card_M_65.MCT_CAT_CD == 52]
bad_card_M_65_sectors_60 = bad_card_M_65[bad_card_M_65.MCT_CAT_CD == 60]
bad_card_M_65_sectors_62 = bad_card_M_65[bad_card_M_65.MCT_CAT_CD == 62]
bad_card_M_65_sectors_70 = bad_card_M_65[bad_card_M_65.MCT_CAT_CD == 70]
bad_card_M_65_sectors_71 = bad_card_M_65[bad_card_M_65.MCT_CAT_CD == 71]
bad_card_M_65_sectors_80 = bad_card_M_65[bad_card_M_65.MCT_CAT_CD == 80]
bad_card_M_65_sectors_81 = bad_card_M_65[bad_card_M_65.MCT_CAT_CD == 81]
bad_card_M_65_sectors_92 = bad_card_M_65[bad_card_M_65.MCT_CAT_CD == 92]

result['bad_Man_65_Sectors_10'] = len(bad_card_M_65_sectors_10.index)
result['bad_Man_65_Sectors_20'] = len(bad_card_M_65_sectors_20.index)
result['bad_Man_65_Sectors_21'] = len(bad_card_M_65_sectors_21.index)
result['bad_Man_65_Sectors_22'] = len(bad_card_M_65_sectors_22.index)
result['bad_Man_65_Sectors_30'] = len(bad_card_M_65_sectors_30.index)
result['bad_Man_65_Sectors_31'] = len(bad_card_M_65_sectors_31.index)
result['bad_Man_65_Sectors_32'] = len(bad_card_M_65_sectors_32.index)
result['bad_Man_65_Sectors_33'] = len(bad_card_M_65_sectors_33.index)
result['bad_Man_65_Sectors_34'] = len(bad_card_M_65_sectors_34.index)
result['bad_Man_65_Sectors_35'] = len(bad_card_M_65_sectors_35.index)
result['bad_Man_65_Sectors_40'] = len(bad_card_M_65_sectors_40.index)
result['bad_Man_65_Sectors_42'] = len(bad_card_M_65_sectors_42.index)
result['bad_Man_65_Sectors_43'] = len(bad_card_M_65_sectors_43.index)
result['bad_Man_65_Sectors_44'] = len(bad_card_M_65_sectors_44.index)
result['bad_Man_65_Sectors_50'] = len(bad_card_M_65_sectors_50.index)
result['bad_Man_65_Sectors_52'] = len(bad_card_M_65_sectors_52.index)
result['bad_Man_65_Sectors_60'] = len(bad_card_M_65_sectors_60.index)
result['bad_Man_65_Sectors_62'] = len(bad_card_M_65_sectors_62.index)
result['bad_Man_65_Sectors_70'] = len(bad_card_M_65_sectors_70.index)
result['bad_Man_65_Sectors_71'] = len(bad_card_M_65_sectors_71.index)
result['bad_Man_65_Sectors_80'] = len(bad_card_M_65_sectors_80.index)
result['bad_Man_65_Sectors_81'] = len(bad_card_M_65_sectors_81.index)
result['bad_Man_65_Sectors_92'] = len(bad_card_M_65_sectors_92.index)

# %%
result
# Out:
# {'total': 1998575,
#  'bad_dust': 948118,
#  'soso_dust': 1050457,
#  'bad_Female': 478331,
#  'bad_Man': 469787,
#  'soso_Female': 531031,
#  'soso_Man': 519426,
#  'bad_Female_20': 47954,
#  'bad_Female_25': 48818,
#  'bad_Female_30': 47287,
#  'bad_Female_35': 48527,
#  'bad_Female_40': 50385,
#  'bad_Female_45': 54718,
#  'bad_Female_50': 52372,
#  'bad_Female_55': 47908,
#  'bad_Female_60': 40984,
#  'bad_Female_65': 39378,
#  'bad_Man_20': 45052,
#  'bad_Man_25': 51300,
#  'bad_Man_30': 49051,
#  'bad_Man_35': 49739,
#  'bad_Man_40': 48500,
#  'bad_Man_45': 51193,
#  'bad_Man_50': 49744,
#  'bad_Man_55': 45450,
#  'bad_Man_60': 39503,
#  'bad_Man_65': 40255,
#  'soso_Female_20': 53930,
#  'soso_Female_25': 54307,
#  'soso_Female_30': 52740,
#  'soso_Female_35': 54154,
#  'soso_Female_40': 55950,
#  'soso_Female_45': 60838,
#  'soso_Female_50': 57882,
#  'soso_Female_55': 52947,
#  'soso_Female_60': 45176,
#  'soso_Female_65': 43107,
#  'soso_Man_20': 50761,
# ...

# %%
bad_card_F_20_sectors_10 = bad_card_F_20[bad_card_F_20.MCT_CAT_CD == 10]
bad_card_F_20_sectors_20 = bad_card_F_20[bad_card_F_20.MCT_CAT_CD == 20]
bad_card_F_20_sectors_21 = bad_card_F_20[bad_card_F_20.MCT_CAT_CD == 21]
bad_card_F_20_sectors_22 = bad_card_F_20[bad_card_F_20.MCT_CAT_CD == 22]
bad_card_F_20_sectors_30 = bad_card_F_20[bad_card_F_20.MCT_CAT_CD == 30]
bad_card_F_20_sectors_31 = bad_card_F_20[bad_card_F_20.MCT_CAT_CD == 31]
bad_card_F_20_sectors_32 = bad_card_F_20[bad_card_F_20.MCT_CAT_CD == 32]
bad_card_F_20_sectors_33 = bad_card_F_20[bad_card_F_20.MCT_CAT_CD == 33]
bad_card_F_20_sectors_34 = bad_card_F_20[bad_card_F_20.MCT_CAT_CD == 34]
bad_card_F_20_sectors_35 = bad_card_F_20[bad_card_F_20.MCT_CAT_CD == 35]
bad_card_F_20_sectors_40 = bad_card_F_20[bad_card_F_20.MCT_CAT_CD == 40]
bad_card_F_20_sectors_42 = bad_card_F_20[bad_card_F_20.MCT_CAT_CD == 42]
bad_card_F_20_sectors_43 = bad_card_F_20[bad_card_F_20.MCT_CAT_CD == 43]
bad_card_F_20_sectors_44 = bad_card_F_20[bad_card_F_20.MCT_CAT_CD == 44]
bad_card_F_20_sectors_50 = bad_card_F_20[bad_card_F_20.MCT_CAT_CD == 50]
bad_card_F_20_sectors_52 = bad_card_F_20[bad_card_F_20.MCT_CAT_CD == 52]
bad_card_F_20_sectors_60 = bad_card_F_20[bad_card_F_20.MCT_CAT_CD == 60]
bad_card_F_20_sectors_62 = bad_card_F_20[bad_card_F_20.MCT_CAT_CD == 62]
bad_card_F_20_sectors_70 = bad_card_F_20[bad_card_F_20.MCT_CAT_CD == 70]
bad_card_F_20_sectors_71 = bad_card_F_20[bad_card_F_20.MCT_CAT_CD == 71]
bad_card_F_20_sectors_80 = bad_card_F_20[bad_card_F_20.MCT_CAT_CD == 80]
bad_card_F_20_sectors_81 = bad_card_F_20[bad_card_F_20.MCT_CAT_CD == 81]
bad_card_F_20_sectors_92 = bad_card_F_20[bad_card_F_20.MCT_CAT_CD == 92]

result['bad_Female_20_Sectors_10'] = len(bad_card_F_20_sectors_10.index)
result['bad_Female_20_Sectors_20'] = len(bad_card_F_20_sectors_20.index)
result['bad_Female_20_Sectors_21'] = len(bad_card_F_20_sectors_21.index)
result['bad_Female_20_Sectors_22'] = len(bad_card_F_20_sectors_22.index)
result['bad_Female_20_Sectors_30'] = len(bad_card_F_20_sectors_30.index)
result['bad_Female_20_Sectors_31'] = len(bad_card_F_20_sectors_31.index)
result['bad_Female_20_Sectors_32'] = len(bad_card_F_20_sectors_32.index)
result['bad_Female_20_Sectors_33'] = len(bad_card_F_20_sectors_33.index)
result['bad_Female_20_Sectors_34'] = len(bad_card_F_20_sectors_34.index)
result['bad_Female_20_Sectors_35'] = len(bad_card_F_20_sectors_35.index)
result['bad_Female_20_Sectors_40'] = len(bad_card_F_20_sectors_40.index)
result['bad_Female_20_Sectors_42'] = len(bad_card_F_20_sectors_42.index)
result['bad_Female_20_Sectors_43'] = len(bad_card_F_20_sectors_43.index)
result['bad_Female_20_Sectors_44'] = len(bad_card_F_20_sectors_44.index)
result['bad_Female_20_Sectors_50'] = len(bad_card_F_20_sectors_50.index)
result['bad_Female_20_Sectors_52'] = len(bad_card_F_20_sectors_52.index)
result['bad_Female_20_Sectors_60'] = len(bad_card_F_20_sectors_60.index)
result['bad_Female_20_Sectors_62'] = len(bad_card_F_20_sectors_62.index)
result['bad_Female_20_Sectors_70'] = len(bad_card_F_20_sectors_70.index)
result['bad_Female_20_Sectors_71'] = len(bad_card_F_20_sectors_71.index)
result['bad_Female_20_Sectors_80'] = len(bad_card_F_20_sectors_80.index)
result['bad_Female_20_Sectors_81'] = len(bad_card_F_20_sectors_81.index)
result['bad_Female_20_Sectors_92'] = len(bad_card_F_20_sectors_92.index)
bad_card_F_25_sectors_10 = bad_card_F_25[bad_card_F_25.MCT_CAT_CD == 10]
bad_card_F_25_sectors_20 = bad_card_F_25[bad_card_F_25.MCT_CAT_CD == 20]
bad_card_F_25_sectors_21 = bad_card_F_25[bad_card_F_25.MCT_CAT_CD == 21]
bad_card_F_25_sectors_22 = bad_card_F_25[bad_card_F_25.MCT_CAT_CD == 22]
bad_card_F_25_sectors_30 = bad_card_F_25[bad_card_F_25.MCT_CAT_CD == 30]
bad_card_F_25_sectors_31 = bad_card_F_25[bad_card_F_25.MCT_CAT_CD == 31]
bad_card_F_25_sectors_32 = bad_card_F_25[bad_card_F_25.MCT_CAT_CD == 32]
bad_card_F_25_sectors_33 = bad_card_F_25[bad_card_F_25.MCT_CAT_CD == 33]
bad_card_F_25_sectors_34 = bad_card_F_25[bad_card_F_25.MCT_CAT_CD == 34]
bad_card_F_25_sectors_35 = bad_card_F_25[bad_card_F_25.MCT_CAT_CD == 35]
bad_card_F_25_sectors_40 = bad_card_F_25[bad_card_F_25.MCT_CAT_CD == 40]
bad_card_F_25_sectors_42 = bad_card_F_25[bad_card_F_25.MCT_CAT_CD == 42]
bad_card_F_25_sectors_43 = bad_card_F_25[bad_card_F_25.MCT_CAT_CD == 43]
bad_card_F_25_sectors_44 = bad_card_F_25[bad_card_F_25.MCT_CAT_CD == 44]
bad_card_F_25_sectors_50 = bad_card_F_25[bad_card_F_25.MCT_CAT_CD == 50]
bad_card_F_25_sectors_52 = bad_card_F_25[bad_card_F_25.MCT_CAT_CD == 52]
bad_card_F_25_sectors_60 = bad_card_F_25[bad_card_F_25.MCT_CAT_CD == 60]
bad_card_F_25_sectors_62 = bad_card_F_25[bad_card_F_25.MCT_CAT_CD == 62]
bad_card_F_25_sectors_70 = bad_card_F_25[bad_card_F_25.MCT_CAT_CD == 70]
bad_card_F_25_sectors_71 = bad_card_F_25[bad_card_F_25.MCT_CAT_CD == 71]
bad_card_F_25_sectors_80 = bad_card_F_25[bad_card_F_25.MCT_CAT_CD == 80]
bad_card_F_25_sectors_81 = bad_card_F_25[bad_card_F_25.MCT_CAT_CD == 81]
bad_card_F_25_sectors_92 = bad_card_F_25[bad_card_F_25.MCT_CAT_CD == 92]

result['bad_Female_25_Sectors_10'] = len(bad_card_F_25_sectors_10.index)
result['bad_Female_25_Sectors_20'] = len(bad_card_F_25_sectors_20.index)
result['bad_Female_25_Sectors_21'] = len(bad_card_F_25_sectors_21.index)
result['bad_Female_25_Sectors_22'] = len(bad_card_F_25_sectors_22.index)
result['bad_Female_25_Sectors_30'] = len(bad_card_F_25_sectors_30.index)
result['bad_Female_25_Sectors_31'] = len(bad_card_F_25_sectors_31.index)
result['bad_Female_25_Sectors_32'] = len(bad_card_F_25_sectors_32.index)
result['bad_Female_25_Sectors_33'] = len(bad_card_F_25_sectors_33.index)
result['bad_Female_25_Sectors_34'] = len(bad_card_F_25_sectors_34.index)
result['bad_Female_25_Sectors_35'] = len(bad_card_F_25_sectors_35.index)
result['bad_Female_25_Sectors_40'] = len(bad_card_F_25_sectors_40.index)
result['bad_Female_25_Sectors_42'] = len(bad_card_F_25_sectors_42.index)
result['bad_Female_25_Sectors_43'] = len(bad_card_F_25_sectors_43.index)
result['bad_Female_25_Sectors_44'] = len(bad_card_F_25_sectors_44.index)
result['bad_Female_25_Sectors_50'] = len(bad_card_F_25_sectors_50.index)
result['bad_Female_25_Sectors_52'] = len(bad_card_F_25_sectors_52.index)
result['bad_Female_25_Sectors_60'] = len(bad_card_F_25_sectors_60.index)
result['bad_Female_25_Sectors_62'] = len(bad_card_F_25_sectors_62.index)
result['bad_Female_25_Sectors_70'] = len(bad_card_F_25_sectors_70.index)
result['bad_Female_25_Sectors_71'] = len(bad_card_F_25_sectors_71.index)
result['bad_Female_25_Sectors_80'] = len(bad_card_F_25_sectors_80.index)
result['bad_Female_25_Sectors_81'] = len(bad_card_F_25_sectors_81.index)
result['bad_Female_25_Sectors_92'] = len(bad_card_F_25_sectors_92.index)
bad_card_F_30_sectors_10 = bad_card_F_30[bad_card_F_30.MCT_CAT_CD == 10]
bad_card_F_30_sectors_20 = bad_card_F_30[bad_card_F_30.MCT_CAT_CD == 20]
bad_card_F_30_sectors_21 = bad_card_F_30[bad_card_F_30.MCT_CAT_CD == 21]
bad_card_F_30_sectors_22 = bad_card_F_30[bad_card_F_30.MCT_CAT_CD == 22]
bad_card_F_30_sectors_30 = bad_card_F_30[bad_card_F_30.MCT_CAT_CD == 30]
bad_card_F_30_sectors_31 = bad_card_F_30[bad_card_F_30.MCT_CAT_CD == 31]
bad_card_F_30_sectors_32 = bad_card_F_30[bad_card_F_30.MCT_CAT_CD == 32]
bad_card_F_30_sectors_33 = bad_card_F_30[bad_card_F_30.MCT_CAT_CD == 33]
bad_card_F_30_sectors_34 = bad_card_F_30[bad_card_F_30.MCT_CAT_CD == 34]
bad_card_F_30_sectors_35 = bad_card_F_30[bad_card_F_30.MCT_CAT_CD == 35]
bad_card_F_30_sectors_40 = bad_card_F_30[bad_card_F_30.MCT_CAT_CD == 40]
bad_card_F_30_sectors_42 = bad_card_F_30[bad_card_F_30.MCT_CAT_CD == 42]
bad_card_F_30_sectors_43 = bad_card_F_30[bad_card_F_30.MCT_CAT_CD == 43]
bad_card_F_30_sectors_44 = bad_card_F_30[bad_card_F_30.MCT_CAT_CD == 44]
bad_card_F_30_sectors_50 = bad_card_F_30[bad_card_F_30.MCT_CAT_CD == 50]
bad_card_F_30_sectors_52 = bad_card_F_30[bad_card_F_30.MCT_CAT_CD == 52]
bad_card_F_30_sectors_60 = bad_card_F_30[bad_card_F_30.MCT_CAT_CD == 60]
bad_card_F_30_sectors_62 = bad_card_F_30[bad_card_F_30.MCT_CAT_CD == 62]
bad_card_F_30_sectors_70 = bad_card_F_30[bad_card_F_30.MCT_CAT_CD == 70]
bad_card_F_30_sectors_71 = bad_card_F_30[bad_card_F_30.MCT_CAT_CD == 71]
bad_card_F_30_sectors_80 = bad_card_F_30[bad_card_F_30.MCT_CAT_CD == 80]
bad_card_F_30_sectors_81 = bad_card_F_30[bad_card_F_30.MCT_CAT_CD == 81]
bad_card_F_30_sectors_92 = bad_card_F_30[bad_card_F_30.MCT_CAT_CD == 92]

result['bad_Female_30_Sectors_10'] = len(bad_card_F_30_sectors_10.index)
result['bad_Female_30_Sectors_20'] = len(bad_card_F_30_sectors_20.index)
result['bad_Female_30_Sectors_21'] = len(bad_card_F_30_sectors_21.index)
result['bad_Female_30_Sectors_22'] = len(bad_card_F_30_sectors_22.index)
result['bad_Female_30_Sectors_30'] = len(bad_card_F_30_sectors_30.index)
result['bad_Female_30_Sectors_31'] = len(bad_card_F_30_sectors_31.index)
result['bad_Female_30_Sectors_32'] = len(bad_card_F_30_sectors_32.index)
result['bad_Female_30_Sectors_33'] = len(bad_card_F_30_sectors_33.index)
result['bad_Female_30_Sectors_34'] = len(bad_card_F_30_sectors_34.index)
result['bad_Female_30_Sectors_35'] = len(bad_card_F_30_sectors_35.index)
result['bad_Female_30_Sectors_40'] = len(bad_card_F_30_sectors_40.index)
result['bad_Female_30_Sectors_42'] = len(bad_card_F_30_sectors_42.index)
result['bad_Female_30_Sectors_43'] = len(bad_card_F_30_sectors_43.index)
result['bad_Female_30_Sectors_44'] = len(bad_card_F_30_sectors_44.index)
result['bad_Female_30_Sectors_50'] = len(bad_card_F_30_sectors_50.index)
result['bad_Female_30_Sectors_52'] = len(bad_card_F_30_sectors_52.index)
result['bad_Female_30_Sectors_60'] = len(bad_card_F_30_sectors_60.index)
result['bad_Female_30_Sectors_62'] = len(bad_card_F_30_sectors_62.index)
result['bad_Female_30_Sectors_70'] = len(bad_card_F_30_sectors_70.index)
result['bad_Female_30_Sectors_71'] = len(bad_card_F_30_sectors_71.index)
result['bad_Female_30_Sectors_80'] = len(bad_card_F_30_sectors_80.index)
result['bad_Female_30_Sectors_81'] = len(bad_card_F_30_sectors_81.index)
result['bad_Female_30_Sectors_92'] = len(bad_card_F_30_sectors_92.index)
bad_card_F_35_sectors_10 = bad_card_F_35[bad_card_F_35.MCT_CAT_CD == 10]
bad_card_F_35_sectors_20 = bad_card_F_35[bad_card_F_35.MCT_CAT_CD == 20]
bad_card_F_35_sectors_21 = bad_card_F_35[bad_card_F_35.MCT_CAT_CD == 21]
bad_card_F_35_sectors_22 = bad_card_F_35[bad_card_F_35.MCT_CAT_CD == 22]
bad_card_F_35_sectors_30 = bad_card_F_35[bad_card_F_35.MCT_CAT_CD == 30]
bad_card_F_35_sectors_31 = bad_card_F_35[bad_card_F_35.MCT_CAT_CD == 31]
bad_card_F_35_sectors_32 = bad_card_F_35[bad_card_F_35.MCT_CAT_CD == 32]
bad_card_F_35_sectors_33 = bad_card_F_35[bad_card_F_35.MCT_CAT_CD == 33]
bad_card_F_35_sectors_34 = bad_card_F_35[bad_card_F_35.MCT_CAT_CD == 34]
bad_card_F_35_sectors_35 = bad_card_F_35[bad_card_F_35.MCT_CAT_CD == 35]
bad_card_F_35_sectors_40 = bad_card_F_35[bad_card_F_35.MCT_CAT_CD == 40]
bad_card_F_35_sectors_42 = bad_card_F_35[bad_card_F_35.MCT_CAT_CD == 42]
bad_card_F_35_sectors_43 = bad_card_F_35[bad_card_F_35.MCT_CAT_CD == 43]
bad_card_F_35_sectors_44 = bad_card_F_35[bad_card_F_35.MCT_CAT_CD == 44]
bad_card_F_35_sectors_50 = bad_card_F_35[bad_card_F_35.MCT_CAT_CD == 50]
bad_card_F_35_sectors_52 = bad_card_F_35[bad_card_F_35.MCT_CAT_CD == 52]
bad_card_F_35_sectors_60 = bad_card_F_35[bad_card_F_35.MCT_CAT_CD == 60]
bad_card_F_35_sectors_62 = bad_card_F_35[bad_card_F_35.MCT_CAT_CD == 62]
bad_card_F_35_sectors_70 = bad_card_F_35[bad_card_F_35.MCT_CAT_CD == 70]
bad_card_F_35_sectors_71 = bad_card_F_35[bad_card_F_35.MCT_CAT_CD == 71]
bad_card_F_35_sectors_80 = bad_card_F_35[bad_card_F_35.MCT_CAT_CD == 80]
bad_card_F_35_sectors_81 = bad_card_F_35[bad_card_F_35.MCT_CAT_CD == 81]
bad_card_F_35_sectors_92 = bad_card_F_35[bad_card_F_35.MCT_CAT_CD == 92]

result['bad_Female_35_Sectors_10'] = len(bad_card_F_35_sectors_10.index)
result['bad_Female_35_Sectors_20'] = len(bad_card_F_35_sectors_20.index)
result['bad_Female_35_Sectors_21'] = len(bad_card_F_35_sectors_21.index)
result['bad_Female_35_Sectors_22'] = len(bad_card_F_35_sectors_22.index)
result['bad_Female_35_Sectors_30'] = len(bad_card_F_35_sectors_30.index)
result['bad_Female_35_Sectors_31'] = len(bad_card_F_35_sectors_31.index)
result['bad_Female_35_Sectors_32'] = len(bad_card_F_35_sectors_32.index)
result['bad_Female_35_Sectors_33'] = len(bad_card_F_35_sectors_33.index)
result['bad_Female_35_Sectors_34'] = len(bad_card_F_35_sectors_34.index)
result['bad_Female_35_Sectors_35'] = len(bad_card_F_35_sectors_35.index)
result['bad_Female_35_Sectors_40'] = len(bad_card_F_35_sectors_40.index)
result['bad_Female_35_Sectors_42'] = len(bad_card_F_35_sectors_42.index)
result['bad_Female_35_Sectors_43'] = len(bad_card_F_35_sectors_43.index)
result['bad_Female_35_Sectors_44'] = len(bad_card_F_35_sectors_44.index)
result['bad_Female_35_Sectors_50'] = len(bad_card_F_35_sectors_50.index)
result['bad_Female_35_Sectors_52'] = len(bad_card_F_35_sectors_52.index)
result['bad_Female_35_Sectors_60'] = len(bad_card_F_35_sectors_60.index)
result['bad_Female_35_Sectors_62'] = len(bad_card_F_35_sectors_62.index)
result['bad_Female_35_Sectors_70'] = len(bad_card_F_35_sectors_70.index)
result['bad_Female_35_Sectors_71'] = len(bad_card_F_35_sectors_71.index)
result['bad_Female_35_Sectors_80'] = len(bad_card_F_35_sectors_80.index)
result['bad_Female_35_Sectors_81'] = len(bad_card_F_35_sectors_81.index)
result['bad_Female_35_Sectors_92'] = len(bad_card_F_35_sectors_92.index)
bad_card_F_40_sectors_10 = bad_card_F_40[bad_card_F_40.MCT_CAT_CD == 10]
bad_card_F_40_sectors_20 = bad_card_F_40[bad_card_F_40.MCT_CAT_CD == 20]
bad_card_F_40_sectors_21 = bad_card_F_40[bad_card_F_40.MCT_CAT_CD == 21]
bad_card_F_40_sectors_22 = bad_card_F_40[bad_card_F_40.MCT_CAT_CD == 22]
bad_card_F_40_sectors_30 = bad_card_F_40[bad_card_F_40.MCT_CAT_CD == 30]
bad_card_F_40_sectors_31 = bad_card_F_40[bad_card_F_40.MCT_CAT_CD == 31]
bad_card_F_40_sectors_32 = bad_card_F_40[bad_card_F_40.MCT_CAT_CD == 32]
bad_card_F_40_sectors_33 = bad_card_F_40[bad_card_F_40.MCT_CAT_CD == 33]
bad_card_F_40_sectors_34 = bad_card_F_40[bad_card_F_40.MCT_CAT_CD == 34]
bad_card_F_40_sectors_35 = bad_card_F_40[bad_card_F_40.MCT_CAT_CD == 35]
bad_card_F_40_sectors_40 = bad_card_F_40[bad_card_F_40.MCT_CAT_CD == 40]
bad_card_F_40_sectors_42 = bad_card_F_40[bad_card_F_40.MCT_CAT_CD == 42]
bad_card_F_40_sectors_43 = bad_card_F_40[bad_card_F_40.MCT_CAT_CD == 43]
bad_card_F_40_sectors_44 = bad_card_F_40[bad_card_F_40.MCT_CAT_CD == 44]
bad_card_F_40_sectors_50 = bad_card_F_40[bad_card_F_40.MCT_CAT_CD == 50]
bad_card_F_40_sectors_52 = bad_card_F_40[bad_card_F_40.MCT_CAT_CD == 52]
bad_card_F_40_sectors_60 = bad_card_F_40[bad_card_F_40.MCT_CAT_CD == 60]
bad_card_F_40_sectors_62 = bad_card_F_40[bad_card_F_40.MCT_CAT_CD == 62]
bad_card_F_40_sectors_70 = bad_card_F_40[bad_card_F_40.MCT_CAT_CD == 70]
bad_card_F_40_sectors_71 = bad_card_F_40[bad_card_F_40.MCT_CAT_CD == 71]
bad_card_F_40_sectors_80 = bad_card_F_40[bad_card_F_40.MCT_CAT_CD == 80]
bad_card_F_40_sectors_81 = bad_card_F_40[bad_card_F_40.MCT_CAT_CD == 81]
bad_card_F_40_sectors_92 = bad_card_F_40[bad_card_F_40.MCT_CAT_CD == 92]

result['bad_Female_40_Sectors_10'] = len(bad_card_F_40_sectors_10.index)
result['bad_Female_40_Sectors_20'] = len(bad_card_F_40_sectors_20.index)
result['bad_Female_40_Sectors_21'] = len(bad_card_F_40_sectors_21.index)
result['bad_Female_40_Sectors_22'] = len(bad_card_F_40_sectors_22.index)
result['bad_Female_40_Sectors_30'] = len(bad_card_F_40_sectors_30.index)
result['bad_Female_40_Sectors_31'] = len(bad_card_F_40_sectors_31.index)
result['bad_Female_40_Sectors_32'] = len(bad_card_F_40_sectors_32.index)
result['bad_Female_40_Sectors_33'] = len(bad_card_F_40_sectors_33.index)
result['bad_Female_40_Sectors_34'] = len(bad_card_F_40_sectors_34.index)
result['bad_Female_40_Sectors_35'] = len(bad_card_F_40_sectors_35.index)
result['bad_Female_40_Sectors_40'] = len(bad_card_F_40_sectors_40.index)
result['bad_Female_40_Sectors_42'] = len(bad_card_F_40_sectors_42.index)
result['bad_Female_40_Sectors_43'] = len(bad_card_F_40_sectors_43.index)
result['bad_Female_40_Sectors_44'] = len(bad_card_F_40_sectors_44.index)
result['bad_Female_40_Sectors_50'] = len(bad_card_F_40_sectors_50.index)
result['bad_Female_40_Sectors_52'] = len(bad_card_F_40_sectors_52.index)
result['bad_Female_40_Sectors_60'] = len(bad_card_F_40_sectors_60.index)
result['bad_Female_40_Sectors_62'] = len(bad_card_F_40_sectors_62.index)
result['bad_Female_40_Sectors_70'] = len(bad_card_F_40_sectors_70.index)
result['bad_Female_40_Sectors_71'] = len(bad_card_F_40_sectors_71.index)
result['bad_Female_40_Sectors_80'] = len(bad_card_F_40_sectors_80.index)
result['bad_Female_40_Sectors_81'] = len(bad_card_F_40_sectors_81.index)
result['bad_Female_40_Sectors_92'] = len(bad_card_F_40_sectors_92.index)

bad_card_F_45_sectors_10 = bad_card_F_45[bad_card_F_45.MCT_CAT_CD == 10]
bad_card_F_45_sectors_20 = bad_card_F_45[bad_card_F_45.MCT_CAT_CD == 20]
bad_card_F_45_sectors_21 = bad_card_F_45[bad_card_F_45.MCT_CAT_CD == 21]
bad_card_F_45_sectors_22 = bad_card_F_45[bad_card_F_45.MCT_CAT_CD == 22]
bad_card_F_45_sectors_30 = bad_card_F_45[bad_card_F_45.MCT_CAT_CD == 30]
bad_card_F_45_sectors_31 = bad_card_F_45[bad_card_F_45.MCT_CAT_CD == 31]
bad_card_F_45_sectors_32 = bad_card_F_45[bad_card_F_45.MCT_CAT_CD == 32]
bad_card_F_45_sectors_33 = bad_card_F_45[bad_card_F_45.MCT_CAT_CD == 33]
bad_card_F_45_sectors_34 = bad_card_F_45[bad_card_F_45.MCT_CAT_CD == 34]
bad_card_F_45_sectors_35 = bad_card_F_45[bad_card_F_45.MCT_CAT_CD == 35]
bad_card_F_45_sectors_40 = bad_card_F_45[bad_card_F_45.MCT_CAT_CD == 40]
bad_card_F_45_sectors_42 = bad_card_F_45[bad_card_F_45.MCT_CAT_CD == 42]
bad_card_F_45_sectors_43 = bad_card_F_45[bad_card_F_45.MCT_CAT_CD == 43]
bad_card_F_45_sectors_44 = bad_card_F_45[bad_card_F_45.MCT_CAT_CD == 44]
bad_card_F_45_sectors_50 = bad_card_F_45[bad_card_F_45.MCT_CAT_CD == 50]
bad_card_F_45_sectors_52 = bad_card_F_45[bad_card_F_45.MCT_CAT_CD == 52]
bad_card_F_45_sectors_60 = bad_card_F_45[bad_card_F_45.MCT_CAT_CD == 60]
bad_card_F_45_sectors_62 = bad_card_F_45[bad_card_F_45.MCT_CAT_CD == 62]
bad_card_F_45_sectors_70 = bad_card_F_45[bad_card_F_45.MCT_CAT_CD == 70]
bad_card_F_45_sectors_71 = bad_card_F_45[bad_card_F_45.MCT_CAT_CD == 71]
bad_card_F_45_sectors_80 = bad_card_F_45[bad_card_F_45.MCT_CAT_CD == 80]
bad_card_F_45_sectors_81 = bad_card_F_45[bad_card_F_45.MCT_CAT_CD == 81]
bad_card_F_45_sectors_92 = bad_card_F_45[bad_card_F_45.MCT_CAT_CD == 92]

result['bad_Female_45_Sectors_10'] = len(bad_card_F_45_sectors_10.index)
result['bad_Female_45_Sectors_20'] = len(bad_card_F_45_sectors_20.index)
result['bad_Female_45_Sectors_21'] = len(bad_card_F_45_sectors_21.index)
result['bad_Female_45_Sectors_22'] = len(bad_card_F_45_sectors_22.index)
result['bad_Female_45_Sectors_30'] = len(bad_card_F_45_sectors_30.index)
result['bad_Female_45_Sectors_31'] = len(bad_card_F_45_sectors_31.index)
result['bad_Female_45_Sectors_32'] = len(bad_card_F_45_sectors_32.index)
result['bad_Female_45_Sectors_33'] = len(bad_card_F_45_sectors_33.index)
result['bad_Female_45_Sectors_34'] = len(bad_card_F_45_sectors_34.index)
result['bad_Female_45_Sectors_35'] = len(bad_card_F_45_sectors_35.index)
result['bad_Female_45_Sectors_40'] = len(bad_card_F_45_sectors_40.index)
result['bad_Female_45_Sectors_42'] = len(bad_card_F_45_sectors_42.index)
result['bad_Female_45_Sectors_43'] = len(bad_card_F_45_sectors_43.index)
result['bad_Female_45_Sectors_44'] = len(bad_card_F_45_sectors_44.index)
result['bad_Female_45_Sectors_50'] = len(bad_card_F_45_sectors_50.index)
result['bad_Female_45_Sectors_52'] = len(bad_card_F_45_sectors_52.index)
result['bad_Female_45_Sectors_60'] = len(bad_card_F_45_sectors_60.index)
result['bad_Female_45_Sectors_62'] = len(bad_card_F_45_sectors_62.index)
result['bad_Female_45_Sectors_70'] = len(bad_card_F_45_sectors_70.index)
result['bad_Female_45_Sectors_71'] = len(bad_card_F_45_sectors_71.index)
result['bad_Female_45_Sectors_80'] = len(bad_card_F_45_sectors_80.index)
result['bad_Female_45_Sectors_81'] = len(bad_card_F_45_sectors_81.index)
result['bad_Female_45_Sectors_92'] = len(bad_card_F_45_sectors_92.index)

bad_card_F_50_sectors_10 = bad_card_F_50[bad_card_F_50.MCT_CAT_CD == 10]
bad_card_F_50_sectors_20 = bad_card_F_50[bad_card_F_50.MCT_CAT_CD == 20]
bad_card_F_50_sectors_21 = bad_card_F_50[bad_card_F_50.MCT_CAT_CD == 21]
bad_card_F_50_sectors_22 = bad_card_F_50[bad_card_F_50.MCT_CAT_CD == 22]
bad_card_F_50_sectors_30 = bad_card_F_50[bad_card_F_50.MCT_CAT_CD == 30]
bad_card_F_50_sectors_31 = bad_card_F_50[bad_card_F_50.MCT_CAT_CD == 31]
bad_card_F_50_sectors_32 = bad_card_F_50[bad_card_F_50.MCT_CAT_CD == 32]
bad_card_F_50_sectors_33 = bad_card_F_50[bad_card_F_50.MCT_CAT_CD == 33]
bad_card_F_50_sectors_34 = bad_card_F_50[bad_card_F_50.MCT_CAT_CD == 34]
bad_card_F_50_sectors_35 = bad_card_F_50[bad_card_F_50.MCT_CAT_CD == 35]
bad_card_F_50_sectors_40 = bad_card_F_50[bad_card_F_50.MCT_CAT_CD == 40]
bad_card_F_50_sectors_42 = bad_card_F_50[bad_card_F_50.MCT_CAT_CD == 42]
bad_card_F_50_sectors_43 = bad_card_F_50[bad_card_F_50.MCT_CAT_CD == 43]
bad_card_F_50_sectors_44 = bad_card_F_50[bad_card_F_50.MCT_CAT_CD == 44]
bad_card_F_50_sectors_50 = bad_card_F_50[bad_card_F_50.MCT_CAT_CD == 50]
bad_card_F_50_sectors_52 = bad_card_F_50[bad_card_F_50.MCT_CAT_CD == 52]
bad_card_F_50_sectors_60 = bad_card_F_50[bad_card_F_50.MCT_CAT_CD == 60]
bad_card_F_50_sectors_62 = bad_card_F_50[bad_card_F_50.MCT_CAT_CD == 62]
bad_card_F_50_sectors_70 = bad_card_F_50[bad_card_F_50.MCT_CAT_CD == 70]
bad_card_F_50_sectors_71 = bad_card_F_50[bad_card_F_50.MCT_CAT_CD == 71]
bad_card_F_50_sectors_80 = bad_card_F_50[bad_card_F_50.MCT_CAT_CD == 80]
bad_card_F_50_sectors_81 = bad_card_F_50[bad_card_F_50.MCT_CAT_CD == 81]
bad_card_F_50_sectors_92 = bad_card_F_50[bad_card_F_50.MCT_CAT_CD == 92]

result['bad_Female_50_Sectors_10'] = len(bad_card_F_50_sectors_10.index)
result['bad_Female_50_Sectors_20'] = len(bad_card_F_50_sectors_20.index)
result['bad_Female_50_Sectors_21'] = len(bad_card_F_50_sectors_21.index)
result['bad_Female_50_Sectors_22'] = len(bad_card_F_50_sectors_22.index)
result['bad_Female_50_Sectors_30'] = len(bad_card_F_50_sectors_30.index)
result['bad_Female_50_Sectors_31'] = len(bad_card_F_50_sectors_31.index)
result['bad_Female_50_Sectors_32'] = len(bad_card_F_50_sectors_32.index)
result['bad_Female_50_Sectors_33'] = len(bad_card_F_50_sectors_33.index)
result['bad_Female_50_Sectors_34'] = len(bad_card_F_50_sectors_34.index)
result['bad_Female_50_Sectors_35'] = len(bad_card_F_50_sectors_35.index)
result['bad_Female_50_Sectors_40'] = len(bad_card_F_50_sectors_40.index)
result['bad_Female_50_Sectors_42'] = len(bad_card_F_50_sectors_42.index)
result['bad_Female_50_Sectors_43'] = len(bad_card_F_50_sectors_43.index)
result['bad_Female_50_Sectors_44'] = len(bad_card_F_50_sectors_44.index)
result['bad_Female_50_Sectors_50'] = len(bad_card_F_50_sectors_50.index)
result['bad_Female_50_Sectors_52'] = len(bad_card_F_50_sectors_52.index)
result['bad_Female_50_Sectors_60'] = len(bad_card_F_50_sectors_60.index)
result['bad_Female_50_Sectors_62'] = len(bad_card_F_50_sectors_62.index)
result['bad_Female_50_Sectors_70'] = len(bad_card_F_50_sectors_70.index)
result['bad_Female_50_Sectors_71'] = len(bad_card_F_50_sectors_71.index)
result['bad_Female_50_Sectors_80'] = len(bad_card_F_50_sectors_80.index)
result['bad_Female_50_Sectors_81'] = len(bad_card_F_50_sectors_81.index)
result['bad_Female_50_Sectors_92'] = len(bad_card_F_50_sectors_92.index)

bad_card_F_55_sectors_10 = bad_card_F_55[bad_card_F_55.MCT_CAT_CD == 10]
bad_card_F_55_sectors_20 = bad_card_F_55[bad_card_F_55.MCT_CAT_CD == 20]
bad_card_F_55_sectors_21 = bad_card_F_55[bad_card_F_55.MCT_CAT_CD == 21]
bad_card_F_55_sectors_22 = bad_card_F_55[bad_card_F_55.MCT_CAT_CD == 22]
bad_card_F_55_sectors_30 = bad_card_F_55[bad_card_F_55.MCT_CAT_CD == 30]
bad_card_F_55_sectors_31 = bad_card_F_55[bad_card_F_55.MCT_CAT_CD == 31]
bad_card_F_55_sectors_32 = bad_card_F_55[bad_card_F_55.MCT_CAT_CD == 32]
bad_card_F_55_sectors_33 = bad_card_F_55[bad_card_F_55.MCT_CAT_CD == 33]
bad_card_F_55_sectors_34 = bad_card_F_55[bad_card_F_55.MCT_CAT_CD == 34]
bad_card_F_55_sectors_35 = bad_card_F_55[bad_card_F_55.MCT_CAT_CD == 35]
bad_card_F_55_sectors_40 = bad_card_F_55[bad_card_F_55.MCT_CAT_CD == 40]
bad_card_F_55_sectors_42 = bad_card_F_55[bad_card_F_55.MCT_CAT_CD == 42]
bad_card_F_55_sectors_43 = bad_card_F_55[bad_card_F_55.MCT_CAT_CD == 43]
bad_card_F_55_sectors_44 = bad_card_F_55[bad_card_F_55.MCT_CAT_CD == 44]
bad_card_F_55_sectors_50 = bad_card_F_55[bad_card_F_55.MCT_CAT_CD == 50]
bad_card_F_55_sectors_52 = bad_card_F_55[bad_card_F_55.MCT_CAT_CD == 52]
bad_card_F_55_sectors_60 = bad_card_F_55[bad_card_F_55.MCT_CAT_CD == 60]
bad_card_F_55_sectors_62 = bad_card_F_55[bad_card_F_55.MCT_CAT_CD == 62]
bad_card_F_55_sectors_70 = bad_card_F_55[bad_card_F_55.MCT_CAT_CD == 70]
bad_card_F_55_sectors_71 = bad_card_F_55[bad_card_F_55.MCT_CAT_CD == 71]
bad_card_F_55_sectors_80 = bad_card_F_55[bad_card_F_55.MCT_CAT_CD == 80]
bad_card_F_55_sectors_81 = bad_card_F_55[bad_card_F_55.MCT_CAT_CD == 81]
bad_card_F_55_sectors_92 = bad_card_F_55[bad_card_F_55.MCT_CAT_CD == 92]

result['bad_Female_55_Sectors_10'] = len(bad_card_F_55_sectors_10.index)
result['bad_Female_55_Sectors_20'] = len(bad_card_F_55_sectors_20.index)
result['bad_Female_55_Sectors_21'] = len(bad_card_F_55_sectors_21.index)
result['bad_Female_55_Sectors_22'] = len(bad_card_F_55_sectors_22.index)
result['bad_Female_55_Sectors_30'] = len(bad_card_F_55_sectors_30.index)
result['bad_Female_55_Sectors_31'] = len(bad_card_F_55_sectors_31.index)
result['bad_Female_55_Sectors_32'] = len(bad_card_F_55_sectors_32.index)
result['bad_Female_55_Sectors_33'] = len(bad_card_F_55_sectors_33.index)
result['bad_Female_55_Sectors_34'] = len(bad_card_F_55_sectors_34.index)
result['bad_Female_55_Sectors_35'] = len(bad_card_F_55_sectors_35.index)
result['bad_Female_55_Sectors_40'] = len(bad_card_F_55_sectors_40.index)
result['bad_Female_55_Sectors_42'] = len(bad_card_F_55_sectors_42.index)
result['bad_Female_55_Sectors_43'] = len(bad_card_F_55_sectors_43.index)
result['bad_Female_55_Sectors_44'] = len(bad_card_F_55_sectors_44.index)
result['bad_Female_55_Sectors_50'] = len(bad_card_F_55_sectors_50.index)
result['bad_Female_55_Sectors_52'] = len(bad_card_F_55_sectors_52.index)
result['bad_Female_55_Sectors_60'] = len(bad_card_F_55_sectors_60.index)
result['bad_Female_55_Sectors_62'] = len(bad_card_F_55_sectors_62.index)
result['bad_Female_55_Sectors_70'] = len(bad_card_F_55_sectors_70.index)
result['bad_Female_55_Sectors_71'] = len(bad_card_F_55_sectors_71.index)
result['bad_Female_55_Sectors_80'] = len(bad_card_F_55_sectors_80.index)
result['bad_Female_55_Sectors_81'] = len(bad_card_F_55_sectors_81.index)
result['bad_Female_55_Sectors_92'] = len(bad_card_F_55_sectors_92.index)

bad_card_F_60_sectors_10 = bad_card_F_60[bad_card_F_60.MCT_CAT_CD == 10]
bad_card_F_60_sectors_20 = bad_card_F_60[bad_card_F_60.MCT_CAT_CD == 20]
bad_card_F_60_sectors_21 = bad_card_F_60[bad_card_F_60.MCT_CAT_CD == 21]
bad_card_F_60_sectors_22 = bad_card_F_60[bad_card_F_60.MCT_CAT_CD == 22]
bad_card_F_60_sectors_30 = bad_card_F_60[bad_card_F_60.MCT_CAT_CD == 30]
bad_card_F_60_sectors_31 = bad_card_F_60[bad_card_F_60.MCT_CAT_CD == 31]
bad_card_F_60_sectors_32 = bad_card_F_60[bad_card_F_60.MCT_CAT_CD == 32]
bad_card_F_60_sectors_33 = bad_card_F_60[bad_card_F_60.MCT_CAT_CD == 33]
bad_card_F_60_sectors_34 = bad_card_F_60[bad_card_F_60.MCT_CAT_CD == 34]
bad_card_F_60_sectors_35 = bad_card_F_60[bad_card_F_60.MCT_CAT_CD == 35]
bad_card_F_60_sectors_40 = bad_card_F_60[bad_card_F_60.MCT_CAT_CD == 40]
bad_card_F_60_sectors_42 = bad_card_F_60[bad_card_F_60.MCT_CAT_CD == 42]
bad_card_F_60_sectors_43 = bad_card_F_60[bad_card_F_60.MCT_CAT_CD == 43]
bad_card_F_60_sectors_44 = bad_card_F_60[bad_card_F_60.MCT_CAT_CD == 44]
bad_card_F_60_sectors_50 = bad_card_F_60[bad_card_F_60.MCT_CAT_CD == 50]
bad_card_F_60_sectors_52 = bad_card_F_60[bad_card_F_60.MCT_CAT_CD == 52]
bad_card_F_60_sectors_60 = bad_card_F_60[bad_card_F_60.MCT_CAT_CD == 60]
bad_card_F_60_sectors_62 = bad_card_F_60[bad_card_F_60.MCT_CAT_CD == 62]
bad_card_F_60_sectors_70 = bad_card_F_60[bad_card_F_60.MCT_CAT_CD == 70]
bad_card_F_60_sectors_71 = bad_card_F_60[bad_card_F_60.MCT_CAT_CD == 71]
bad_card_F_60_sectors_80 = bad_card_F_60[bad_card_F_60.MCT_CAT_CD == 80]
bad_card_F_60_sectors_81 = bad_card_F_60[bad_card_F_60.MCT_CAT_CD == 81]
bad_card_F_60_sectors_92 = bad_card_F_60[bad_card_F_60.MCT_CAT_CD == 92]

result['bad_Female_60_Sectors_10'] = len(bad_card_F_60_sectors_10.index)
result['bad_Female_60_Sectors_20'] = len(bad_card_F_60_sectors_20.index)
result['bad_Female_60_Sectors_21'] = len(bad_card_F_60_sectors_21.index)
result['bad_Female_60_Sectors_22'] = len(bad_card_F_60_sectors_22.index)
result['bad_Female_60_Sectors_30'] = len(bad_card_F_60_sectors_30.index)
result['bad_Female_60_Sectors_31'] = len(bad_card_F_60_sectors_31.index)
result['bad_Female_60_Sectors_32'] = len(bad_card_F_60_sectors_32.index)
result['bad_Female_60_Sectors_33'] = len(bad_card_F_60_sectors_33.index)
result['bad_Female_60_Sectors_34'] = len(bad_card_F_60_sectors_34.index)
result['bad_Female_60_Sectors_35'] = len(bad_card_F_60_sectors_35.index)
result['bad_Female_60_Sectors_40'] = len(bad_card_F_60_sectors_40.index)
result['bad_Female_60_Sectors_42'] = len(bad_card_F_60_sectors_42.index)
result['bad_Female_60_Sectors_43'] = len(bad_card_F_60_sectors_43.index)
result['bad_Female_60_Sectors_44'] = len(bad_card_F_60_sectors_44.index)
result['bad_Female_60_Sectors_50'] = len(bad_card_F_60_sectors_50.index)
result['bad_Female_60_Sectors_52'] = len(bad_card_F_60_sectors_52.index)
result['bad_Female_60_Sectors_60'] = len(bad_card_F_60_sectors_60.index)
result['bad_Female_60_Sectors_62'] = len(bad_card_F_60_sectors_62.index)
result['bad_Female_60_Sectors_70'] = len(bad_card_F_60_sectors_70.index)
result['bad_Female_60_Sectors_71'] = len(bad_card_F_60_sectors_71.index)
result['bad_Female_60_Sectors_80'] = len(bad_card_F_60_sectors_80.index)
result['bad_Female_60_Sectors_81'] = len(bad_card_F_60_sectors_81.index)
result['bad_Female_60_Sectors_92'] = len(bad_card_F_60_sectors_92.index)

bad_card_F_65_sectors_10 = bad_card_F_65[bad_card_F_65.MCT_CAT_CD == 10]
bad_card_F_65_sectors_20 = bad_card_F_65[bad_card_F_65.MCT_CAT_CD == 20]
bad_card_F_65_sectors_21 = bad_card_F_65[bad_card_F_65.MCT_CAT_CD == 21]
bad_card_F_65_sectors_22 = bad_card_F_65[bad_card_F_65.MCT_CAT_CD == 22]
bad_card_F_65_sectors_30 = bad_card_F_65[bad_card_F_65.MCT_CAT_CD == 30]
bad_card_F_65_sectors_31 = bad_card_F_65[bad_card_F_65.MCT_CAT_CD == 31]
bad_card_F_65_sectors_32 = bad_card_F_65[bad_card_F_65.MCT_CAT_CD == 32]
bad_card_F_65_sectors_33 = bad_card_F_65[bad_card_F_65.MCT_CAT_CD == 33]
bad_card_F_65_sectors_34 = bad_card_F_65[bad_card_F_65.MCT_CAT_CD == 34]
bad_card_F_65_sectors_35 = bad_card_F_65[bad_card_F_65.MCT_CAT_CD == 35]
bad_card_F_65_sectors_40 = bad_card_F_65[bad_card_F_65.MCT_CAT_CD == 40]
bad_card_F_65_sectors_42 = bad_card_F_65[bad_card_F_65.MCT_CAT_CD == 42]
bad_card_F_65_sectors_43 = bad_card_F_65[bad_card_F_65.MCT_CAT_CD == 43]
bad_card_F_65_sectors_44 = bad_card_F_65[bad_card_F_65.MCT_CAT_CD == 44]
bad_card_F_65_sectors_50 = bad_card_F_65[bad_card_F_65.MCT_CAT_CD == 50]
bad_card_F_65_sectors_52 = bad_card_F_65[bad_card_F_65.MCT_CAT_CD == 52]
bad_card_F_65_sectors_60 = bad_card_F_65[bad_card_F_65.MCT_CAT_CD == 60]
bad_card_F_65_sectors_62 = bad_card_F_65[bad_card_F_65.MCT_CAT_CD == 62]
bad_card_F_65_sectors_70 = bad_card_F_65[bad_card_F_65.MCT_CAT_CD == 70]
bad_card_F_65_sectors_71 = bad_card_F_65[bad_card_F_65.MCT_CAT_CD == 71]
bad_card_F_65_sectors_80 = bad_card_F_65[bad_card_F_65.MCT_CAT_CD == 80]
bad_card_F_65_sectors_81 = bad_card_F_65[bad_card_F_65.MCT_CAT_CD == 81]
bad_card_F_65_sectors_92 = bad_card_F_65[bad_card_F_65.MCT_CAT_CD == 92]

result['bad_Female_65_Sectors_10'] = len(bad_card_F_65_sectors_10.index)
result['bad_Female_65_Sectors_20'] = len(bad_card_F_65_sectors_20.index)
result['bad_Female_65_Sectors_21'] = len(bad_card_F_65_sectors_21.index)
result['bad_Female_65_Sectors_22'] = len(bad_card_F_65_sectors_22.index)
result['bad_Female_65_Sectors_30'] = len(bad_card_F_65_sectors_30.index)
result['bad_Female_65_Sectors_31'] = len(bad_card_F_65_sectors_31.index)
result['bad_Female_65_Sectors_32'] = len(bad_card_F_65_sectors_32.index)
result['bad_Female_65_Sectors_33'] = len(bad_card_F_65_sectors_33.index)
result['bad_Female_65_Sectors_34'] = len(bad_card_F_65_sectors_34.index)
result['bad_Female_65_Sectors_35'] = len(bad_card_F_65_sectors_35.index)
result['bad_Female_65_Sectors_40'] = len(bad_card_F_65_sectors_40.index)
result['bad_Female_65_Sectors_42'] = len(bad_card_F_65_sectors_42.index)
result['bad_Female_65_Sectors_43'] = len(bad_card_F_65_sectors_43.index)
result['bad_Female_65_Sectors_44'] = len(bad_card_F_65_sectors_44.index)
result['bad_Female_65_Sectors_50'] = len(bad_card_F_65_sectors_50.index)
result['bad_Female_65_Sectors_52'] = len(bad_card_F_65_sectors_52.index)
result['bad_Female_65_Sectors_60'] = len(bad_card_F_65_sectors_60.index)
result['bad_Female_65_Sectors_62'] = len(bad_card_F_65_sectors_62.index)
result['bad_Female_65_Sectors_70'] = len(bad_card_F_65_sectors_70.index)
result['bad_Female_65_Sectors_71'] = len(bad_card_F_65_sectors_71.index)
result['bad_Female_65_Sectors_80'] = len(bad_card_F_65_sectors_80.index)
result['bad_Female_65_Sectors_81'] = len(bad_card_F_65_sectors_81.index)
result['bad_Female_65_Sectors_92'] = len(bad_card_F_65_sectors_92.index)

# %%
soso_card_F_20_sectors_10 = soso_card_F_20[soso_card_F_20.MCT_CAT_CD == 10]
soso_card_F_20_sectors_20 = soso_card_F_20[soso_card_F_20.MCT_CAT_CD == 20]
soso_card_F_20_sectors_21 = soso_card_F_20[soso_card_F_20.MCT_CAT_CD == 21]
soso_card_F_20_sectors_22 = soso_card_F_20[soso_card_F_20.MCT_CAT_CD == 22]
soso_card_F_20_sectors_30 = soso_card_F_20[soso_card_F_20.MCT_CAT_CD == 30]
soso_card_F_20_sectors_31 = soso_card_F_20[soso_card_F_20.MCT_CAT_CD == 31]
soso_card_F_20_sectors_32 = soso_card_F_20[soso_card_F_20.MCT_CAT_CD == 32]
soso_card_F_20_sectors_33 = soso_card_F_20[soso_card_F_20.MCT_CAT_CD == 33]
soso_card_F_20_sectors_34 = soso_card_F_20[soso_card_F_20.MCT_CAT_CD == 34]
soso_card_F_20_sectors_35 = soso_card_F_20[soso_card_F_20.MCT_CAT_CD == 35]
soso_card_F_20_sectors_40 = soso_card_F_20[soso_card_F_20.MCT_CAT_CD == 40]
soso_card_F_20_sectors_42 = soso_card_F_20[soso_card_F_20.MCT_CAT_CD == 42]
soso_card_F_20_sectors_43 = soso_card_F_20[soso_card_F_20.MCT_CAT_CD == 43]
soso_card_F_20_sectors_44 = soso_card_F_20[soso_card_F_20.MCT_CAT_CD == 44]
soso_card_F_20_sectors_50 = soso_card_F_20[soso_card_F_20.MCT_CAT_CD == 50]
soso_card_F_20_sectors_52 = soso_card_F_20[soso_card_F_20.MCT_CAT_CD == 52]
soso_card_F_20_sectors_60 = soso_card_F_20[soso_card_F_20.MCT_CAT_CD == 60]
soso_card_F_20_sectors_62 = soso_card_F_20[soso_card_F_20.MCT_CAT_CD == 62]
soso_card_F_20_sectors_70 = soso_card_F_20[soso_card_F_20.MCT_CAT_CD == 70]
soso_card_F_20_sectors_71 = soso_card_F_20[soso_card_F_20.MCT_CAT_CD == 71]
soso_card_F_20_sectors_80 = soso_card_F_20[soso_card_F_20.MCT_CAT_CD == 80]
soso_card_F_20_sectors_81 = soso_card_F_20[soso_card_F_20.MCT_CAT_CD == 81]
soso_card_F_20_sectors_92 = soso_card_F_20[soso_card_F_20.MCT_CAT_CD == 92]

result['soso_Female_20_Sectors_10'] = len(soso_card_F_20_sectors_10.index)
result['soso_Female_20_Sectors_20'] = len(soso_card_F_20_sectors_20.index)
result['soso_Female_20_Sectors_21'] = len(soso_card_F_20_sectors_21.index)
result['soso_Female_20_Sectors_22'] = len(soso_card_F_20_sectors_22.index)
result['soso_Female_20_Sectors_30'] = len(soso_card_F_20_sectors_30.index)
result['soso_Female_20_Sectors_31'] = len(soso_card_F_20_sectors_31.index)
result['soso_Female_20_Sectors_32'] = len(soso_card_F_20_sectors_32.index)
result['soso_Female_20_Sectors_33'] = len(soso_card_F_20_sectors_33.index)
result['soso_Female_20_Sectors_34'] = len(soso_card_F_20_sectors_34.index)
result['soso_Female_20_Sectors_35'] = len(soso_card_F_20_sectors_35.index)
result['soso_Female_20_Sectors_40'] = len(soso_card_F_20_sectors_40.index)
result['soso_Female_20_Sectors_42'] = len(soso_card_F_20_sectors_42.index)
result['soso_Female_20_Sectors_43'] = len(soso_card_F_20_sectors_43.index)
result['soso_Female_20_Sectors_44'] = len(soso_card_F_20_sectors_44.index)
result['soso_Female_20_Sectors_50'] = len(soso_card_F_20_sectors_50.index)
result['soso_Female_20_Sectors_52'] = len(soso_card_F_20_sectors_52.index)
result['soso_Female_20_Sectors_60'] = len(soso_card_F_20_sectors_60.index)
result['soso_Female_20_Sectors_62'] = len(soso_card_F_20_sectors_62.index)
result['soso_Female_20_Sectors_70'] = len(soso_card_F_20_sectors_70.index)
result['soso_Female_20_Sectors_71'] = len(soso_card_F_20_sectors_71.index)
result['soso_Female_20_Sectors_80'] = len(soso_card_F_20_sectors_80.index)
result['soso_Female_20_Sectors_81'] = len(soso_card_F_20_sectors_81.index)
result['soso_Female_20_Sectors_92'] = len(soso_card_F_20_sectors_92.index)
soso_card_F_25_sectors_10 = soso_card_F_25[soso_card_F_25.MCT_CAT_CD == 10]
soso_card_F_25_sectors_20 = soso_card_F_25[soso_card_F_25.MCT_CAT_CD == 20]
soso_card_F_25_sectors_21 = soso_card_F_25[soso_card_F_25.MCT_CAT_CD == 21]
soso_card_F_25_sectors_22 = soso_card_F_25[soso_card_F_25.MCT_CAT_CD == 22]
soso_card_F_25_sectors_30 = soso_card_F_25[soso_card_F_25.MCT_CAT_CD == 30]
soso_card_F_25_sectors_31 = soso_card_F_25[soso_card_F_25.MCT_CAT_CD == 31]
soso_card_F_25_sectors_32 = soso_card_F_25[soso_card_F_25.MCT_CAT_CD == 32]
soso_card_F_25_sectors_33 = soso_card_F_25[soso_card_F_25.MCT_CAT_CD == 33]
soso_card_F_25_sectors_34 = soso_card_F_25[soso_card_F_25.MCT_CAT_CD == 34]
soso_card_F_25_sectors_35 = soso_card_F_25[soso_card_F_25.MCT_CAT_CD == 35]
soso_card_F_25_sectors_40 = soso_card_F_25[soso_card_F_25.MCT_CAT_CD == 40]
soso_card_F_25_sectors_42 = soso_card_F_25[soso_card_F_25.MCT_CAT_CD == 42]
soso_card_F_25_sectors_43 = soso_card_F_25[soso_card_F_25.MCT_CAT_CD == 43]
soso_card_F_25_sectors_44 = soso_card_F_25[soso_card_F_25.MCT_CAT_CD == 44]
soso_card_F_25_sectors_50 = soso_card_F_25[soso_card_F_25.MCT_CAT_CD == 50]
soso_card_F_25_sectors_52 = soso_card_F_25[soso_card_F_25.MCT_CAT_CD == 52]
soso_card_F_25_sectors_60 = soso_card_F_25[soso_card_F_25.MCT_CAT_CD == 60]
soso_card_F_25_sectors_62 = soso_card_F_25[soso_card_F_25.MCT_CAT_CD == 62]
soso_card_F_25_sectors_70 = soso_card_F_25[soso_card_F_25.MCT_CAT_CD == 70]
soso_card_F_25_sectors_71 = soso_card_F_25[soso_card_F_25.MCT_CAT_CD == 71]
soso_card_F_25_sectors_80 = soso_card_F_25[soso_card_F_25.MCT_CAT_CD == 80]
soso_card_F_25_sectors_81 = soso_card_F_25[soso_card_F_25.MCT_CAT_CD == 81]
soso_card_F_25_sectors_92 = soso_card_F_25[soso_card_F_25.MCT_CAT_CD == 92]

result['soso_Female_25_Sectors_10'] = len(soso_card_F_25_sectors_10.index)
result['soso_Female_25_Sectors_20'] = len(soso_card_F_25_sectors_20.index)
result['soso_Female_25_Sectors_21'] = len(soso_card_F_25_sectors_21.index)
result['soso_Female_25_Sectors_22'] = len(soso_card_F_25_sectors_22.index)
result['soso_Female_25_Sectors_30'] = len(soso_card_F_25_sectors_30.index)
result['soso_Female_25_Sectors_31'] = len(soso_card_F_25_sectors_31.index)
result['soso_Female_25_Sectors_32'] = len(soso_card_F_25_sectors_32.index)
result['soso_Female_25_Sectors_33'] = len(soso_card_F_25_sectors_33.index)
result['soso_Female_25_Sectors_34'] = len(soso_card_F_25_sectors_34.index)
result['soso_Female_25_Sectors_35'] = len(soso_card_F_25_sectors_35.index)
result['soso_Female_25_Sectors_40'] = len(soso_card_F_25_sectors_40.index)
result['soso_Female_25_Sectors_42'] = len(soso_card_F_25_sectors_42.index)
result['soso_Female_25_Sectors_43'] = len(soso_card_F_25_sectors_43.index)
result['soso_Female_25_Sectors_44'] = len(soso_card_F_25_sectors_44.index)
result['soso_Female_25_Sectors_50'] = len(soso_card_F_25_sectors_50.index)
result['soso_Female_25_Sectors_52'] = len(soso_card_F_25_sectors_52.index)
result['soso_Female_25_Sectors_60'] = len(soso_card_F_25_sectors_60.index)
result['soso_Female_25_Sectors_62'] = len(soso_card_F_25_sectors_62.index)
result['soso_Female_25_Sectors_70'] = len(soso_card_F_25_sectors_70.index)
result['soso_Female_25_Sectors_71'] = len(soso_card_F_25_sectors_71.index)
result['soso_Female_25_Sectors_80'] = len(soso_card_F_25_sectors_80.index)
result['soso_Female_25_Sectors_81'] = len(soso_card_F_25_sectors_81.index)
result['soso_Female_25_Sectors_92'] = len(soso_card_F_25_sectors_92.index)
soso_card_F_30_sectors_10 = soso_card_F_30[soso_card_F_30.MCT_CAT_CD == 10]
soso_card_F_30_sectors_20 = soso_card_F_30[soso_card_F_30.MCT_CAT_CD == 20]
soso_card_F_30_sectors_21 = soso_card_F_30[soso_card_F_30.MCT_CAT_CD == 21]
soso_card_F_30_sectors_22 = soso_card_F_30[soso_card_F_30.MCT_CAT_CD == 22]
soso_card_F_30_sectors_30 = soso_card_F_30[soso_card_F_30.MCT_CAT_CD == 30]
soso_card_F_30_sectors_31 = soso_card_F_30[soso_card_F_30.MCT_CAT_CD == 31]
soso_card_F_30_sectors_32 = soso_card_F_30[soso_card_F_30.MCT_CAT_CD == 32]
soso_card_F_30_sectors_33 = soso_card_F_30[soso_card_F_30.MCT_CAT_CD == 33]
soso_card_F_30_sectors_34 = soso_card_F_30[soso_card_F_30.MCT_CAT_CD == 34]
soso_card_F_30_sectors_35 = soso_card_F_30[soso_card_F_30.MCT_CAT_CD == 35]
soso_card_F_30_sectors_40 = soso_card_F_30[soso_card_F_30.MCT_CAT_CD == 40]
soso_card_F_30_sectors_42 = soso_card_F_30[soso_card_F_30.MCT_CAT_CD == 42]
soso_card_F_30_sectors_43 = soso_card_F_30[soso_card_F_30.MCT_CAT_CD == 43]
soso_card_F_30_sectors_44 = soso_card_F_30[soso_card_F_30.MCT_CAT_CD == 44]
soso_card_F_30_sectors_50 = soso_card_F_30[soso_card_F_30.MCT_CAT_CD == 50]
soso_card_F_30_sectors_52 = soso_card_F_30[soso_card_F_30.MCT_CAT_CD == 52]
soso_card_F_30_sectors_60 = soso_card_F_30[soso_card_F_30.MCT_CAT_CD == 60]
soso_card_F_30_sectors_62 = soso_card_F_30[soso_card_F_30.MCT_CAT_CD == 62]
soso_card_F_30_sectors_70 = soso_card_F_30[soso_card_F_30.MCT_CAT_CD == 70]
soso_card_F_30_sectors_71 = soso_card_F_30[soso_card_F_30.MCT_CAT_CD == 71]
soso_card_F_30_sectors_80 = soso_card_F_30[soso_card_F_30.MCT_CAT_CD == 80]
soso_card_F_30_sectors_81 = soso_card_F_30[soso_card_F_30.MCT_CAT_CD == 81]
soso_card_F_30_sectors_92 = soso_card_F_30[soso_card_F_30.MCT_CAT_CD == 92]

result['soso_Female_30_Sectors_10'] = len(soso_card_F_30_sectors_10.index)
result['soso_Female_30_Sectors_20'] = len(soso_card_F_30_sectors_20.index)
result['soso_Female_30_Sectors_21'] = len(soso_card_F_30_sectors_21.index)
result['soso_Female_30_Sectors_22'] = len(soso_card_F_30_sectors_22.index)
result['soso_Female_30_Sectors_30'] = len(soso_card_F_30_sectors_30.index)
result['soso_Female_30_Sectors_31'] = len(soso_card_F_30_sectors_31.index)
result['soso_Female_30_Sectors_32'] = len(soso_card_F_30_sectors_32.index)
result['soso_Female_30_Sectors_33'] = len(soso_card_F_30_sectors_33.index)
result['soso_Female_30_Sectors_34'] = len(soso_card_F_30_sectors_34.index)
result['soso_Female_30_Sectors_35'] = len(soso_card_F_30_sectors_35.index)
result['soso_Female_30_Sectors_40'] = len(soso_card_F_30_sectors_40.index)
result['soso_Female_30_Sectors_42'] = len(soso_card_F_30_sectors_42.index)
result['soso_Female_30_Sectors_43'] = len(soso_card_F_30_sectors_43.index)
result['soso_Female_30_Sectors_44'] = len(soso_card_F_30_sectors_44.index)
result['soso_Female_30_Sectors_50'] = len(soso_card_F_30_sectors_50.index)
result['soso_Female_30_Sectors_52'] = len(soso_card_F_30_sectors_52.index)
result['soso_Female_30_Sectors_60'] = len(soso_card_F_30_sectors_60.index)
result['soso_Female_30_Sectors_62'] = len(soso_card_F_30_sectors_62.index)
result['soso_Female_30_Sectors_70'] = len(soso_card_F_30_sectors_70.index)
result['soso_Female_30_Sectors_71'] = len(soso_card_F_30_sectors_71.index)
result['soso_Female_30_Sectors_80'] = len(soso_card_F_30_sectors_80.index)
result['soso_Female_30_Sectors_81'] = len(soso_card_F_30_sectors_81.index)
result['soso_Female_30_Sectors_92'] = len(soso_card_F_30_sectors_92.index)
soso_card_F_35_sectors_10 = soso_card_F_35[soso_card_F_35.MCT_CAT_CD == 10]
soso_card_F_35_sectors_20 = soso_card_F_35[soso_card_F_35.MCT_CAT_CD == 20]
soso_card_F_35_sectors_21 = soso_card_F_35[soso_card_F_35.MCT_CAT_CD == 21]
soso_card_F_35_sectors_22 = soso_card_F_35[soso_card_F_35.MCT_CAT_CD == 22]
soso_card_F_35_sectors_30 = soso_card_F_35[soso_card_F_35.MCT_CAT_CD == 30]
soso_card_F_35_sectors_31 = soso_card_F_35[soso_card_F_35.MCT_CAT_CD == 31]
soso_card_F_35_sectors_32 = soso_card_F_35[soso_card_F_35.MCT_CAT_CD == 32]
soso_card_F_35_sectors_33 = soso_card_F_35[soso_card_F_35.MCT_CAT_CD == 33]
soso_card_F_35_sectors_34 = soso_card_F_35[soso_card_F_35.MCT_CAT_CD == 34]
soso_card_F_35_sectors_35 = soso_card_F_35[soso_card_F_35.MCT_CAT_CD == 35]
soso_card_F_35_sectors_40 = soso_card_F_35[soso_card_F_35.MCT_CAT_CD == 40]
soso_card_F_35_sectors_42 = soso_card_F_35[soso_card_F_35.MCT_CAT_CD == 42]
soso_card_F_35_sectors_43 = soso_card_F_35[soso_card_F_35.MCT_CAT_CD == 43]
soso_card_F_35_sectors_44 = soso_card_F_35[soso_card_F_35.MCT_CAT_CD == 44]
soso_card_F_35_sectors_50 = soso_card_F_35[soso_card_F_35.MCT_CAT_CD == 50]
soso_card_F_35_sectors_52 = soso_card_F_35[soso_card_F_35.MCT_CAT_CD == 52]
soso_card_F_35_sectors_60 = soso_card_F_35[soso_card_F_35.MCT_CAT_CD == 60]
soso_card_F_35_sectors_62 = soso_card_F_35[soso_card_F_35.MCT_CAT_CD == 62]
soso_card_F_35_sectors_70 = soso_card_F_35[soso_card_F_35.MCT_CAT_CD == 70]
soso_card_F_35_sectors_71 = soso_card_F_35[soso_card_F_35.MCT_CAT_CD == 71]
soso_card_F_35_sectors_80 = soso_card_F_35[soso_card_F_35.MCT_CAT_CD == 80]
soso_card_F_35_sectors_81 = soso_card_F_35[soso_card_F_35.MCT_CAT_CD == 81]
soso_card_F_35_sectors_92 = soso_card_F_35[soso_card_F_35.MCT_CAT_CD == 92]

result['soso_Female_35_Sectors_10'] = len(soso_card_F_35_sectors_10.index)
result['soso_Female_35_Sectors_20'] = len(soso_card_F_35_sectors_20.index)
result['soso_Female_35_Sectors_21'] = len(soso_card_F_35_sectors_21.index)
result['soso_Female_35_Sectors_22'] = len(soso_card_F_35_sectors_22.index)
result['soso_Female_35_Sectors_30'] = len(soso_card_F_35_sectors_30.index)
result['soso_Female_35_Sectors_31'] = len(soso_card_F_35_sectors_31.index)
result['soso_Female_35_Sectors_32'] = len(soso_card_F_35_sectors_32.index)
result['soso_Female_35_Sectors_33'] = len(soso_card_F_35_sectors_33.index)
result['soso_Female_35_Sectors_34'] = len(soso_card_F_35_sectors_34.index)
result['soso_Female_35_Sectors_35'] = len(soso_card_F_35_sectors_35.index)
result['soso_Female_35_Sectors_40'] = len(soso_card_F_35_sectors_40.index)
result['soso_Female_35_Sectors_42'] = len(soso_card_F_35_sectors_42.index)
result['soso_Female_35_Sectors_43'] = len(soso_card_F_35_sectors_43.index)
result['soso_Female_35_Sectors_44'] = len(soso_card_F_35_sectors_44.index)
result['soso_Female_35_Sectors_50'] = len(soso_card_F_35_sectors_50.index)
result['soso_Female_35_Sectors_52'] = len(soso_card_F_35_sectors_52.index)
result['soso_Female_35_Sectors_60'] = len(soso_card_F_35_sectors_60.index)
result['soso_Female_35_Sectors_62'] = len(soso_card_F_35_sectors_62.index)
result['soso_Female_35_Sectors_70'] = len(soso_card_F_35_sectors_70.index)
result['soso_Female_35_Sectors_71'] = len(soso_card_F_35_sectors_71.index)
result['soso_Female_35_Sectors_80'] = len(soso_card_F_35_sectors_80.index)
result['soso_Female_35_Sectors_81'] = len(soso_card_F_35_sectors_81.index)
result['soso_Female_35_Sectors_92'] = len(soso_card_F_35_sectors_92.index)
soso_card_F_40_sectors_10 = soso_card_F_40[soso_card_F_40.MCT_CAT_CD == 10]
soso_card_F_40_sectors_20 = soso_card_F_40[soso_card_F_40.MCT_CAT_CD == 20]
soso_card_F_40_sectors_21 = soso_card_F_40[soso_card_F_40.MCT_CAT_CD == 21]
soso_card_F_40_sectors_22 = soso_card_F_40[soso_card_F_40.MCT_CAT_CD == 22]
soso_card_F_40_sectors_30 = soso_card_F_40[soso_card_F_40.MCT_CAT_CD == 30]
soso_card_F_40_sectors_31 = soso_card_F_40[soso_card_F_40.MCT_CAT_CD == 31]
soso_card_F_40_sectors_32 = soso_card_F_40[soso_card_F_40.MCT_CAT_CD == 32]
soso_card_F_40_sectors_33 = soso_card_F_40[soso_card_F_40.MCT_CAT_CD == 33]
soso_card_F_40_sectors_34 = soso_card_F_40[soso_card_F_40.MCT_CAT_CD == 34]
soso_card_F_40_sectors_35 = soso_card_F_40[soso_card_F_40.MCT_CAT_CD == 35]
soso_card_F_40_sectors_40 = soso_card_F_40[soso_card_F_40.MCT_CAT_CD == 40]
soso_card_F_40_sectors_42 = soso_card_F_40[soso_card_F_40.MCT_CAT_CD == 42]
soso_card_F_40_sectors_43 = soso_card_F_40[soso_card_F_40.MCT_CAT_CD == 43]
soso_card_F_40_sectors_44 = soso_card_F_40[soso_card_F_40.MCT_CAT_CD == 44]
soso_card_F_40_sectors_50 = soso_card_F_40[soso_card_F_40.MCT_CAT_CD == 50]
soso_card_F_40_sectors_52 = soso_card_F_40[soso_card_F_40.MCT_CAT_CD == 52]
soso_card_F_40_sectors_60 = soso_card_F_40[soso_card_F_40.MCT_CAT_CD == 60]
soso_card_F_40_sectors_62 = soso_card_F_40[soso_card_F_40.MCT_CAT_CD == 62]
soso_card_F_40_sectors_70 = soso_card_F_40[soso_card_F_40.MCT_CAT_CD == 70]
soso_card_F_40_sectors_71 = soso_card_F_40[soso_card_F_40.MCT_CAT_CD == 71]
soso_card_F_40_sectors_80 = soso_card_F_40[soso_card_F_40.MCT_CAT_CD == 80]
soso_card_F_40_sectors_81 = soso_card_F_40[soso_card_F_40.MCT_CAT_CD == 81]
soso_card_F_40_sectors_92 = soso_card_F_40[soso_card_F_40.MCT_CAT_CD == 92]

result['soso_Female_40_Sectors_10'] = len(soso_card_F_40_sectors_10.index)
result['soso_Female_40_Sectors_20'] = len(soso_card_F_40_sectors_20.index)
result['soso_Female_40_Sectors_21'] = len(soso_card_F_40_sectors_21.index)
result['soso_Female_40_Sectors_22'] = len(soso_card_F_40_sectors_22.index)
result['soso_Female_40_Sectors_30'] = len(soso_card_F_40_sectors_30.index)
result['soso_Female_40_Sectors_31'] = len(soso_card_F_40_sectors_31.index)
result['soso_Female_40_Sectors_32'] = len(soso_card_F_40_sectors_32.index)
result['soso_Female_40_Sectors_33'] = len(soso_card_F_40_sectors_33.index)
result['soso_Female_40_Sectors_34'] = len(soso_card_F_40_sectors_34.index)
result['soso_Female_40_Sectors_35'] = len(soso_card_F_40_sectors_35.index)
result['soso_Female_40_Sectors_40'] = len(soso_card_F_40_sectors_40.index)
result['soso_Female_40_Sectors_42'] = len(soso_card_F_40_sectors_42.index)
result['soso_Female_40_Sectors_43'] = len(soso_card_F_40_sectors_43.index)
result['soso_Female_40_Sectors_44'] = len(soso_card_F_40_sectors_44.index)
result['soso_Female_40_Sectors_50'] = len(soso_card_F_40_sectors_50.index)
result['soso_Female_40_Sectors_52'] = len(soso_card_F_40_sectors_52.index)
result['soso_Female_40_Sectors_60'] = len(soso_card_F_40_sectors_60.index)
result['soso_Female_40_Sectors_62'] = len(soso_card_F_40_sectors_62.index)
result['soso_Female_40_Sectors_70'] = len(soso_card_F_40_sectors_70.index)
result['soso_Female_40_Sectors_71'] = len(soso_card_F_40_sectors_71.index)
result['soso_Female_40_Sectors_80'] = len(soso_card_F_40_sectors_80.index)
result['soso_Female_40_Sectors_81'] = len(soso_card_F_40_sectors_81.index)
result['soso_Female_40_Sectors_92'] = len(soso_card_F_40_sectors_92.index)

soso_card_F_45_sectors_10 = soso_card_F_45[soso_card_F_45.MCT_CAT_CD == 10]
soso_card_F_45_sectors_20 = soso_card_F_45[soso_card_F_45.MCT_CAT_CD == 20]
soso_card_F_45_sectors_21 = soso_card_F_45[soso_card_F_45.MCT_CAT_CD == 21]
soso_card_F_45_sectors_22 = soso_card_F_45[soso_card_F_45.MCT_CAT_CD == 22]
soso_card_F_45_sectors_30 = soso_card_F_45[soso_card_F_45.MCT_CAT_CD == 30]
soso_card_F_45_sectors_31 = soso_card_F_45[soso_card_F_45.MCT_CAT_CD == 31]
soso_card_F_45_sectors_32 = soso_card_F_45[soso_card_F_45.MCT_CAT_CD == 32]
soso_card_F_45_sectors_33 = soso_card_F_45[soso_card_F_45.MCT_CAT_CD == 33]
soso_card_F_45_sectors_34 = soso_card_F_45[soso_card_F_45.MCT_CAT_CD == 34]
soso_card_F_45_sectors_35 = soso_card_F_45[soso_card_F_45.MCT_CAT_CD == 35]
soso_card_F_45_sectors_40 = soso_card_F_45[soso_card_F_45.MCT_CAT_CD == 40]
soso_card_F_45_sectors_42 = soso_card_F_45[soso_card_F_45.MCT_CAT_CD == 42]
soso_card_F_45_sectors_43 = soso_card_F_45[soso_card_F_45.MCT_CAT_CD == 43]
soso_card_F_45_sectors_44 = soso_card_F_45[soso_card_F_45.MCT_CAT_CD == 44]
soso_card_F_45_sectors_50 = soso_card_F_45[soso_card_F_45.MCT_CAT_CD == 50]
soso_card_F_45_sectors_52 = soso_card_F_45[soso_card_F_45.MCT_CAT_CD == 52]
soso_card_F_45_sectors_60 = soso_card_F_45[soso_card_F_45.MCT_CAT_CD == 60]
soso_card_F_45_sectors_62 = soso_card_F_45[soso_card_F_45.MCT_CAT_CD == 62]
soso_card_F_45_sectors_70 = soso_card_F_45[soso_card_F_45.MCT_CAT_CD == 70]
soso_card_F_45_sectors_71 = soso_card_F_45[soso_card_F_45.MCT_CAT_CD == 71]
soso_card_F_45_sectors_80 = soso_card_F_45[soso_card_F_45.MCT_CAT_CD == 80]
soso_card_F_45_sectors_81 = soso_card_F_45[soso_card_F_45.MCT_CAT_CD == 81]
soso_card_F_45_sectors_92 = soso_card_F_45[soso_card_F_45.MCT_CAT_CD == 92]

result['soso_Female_45_Sectors_10'] = len(soso_card_F_45_sectors_10.index)
result['soso_Female_45_Sectors_20'] = len(soso_card_F_45_sectors_20.index)
result['soso_Female_45_Sectors_21'] = len(soso_card_F_45_sectors_21.index)
result['soso_Female_45_Sectors_22'] = len(soso_card_F_45_sectors_22.index)
result['soso_Female_45_Sectors_30'] = len(soso_card_F_45_sectors_30.index)
result['soso_Female_45_Sectors_31'] = len(soso_card_F_45_sectors_31.index)
result['soso_Female_45_Sectors_32'] = len(soso_card_F_45_sectors_32.index)
result['soso_Female_45_Sectors_33'] = len(soso_card_F_45_sectors_33.index)
result['soso_Female_45_Sectors_34'] = len(soso_card_F_45_sectors_34.index)
result['soso_Female_45_Sectors_35'] = len(soso_card_F_45_sectors_35.index)
result['soso_Female_45_Sectors_40'] = len(soso_card_F_45_sectors_40.index)
result['soso_Female_45_Sectors_42'] = len(soso_card_F_45_sectors_42.index)
result['soso_Female_45_Sectors_43'] = len(soso_card_F_45_sectors_43.index)
result['soso_Female_45_Sectors_44'] = len(soso_card_F_45_sectors_44.index)
result['soso_Female_45_Sectors_50'] = len(soso_card_F_45_sectors_50.index)
result['soso_Female_45_Sectors_52'] = len(soso_card_F_45_sectors_52.index)
result['soso_Female_45_Sectors_60'] = len(soso_card_F_45_sectors_60.index)
result['soso_Female_45_Sectors_62'] = len(soso_card_F_45_sectors_62.index)
result['soso_Female_45_Sectors_70'] = len(soso_card_F_45_sectors_70.index)
result['soso_Female_45_Sectors_71'] = len(soso_card_F_45_sectors_71.index)
result['soso_Female_45_Sectors_80'] = len(soso_card_F_45_sectors_80.index)
result['soso_Female_45_Sectors_81'] = len(soso_card_F_45_sectors_81.index)
result['soso_Female_45_Sectors_92'] = len(soso_card_F_45_sectors_92.index)

soso_card_F_50_sectors_10 = soso_card_F_50[soso_card_F_50.MCT_CAT_CD == 10]
soso_card_F_50_sectors_20 = soso_card_F_50[soso_card_F_50.MCT_CAT_CD == 20]
soso_card_F_50_sectors_21 = soso_card_F_50[soso_card_F_50.MCT_CAT_CD == 21]
soso_card_F_50_sectors_22 = soso_card_F_50[soso_card_F_50.MCT_CAT_CD == 22]
soso_card_F_50_sectors_30 = soso_card_F_50[soso_card_F_50.MCT_CAT_CD == 30]
soso_card_F_50_sectors_31 = soso_card_F_50[soso_card_F_50.MCT_CAT_CD == 31]
soso_card_F_50_sectors_32 = soso_card_F_50[soso_card_F_50.MCT_CAT_CD == 32]
soso_card_F_50_sectors_33 = soso_card_F_50[soso_card_F_50.MCT_CAT_CD == 33]
soso_card_F_50_sectors_34 = soso_card_F_50[soso_card_F_50.MCT_CAT_CD == 34]
soso_card_F_50_sectors_35 = soso_card_F_50[soso_card_F_50.MCT_CAT_CD == 35]
soso_card_F_50_sectors_40 = soso_card_F_50[soso_card_F_50.MCT_CAT_CD == 40]
soso_card_F_50_sectors_42 = soso_card_F_50[soso_card_F_50.MCT_CAT_CD == 42]
soso_card_F_50_sectors_43 = soso_card_F_50[soso_card_F_50.MCT_CAT_CD == 43]
soso_card_F_50_sectors_44 = soso_card_F_50[soso_card_F_50.MCT_CAT_CD == 44]
soso_card_F_50_sectors_50 = soso_card_F_50[soso_card_F_50.MCT_CAT_CD == 50]
soso_card_F_50_sectors_52 = soso_card_F_50[soso_card_F_50.MCT_CAT_CD == 52]
soso_card_F_50_sectors_60 = soso_card_F_50[soso_card_F_50.MCT_CAT_CD == 60]
soso_card_F_50_sectors_62 = soso_card_F_50[soso_card_F_50.MCT_CAT_CD == 62]
soso_card_F_50_sectors_70 = soso_card_F_50[soso_card_F_50.MCT_CAT_CD == 70]
soso_card_F_50_sectors_71 = soso_card_F_50[soso_card_F_50.MCT_CAT_CD == 71]
soso_card_F_50_sectors_80 = soso_card_F_50[soso_card_F_50.MCT_CAT_CD == 80]
soso_card_F_50_sectors_81 = soso_card_F_50[soso_card_F_50.MCT_CAT_CD == 81]
soso_card_F_50_sectors_92 = soso_card_F_50[soso_card_F_50.MCT_CAT_CD == 92]

result['soso_Female_50_Sectors_10'] = len(soso_card_F_50_sectors_10.index)
result['soso_Female_50_Sectors_20'] = len(soso_card_F_50_sectors_20.index)
result['soso_Female_50_Sectors_21'] = len(soso_card_F_50_sectors_21.index)
result['soso_Female_50_Sectors_22'] = len(soso_card_F_50_sectors_22.index)
result['soso_Female_50_Sectors_30'] = len(soso_card_F_50_sectors_30.index)
result['soso_Female_50_Sectors_31'] = len(soso_card_F_50_sectors_31.index)
result['soso_Female_50_Sectors_32'] = len(soso_card_F_50_sectors_32.index)
result['soso_Female_50_Sectors_33'] = len(soso_card_F_50_sectors_33.index)
result['soso_Female_50_Sectors_34'] = len(soso_card_F_50_sectors_34.index)
result['soso_Female_50_Sectors_35'] = len(soso_card_F_50_sectors_35.index)
result['soso_Female_50_Sectors_40'] = len(soso_card_F_50_sectors_40.index)
result['soso_Female_50_Sectors_42'] = len(soso_card_F_50_sectors_42.index)
result['soso_Female_50_Sectors_43'] = len(soso_card_F_50_sectors_43.index)
result['soso_Female_50_Sectors_44'] = len(soso_card_F_50_sectors_44.index)
result['soso_Female_50_Sectors_50'] = len(soso_card_F_50_sectors_50.index)
result['soso_Female_50_Sectors_52'] = len(soso_card_F_50_sectors_52.index)
result['soso_Female_50_Sectors_60'] = len(soso_card_F_50_sectors_60.index)
result['soso_Female_50_Sectors_62'] = len(soso_card_F_50_sectors_62.index)
result['soso_Female_50_Sectors_70'] = len(soso_card_F_50_sectors_70.index)
result['soso_Female_50_Sectors_71'] = len(soso_card_F_50_sectors_71.index)
result['soso_Female_50_Sectors_80'] = len(soso_card_F_50_sectors_80.index)
result['soso_Female_50_Sectors_81'] = len(soso_card_F_50_sectors_81.index)
result['soso_Female_50_Sectors_92'] = len(soso_card_F_50_sectors_92.index)

soso_card_F_55_sectors_10 = soso_card_F_55[soso_card_F_55.MCT_CAT_CD == 10]
soso_card_F_55_sectors_20 = soso_card_F_55[soso_card_F_55.MCT_CAT_CD == 20]
soso_card_F_55_sectors_21 = soso_card_F_55[soso_card_F_55.MCT_CAT_CD == 21]
soso_card_F_55_sectors_22 = soso_card_F_55[soso_card_F_55.MCT_CAT_CD == 22]
soso_card_F_55_sectors_30 = soso_card_F_55[soso_card_F_55.MCT_CAT_CD == 30]
soso_card_F_55_sectors_31 = soso_card_F_55[soso_card_F_55.MCT_CAT_CD == 31]
soso_card_F_55_sectors_32 = soso_card_F_55[soso_card_F_55.MCT_CAT_CD == 32]
soso_card_F_55_sectors_33 = soso_card_F_55[soso_card_F_55.MCT_CAT_CD == 33]
soso_card_F_55_sectors_34 = soso_card_F_55[soso_card_F_55.MCT_CAT_CD == 34]
soso_card_F_55_sectors_35 = soso_card_F_55[soso_card_F_55.MCT_CAT_CD == 35]
soso_card_F_55_sectors_40 = soso_card_F_55[soso_card_F_55.MCT_CAT_CD == 40]
soso_card_F_55_sectors_42 = soso_card_F_55[soso_card_F_55.MCT_CAT_CD == 42]
soso_card_F_55_sectors_43 = soso_card_F_55[soso_card_F_55.MCT_CAT_CD == 43]
soso_card_F_55_sectors_44 = soso_card_F_55[soso_card_F_55.MCT_CAT_CD == 44]
soso_card_F_55_sectors_50 = soso_card_F_55[soso_card_F_55.MCT_CAT_CD == 50]
soso_card_F_55_sectors_52 = soso_card_F_55[soso_card_F_55.MCT_CAT_CD == 52]
soso_card_F_55_sectors_60 = soso_card_F_55[soso_card_F_55.MCT_CAT_CD == 60]
soso_card_F_55_sectors_62 = soso_card_F_55[soso_card_F_55.MCT_CAT_CD == 62]
soso_card_F_55_sectors_70 = soso_card_F_55[soso_card_F_55.MCT_CAT_CD == 70]
soso_card_F_55_sectors_71 = soso_card_F_55[soso_card_F_55.MCT_CAT_CD == 71]
soso_card_F_55_sectors_80 = soso_card_F_55[soso_card_F_55.MCT_CAT_CD == 80]
soso_card_F_55_sectors_81 = soso_card_F_55[soso_card_F_55.MCT_CAT_CD == 81]
soso_card_F_55_sectors_92 = soso_card_F_55[soso_card_F_55.MCT_CAT_CD == 92]

result['soso_Female_55_Sectors_10'] = len(soso_card_F_55_sectors_10.index)
result['soso_Female_55_Sectors_20'] = len(soso_card_F_55_sectors_20.index)
result['soso_Female_55_Sectors_21'] = len(soso_card_F_55_sectors_21.index)
result['soso_Female_55_Sectors_22'] = len(soso_card_F_55_sectors_22.index)
result['soso_Female_55_Sectors_30'] = len(soso_card_F_55_sectors_30.index)
result['soso_Female_55_Sectors_31'] = len(soso_card_F_55_sectors_31.index)
result['soso_Female_55_Sectors_32'] = len(soso_card_F_55_sectors_32.index)
result['soso_Female_55_Sectors_33'] = len(soso_card_F_55_sectors_33.index)
result['soso_Female_55_Sectors_34'] = len(soso_card_F_55_sectors_34.index)
result['soso_Female_55_Sectors_35'] = len(soso_card_F_55_sectors_35.index)
result['soso_Female_55_Sectors_40'] = len(soso_card_F_55_sectors_40.index)
result['soso_Female_55_Sectors_42'] = len(soso_card_F_55_sectors_42.index)
result['soso_Female_55_Sectors_43'] = len(soso_card_F_55_sectors_43.index)
result['soso_Female_55_Sectors_44'] = len(soso_card_F_55_sectors_44.index)
result['soso_Female_55_Sectors_50'] = len(soso_card_F_55_sectors_50.index)
result['soso_Female_55_Sectors_52'] = len(soso_card_F_55_sectors_52.index)
result['soso_Female_55_Sectors_60'] = len(soso_card_F_55_sectors_60.index)
result['soso_Female_55_Sectors_62'] = len(soso_card_F_55_sectors_62.index)
result['soso_Female_55_Sectors_70'] = len(soso_card_F_55_sectors_70.index)
result['soso_Female_55_Sectors_71'] = len(soso_card_F_55_sectors_71.index)
result['soso_Female_55_Sectors_80'] = len(soso_card_F_55_sectors_80.index)
result['soso_Female_55_Sectors_81'] = len(soso_card_F_55_sectors_81.index)
result['soso_Female_55_Sectors_92'] = len(soso_card_F_55_sectors_92.index)

soso_card_F_60_sectors_10 = soso_card_F_60[soso_card_F_60.MCT_CAT_CD == 10]
soso_card_F_60_sectors_20 = soso_card_F_60[soso_card_F_60.MCT_CAT_CD == 20]
soso_card_F_60_sectors_21 = soso_card_F_60[soso_card_F_60.MCT_CAT_CD == 21]
soso_card_F_60_sectors_22 = soso_card_F_60[soso_card_F_60.MCT_CAT_CD == 22]
soso_card_F_60_sectors_30 = soso_card_F_60[soso_card_F_60.MCT_CAT_CD == 30]
soso_card_F_60_sectors_31 = soso_card_F_60[soso_card_F_60.MCT_CAT_CD == 31]
soso_card_F_60_sectors_32 = soso_card_F_60[soso_card_F_60.MCT_CAT_CD == 32]
soso_card_F_60_sectors_33 = soso_card_F_60[soso_card_F_60.MCT_CAT_CD == 33]
soso_card_F_60_sectors_34 = soso_card_F_60[soso_card_F_60.MCT_CAT_CD == 34]
soso_card_F_60_sectors_35 = soso_card_F_60[soso_card_F_60.MCT_CAT_CD == 35]
soso_card_F_60_sectors_40 = soso_card_F_60[soso_card_F_60.MCT_CAT_CD == 40]
soso_card_F_60_sectors_42 = soso_card_F_60[soso_card_F_60.MCT_CAT_CD == 42]
soso_card_F_60_sectors_43 = soso_card_F_60[soso_card_F_60.MCT_CAT_CD == 43]
soso_card_F_60_sectors_44 = soso_card_F_60[soso_card_F_60.MCT_CAT_CD == 44]
soso_card_F_60_sectors_50 = soso_card_F_60[soso_card_F_60.MCT_CAT_CD == 50]
soso_card_F_60_sectors_52 = soso_card_F_60[soso_card_F_60.MCT_CAT_CD == 52]
soso_card_F_60_sectors_60 = soso_card_F_60[soso_card_F_60.MCT_CAT_CD == 60]
soso_card_F_60_sectors_62 = soso_card_F_60[soso_card_F_60.MCT_CAT_CD == 62]
soso_card_F_60_sectors_70 = soso_card_F_60[soso_card_F_60.MCT_CAT_CD == 70]
soso_card_F_60_sectors_71 = soso_card_F_60[soso_card_F_60.MCT_CAT_CD == 71]
soso_card_F_60_sectors_80 = soso_card_F_60[soso_card_F_60.MCT_CAT_CD == 80]
soso_card_F_60_sectors_81 = soso_card_F_60[soso_card_F_60.MCT_CAT_CD == 81]
soso_card_F_60_sectors_92 = soso_card_F_60[soso_card_F_60.MCT_CAT_CD == 92]

result['soso_Female_60_Sectors_10'] = len(soso_card_F_60_sectors_10.index)
result['soso_Female_60_Sectors_20'] = len(soso_card_F_60_sectors_20.index)
result['soso_Female_60_Sectors_21'] = len(soso_card_F_60_sectors_21.index)
result['soso_Female_60_Sectors_22'] = len(soso_card_F_60_sectors_22.index)
result['soso_Female_60_Sectors_30'] = len(soso_card_F_60_sectors_30.index)
result['soso_Female_60_Sectors_31'] = len(soso_card_F_60_sectors_31.index)
result['soso_Female_60_Sectors_32'] = len(soso_card_F_60_sectors_32.index)
result['soso_Female_60_Sectors_33'] = len(soso_card_F_60_sectors_33.index)
result['soso_Female_60_Sectors_34'] = len(soso_card_F_60_sectors_34.index)
result['soso_Female_60_Sectors_35'] = len(soso_card_F_60_sectors_35.index)
result['soso_Female_60_Sectors_40'] = len(soso_card_F_60_sectors_40.index)
result['soso_Female_60_Sectors_42'] = len(soso_card_F_60_sectors_42.index)
result['soso_Female_60_Sectors_43'] = len(soso_card_F_60_sectors_43.index)
result['soso_Female_60_Sectors_44'] = len(soso_card_F_60_sectors_44.index)
result['soso_Female_60_Sectors_50'] = len(soso_card_F_60_sectors_50.index)
result['soso_Female_60_Sectors_52'] = len(soso_card_F_60_sectors_52.index)
result['soso_Female_60_Sectors_60'] = len(soso_card_F_60_sectors_60.index)
result['soso_Female_60_Sectors_62'] = len(soso_card_F_60_sectors_62.index)
result['soso_Female_60_Sectors_70'] = len(soso_card_F_60_sectors_70.index)
result['soso_Female_60_Sectors_71'] = len(soso_card_F_60_sectors_71.index)
result['soso_Female_60_Sectors_80'] = len(soso_card_F_60_sectors_80.index)
result['soso_Female_60_Sectors_81'] = len(soso_card_F_60_sectors_81.index)
result['soso_Female_60_Sectors_92'] = len(soso_card_F_60_sectors_92.index)

soso_card_F_65_sectors_10 = soso_card_F_65[soso_card_F_65.MCT_CAT_CD == 10]
soso_card_F_65_sectors_20 = soso_card_F_65[soso_card_F_65.MCT_CAT_CD == 20]
soso_card_F_65_sectors_21 = soso_card_F_65[soso_card_F_65.MCT_CAT_CD == 21]
soso_card_F_65_sectors_22 = soso_card_F_65[soso_card_F_65.MCT_CAT_CD == 22]
soso_card_F_65_sectors_30 = soso_card_F_65[soso_card_F_65.MCT_CAT_CD == 30]
soso_card_F_65_sectors_31 = soso_card_F_65[soso_card_F_65.MCT_CAT_CD == 31]
soso_card_F_65_sectors_32 = soso_card_F_65[soso_card_F_65.MCT_CAT_CD == 32]
soso_card_F_65_sectors_33 = soso_card_F_65[soso_card_F_65.MCT_CAT_CD == 33]
soso_card_F_65_sectors_34 = soso_card_F_65[soso_card_F_65.MCT_CAT_CD == 34]
soso_card_F_65_sectors_35 = soso_card_F_65[soso_card_F_65.MCT_CAT_CD == 35]
soso_card_F_65_sectors_40 = soso_card_F_65[soso_card_F_65.MCT_CAT_CD == 40]
soso_card_F_65_sectors_42 = soso_card_F_65[soso_card_F_65.MCT_CAT_CD == 42]
soso_card_F_65_sectors_43 = soso_card_F_65[soso_card_F_65.MCT_CAT_CD == 43]
soso_card_F_65_sectors_44 = soso_card_F_65[soso_card_F_65.MCT_CAT_CD == 44]
soso_card_F_65_sectors_50 = soso_card_F_65[soso_card_F_65.MCT_CAT_CD == 50]
soso_card_F_65_sectors_52 = soso_card_F_65[soso_card_F_65.MCT_CAT_CD == 52]
soso_card_F_65_sectors_60 = soso_card_F_65[soso_card_F_65.MCT_CAT_CD == 60]
soso_card_F_65_sectors_62 = soso_card_F_65[soso_card_F_65.MCT_CAT_CD == 62]
soso_card_F_65_sectors_70 = soso_card_F_65[soso_card_F_65.MCT_CAT_CD == 70]
soso_card_F_65_sectors_71 = soso_card_F_65[soso_card_F_65.MCT_CAT_CD == 71]
soso_card_F_65_sectors_80 = soso_card_F_65[soso_card_F_65.MCT_CAT_CD == 80]
soso_card_F_65_sectors_81 = soso_card_F_65[soso_card_F_65.MCT_CAT_CD == 81]
soso_card_F_65_sectors_92 = soso_card_F_65[soso_card_F_65.MCT_CAT_CD == 92]

result['soso_Female_65_Sectors_10'] = len(soso_card_F_65_sectors_10.index)
result['soso_Female_65_Sectors_20'] = len(soso_card_F_65_sectors_20.index)
result['soso_Female_65_Sectors_21'] = len(soso_card_F_65_sectors_21.index)
result['soso_Female_65_Sectors_22'] = len(soso_card_F_65_sectors_22.index)
result['soso_Female_65_Sectors_30'] = len(soso_card_F_65_sectors_30.index)
result['soso_Female_65_Sectors_31'] = len(soso_card_F_65_sectors_31.index)
result['soso_Female_65_Sectors_32'] = len(soso_card_F_65_sectors_32.index)
result['soso_Female_65_Sectors_33'] = len(soso_card_F_65_sectors_33.index)
result['soso_Female_65_Sectors_34'] = len(soso_card_F_65_sectors_34.index)
result['soso_Female_65_Sectors_35'] = len(soso_card_F_65_sectors_35.index)
result['soso_Female_65_Sectors_40'] = len(soso_card_F_65_sectors_40.index)
result['soso_Female_65_Sectors_42'] = len(soso_card_F_65_sectors_42.index)
result['soso_Female_65_Sectors_43'] = len(soso_card_F_65_sectors_43.index)
result['soso_Female_65_Sectors_44'] = len(soso_card_F_65_sectors_44.index)
result['soso_Female_65_Sectors_50'] = len(soso_card_F_65_sectors_50.index)
result['soso_Female_65_Sectors_52'] = len(soso_card_F_65_sectors_52.index)
result['soso_Female_65_Sectors_60'] = len(soso_card_F_65_sectors_60.index)
result['soso_Female_65_Sectors_62'] = len(soso_card_F_65_sectors_62.index)
result['soso_Female_65_Sectors_70'] = len(soso_card_F_65_sectors_70.index)
result['soso_Female_65_Sectors_71'] = len(soso_card_F_65_sectors_71.index)
result['soso_Female_65_Sectors_80'] = len(soso_card_F_65_sectors_80.index)
result['soso_Female_65_Sectors_81'] = len(soso_card_F_65_sectors_81.index)
result['soso_Female_65_Sectors_92'] = len(soso_card_F_65_sectors_92.index)

# %%
soso_card_M_20_sectors_10 = soso_card_M_20[soso_card_M_20.MCT_CAT_CD == 10]
soso_card_M_20_sectors_20 = soso_card_M_20[soso_card_M_20.MCT_CAT_CD == 20]
soso_card_M_20_sectors_21 = soso_card_M_20[soso_card_M_20.MCT_CAT_CD == 21]
soso_card_M_20_sectors_22 = soso_card_M_20[soso_card_M_20.MCT_CAT_CD == 22]
soso_card_M_20_sectors_30 = soso_card_M_20[soso_card_M_20.MCT_CAT_CD == 30]
soso_card_M_20_sectors_31 = soso_card_M_20[soso_card_M_20.MCT_CAT_CD == 31]
soso_card_M_20_sectors_32 = soso_card_M_20[soso_card_M_20.MCT_CAT_CD == 32]
soso_card_M_20_sectors_33 = soso_card_M_20[soso_card_M_20.MCT_CAT_CD == 33]
soso_card_M_20_sectors_34 = soso_card_M_20[soso_card_M_20.MCT_CAT_CD == 34]
soso_card_M_20_sectors_35 = soso_card_M_20[soso_card_M_20.MCT_CAT_CD == 35]
soso_card_M_20_sectors_40 = soso_card_M_20[soso_card_M_20.MCT_CAT_CD == 40]
soso_card_M_20_sectors_42 = soso_card_M_20[soso_card_M_20.MCT_CAT_CD == 42]
soso_card_M_20_sectors_43 = soso_card_M_20[soso_card_M_20.MCT_CAT_CD == 43]
soso_card_M_20_sectors_44 = soso_card_M_20[soso_card_M_20.MCT_CAT_CD == 44]
soso_card_M_20_sectors_50 = soso_card_M_20[soso_card_M_20.MCT_CAT_CD == 50]
soso_card_M_20_sectors_52 = soso_card_M_20[soso_card_M_20.MCT_CAT_CD == 52]
soso_card_M_20_sectors_60 = soso_card_M_20[soso_card_M_20.MCT_CAT_CD == 60]
soso_card_M_20_sectors_62 = soso_card_M_20[soso_card_M_20.MCT_CAT_CD == 62]
soso_card_M_20_sectors_70 = soso_card_M_20[soso_card_M_20.MCT_CAT_CD == 70]
soso_card_M_20_sectors_71 = soso_card_M_20[soso_card_M_20.MCT_CAT_CD == 71]
soso_card_M_20_sectors_80 = soso_card_M_20[soso_card_M_20.MCT_CAT_CD == 80]
soso_card_M_20_sectors_81 = soso_card_M_20[soso_card_M_20.MCT_CAT_CD == 81]
soso_card_M_20_sectors_92 = soso_card_M_20[soso_card_M_20.MCT_CAT_CD == 92]

result['soso_Man_20_Sectors_10'] = len(soso_card_M_20_sectors_10.index)
result['soso_Man_20_Sectors_20'] = len(soso_card_M_20_sectors_20.index)
result['soso_Man_20_Sectors_21'] = len(soso_card_M_20_sectors_21.index)
result['soso_Man_20_Sectors_22'] = len(soso_card_M_20_sectors_22.index)
result['soso_Man_20_Sectors_30'] = len(soso_card_M_20_sectors_30.index)
result['soso_Man_20_Sectors_31'] = len(soso_card_M_20_sectors_31.index)
result['soso_Man_20_Sectors_32'] = len(soso_card_M_20_sectors_32.index)
result['soso_Man_20_Sectors_33'] = len(soso_card_M_20_sectors_33.index)
result['soso_Man_20_Sectors_34'] = len(soso_card_M_20_sectors_34.index)
result['soso_Man_20_Sectors_35'] = len(soso_card_M_20_sectors_35.index)
result['soso_Man_20_Sectors_40'] = len(soso_card_M_20_sectors_40.index)
result['soso_Man_20_Sectors_42'] = len(soso_card_M_20_sectors_42.index)
result['soso_Man_20_Sectors_43'] = len(soso_card_M_20_sectors_43.index)
result['soso_Man_20_Sectors_44'] = len(soso_card_M_20_sectors_44.index)
result['soso_Man_20_Sectors_50'] = len(soso_card_M_20_sectors_50.index)
result['soso_Man_20_Sectors_52'] = len(soso_card_M_20_sectors_52.index)
result['soso_Man_20_Sectors_60'] = len(soso_card_M_20_sectors_60.index)
result['soso_Man_20_Sectors_62'] = len(soso_card_M_20_sectors_62.index)
result['soso_Man_20_Sectors_70'] = len(soso_card_M_20_sectors_70.index)
result['soso_Man_20_Sectors_71'] = len(soso_card_M_20_sectors_71.index)
result['soso_Man_20_Sectors_80'] = len(soso_card_M_20_sectors_80.index)
result['soso_Man_20_Sectors_81'] = len(soso_card_M_20_sectors_81.index)
result['soso_Man_20_Sectors_92'] = len(soso_card_M_20_sectors_92.index)
soso_card_M_25_sectors_10 = soso_card_M_25[soso_card_M_25.MCT_CAT_CD == 10]
soso_card_M_25_sectors_20 = soso_card_M_25[soso_card_M_25.MCT_CAT_CD == 20]
soso_card_M_25_sectors_21 = soso_card_M_25[soso_card_M_25.MCT_CAT_CD == 21]
soso_card_M_25_sectors_22 = soso_card_M_25[soso_card_M_25.MCT_CAT_CD == 22]
soso_card_M_25_sectors_30 = soso_card_M_25[soso_card_M_25.MCT_CAT_CD == 30]
soso_card_M_25_sectors_31 = soso_card_M_25[soso_card_M_25.MCT_CAT_CD == 31]
soso_card_M_25_sectors_32 = soso_card_M_25[soso_card_M_25.MCT_CAT_CD == 32]
soso_card_M_25_sectors_33 = soso_card_M_25[soso_card_M_25.MCT_CAT_CD == 33]
soso_card_M_25_sectors_34 = soso_card_M_25[soso_card_M_25.MCT_CAT_CD == 34]
soso_card_M_25_sectors_35 = soso_card_M_25[soso_card_M_25.MCT_CAT_CD == 35]
soso_card_M_25_sectors_40 = soso_card_M_25[soso_card_M_25.MCT_CAT_CD == 40]
soso_card_M_25_sectors_42 = soso_card_M_25[soso_card_M_25.MCT_CAT_CD == 42]
soso_card_M_25_sectors_43 = soso_card_M_25[soso_card_M_25.MCT_CAT_CD == 43]
soso_card_M_25_sectors_44 = soso_card_M_25[soso_card_M_25.MCT_CAT_CD == 44]
soso_card_M_25_sectors_50 = soso_card_M_25[soso_card_M_25.MCT_CAT_CD == 50]
soso_card_M_25_sectors_52 = soso_card_M_25[soso_card_M_25.MCT_CAT_CD == 52]
soso_card_M_25_sectors_60 = soso_card_M_25[soso_card_M_25.MCT_CAT_CD == 60]
soso_card_M_25_sectors_62 = soso_card_M_25[soso_card_M_25.MCT_CAT_CD == 62]
soso_card_M_25_sectors_70 = soso_card_M_25[soso_card_M_25.MCT_CAT_CD == 70]
soso_card_M_25_sectors_71 = soso_card_M_25[soso_card_M_25.MCT_CAT_CD == 71]
soso_card_M_25_sectors_80 = soso_card_M_25[soso_card_M_25.MCT_CAT_CD == 80]
soso_card_M_25_sectors_81 = soso_card_M_25[soso_card_M_25.MCT_CAT_CD == 81]
soso_card_M_25_sectors_92 = soso_card_M_25[soso_card_M_25.MCT_CAT_CD == 92]

result['soso_Man_25_Sectors_10'] = len(soso_card_M_25_sectors_10.index)
result['soso_Man_25_Sectors_20'] = len(soso_card_M_25_sectors_20.index)
result['soso_Man_25_Sectors_21'] = len(soso_card_M_25_sectors_21.index)
result['soso_Man_25_Sectors_22'] = len(soso_card_M_25_sectors_22.index)
result['soso_Man_25_Sectors_30'] = len(soso_card_M_25_sectors_30.index)
result['soso_Man_25_Sectors_31'] = len(soso_card_M_25_sectors_31.index)
result['soso_Man_25_Sectors_32'] = len(soso_card_M_25_sectors_32.index)
result['soso_Man_25_Sectors_33'] = len(soso_card_M_25_sectors_33.index)
result['soso_Man_25_Sectors_34'] = len(soso_card_M_25_sectors_34.index)
result['soso_Man_25_Sectors_35'] = len(soso_card_M_25_sectors_35.index)
result['soso_Man_25_Sectors_40'] = len(soso_card_M_25_sectors_40.index)
result['soso_Man_25_Sectors_42'] = len(soso_card_M_25_sectors_42.index)
result['soso_Man_25_Sectors_43'] = len(soso_card_M_25_sectors_43.index)
result['soso_Man_25_Sectors_44'] = len(soso_card_M_25_sectors_44.index)
result['soso_Man_25_Sectors_50'] = len(soso_card_M_25_sectors_50.index)
result['soso_Man_25_Sectors_52'] = len(soso_card_M_25_sectors_52.index)
result['soso_Man_25_Sectors_60'] = len(soso_card_M_25_sectors_60.index)
result['soso_Man_25_Sectors_62'] = len(soso_card_M_25_sectors_62.index)
result['soso_Man_25_Sectors_70'] = len(soso_card_M_25_sectors_70.index)
result['soso_Man_25_Sectors_71'] = len(soso_card_M_25_sectors_71.index)
result['soso_Man_25_Sectors_80'] = len(soso_card_M_25_sectors_80.index)
result['soso_Man_25_Sectors_81'] = len(soso_card_M_25_sectors_81.index)
result['soso_Man_25_Sectors_92'] = len(soso_card_M_25_sectors_92.index)
soso_card_M_30_sectors_10 = soso_card_M_30[soso_card_M_30.MCT_CAT_CD == 10]
soso_card_M_30_sectors_20 = soso_card_M_30[soso_card_M_30.MCT_CAT_CD == 20]
soso_card_M_30_sectors_21 = soso_card_M_30[soso_card_M_30.MCT_CAT_CD == 21]
soso_card_M_30_sectors_22 = soso_card_M_30[soso_card_M_30.MCT_CAT_CD == 22]
soso_card_M_30_sectors_30 = soso_card_M_30[soso_card_M_30.MCT_CAT_CD == 30]
soso_card_M_30_sectors_31 = soso_card_M_30[soso_card_M_30.MCT_CAT_CD == 31]
soso_card_M_30_sectors_32 = soso_card_M_30[soso_card_M_30.MCT_CAT_CD == 32]
soso_card_M_30_sectors_33 = soso_card_M_30[soso_card_M_30.MCT_CAT_CD == 33]
soso_card_M_30_sectors_34 = soso_card_M_30[soso_card_M_30.MCT_CAT_CD == 34]
soso_card_M_30_sectors_35 = soso_card_M_30[soso_card_M_30.MCT_CAT_CD == 35]
soso_card_M_30_sectors_40 = soso_card_M_30[soso_card_M_30.MCT_CAT_CD == 40]
soso_card_M_30_sectors_42 = soso_card_M_30[soso_card_M_30.MCT_CAT_CD == 42]
soso_card_M_30_sectors_43 = soso_card_M_30[soso_card_M_30.MCT_CAT_CD == 43]
soso_card_M_30_sectors_44 = soso_card_M_30[soso_card_M_30.MCT_CAT_CD == 44]
soso_card_M_30_sectors_50 = soso_card_M_30[soso_card_M_30.MCT_CAT_CD == 50]
soso_card_M_30_sectors_52 = soso_card_M_30[soso_card_M_30.MCT_CAT_CD == 52]
soso_card_M_30_sectors_60 = soso_card_M_30[soso_card_M_30.MCT_CAT_CD == 60]
soso_card_M_30_sectors_62 = soso_card_M_30[soso_card_M_30.MCT_CAT_CD == 62]
soso_card_M_30_sectors_70 = soso_card_M_30[soso_card_M_30.MCT_CAT_CD == 70]
soso_card_M_30_sectors_71 = soso_card_M_30[soso_card_M_30.MCT_CAT_CD == 71]
soso_card_M_30_sectors_80 = soso_card_M_30[soso_card_M_30.MCT_CAT_CD == 80]
soso_card_M_30_sectors_81 = soso_card_M_30[soso_card_M_30.MCT_CAT_CD == 81]
soso_card_M_30_sectors_92 = soso_card_M_30[soso_card_M_30.MCT_CAT_CD == 92]

result['soso_Man_30_Sectors_10'] = len(soso_card_M_30_sectors_10.index)
result['soso_Man_30_Sectors_20'] = len(soso_card_M_30_sectors_20.index)
result['soso_Man_30_Sectors_21'] = len(soso_card_M_30_sectors_21.index)
result['soso_Man_30_Sectors_22'] = len(soso_card_M_30_sectors_22.index)
result['soso_Man_30_Sectors_30'] = len(soso_card_M_30_sectors_30.index)
result['soso_Man_30_Sectors_31'] = len(soso_card_M_30_sectors_31.index)
result['soso_Man_30_Sectors_32'] = len(soso_card_M_30_sectors_32.index)
result['soso_Man_30_Sectors_33'] = len(soso_card_M_30_sectors_33.index)
result['soso_Man_30_Sectors_34'] = len(soso_card_M_30_sectors_34.index)
result['soso_Man_30_Sectors_35'] = len(soso_card_M_30_sectors_35.index)
result['soso_Man_30_Sectors_40'] = len(soso_card_M_30_sectors_40.index)
result['soso_Man_30_Sectors_42'] = len(soso_card_M_30_sectors_42.index)
result['soso_Man_30_Sectors_43'] = len(soso_card_M_30_sectors_43.index)
result['soso_Man_30_Sectors_44'] = len(soso_card_M_30_sectors_44.index)
result['soso_Man_30_Sectors_50'] = len(soso_card_M_30_sectors_50.index)
result['soso_Man_30_Sectors_52'] = len(soso_card_M_30_sectors_52.index)
result['soso_Man_30_Sectors_60'] = len(soso_card_M_30_sectors_60.index)
result['soso_Man_30_Sectors_62'] = len(soso_card_M_30_sectors_62.index)
result['soso_Man_30_Sectors_70'] = len(soso_card_M_30_sectors_70.index)
result['soso_Man_30_Sectors_71'] = len(soso_card_M_30_sectors_71.index)
result['soso_Man_30_Sectors_80'] = len(soso_card_M_30_sectors_80.index)
result['soso_Man_30_Sectors_81'] = len(soso_card_M_30_sectors_81.index)
result['soso_Man_30_Sectors_92'] = len(soso_card_M_30_sectors_92.index)
soso_card_M_35_sectors_10 = soso_card_M_35[soso_card_M_35.MCT_CAT_CD == 10]
soso_card_M_35_sectors_20 = soso_card_M_35[soso_card_M_35.MCT_CAT_CD == 20]
soso_card_M_35_sectors_21 = soso_card_M_35[soso_card_M_35.MCT_CAT_CD == 21]
soso_card_M_35_sectors_22 = soso_card_M_35[soso_card_M_35.MCT_CAT_CD == 22]
soso_card_M_35_sectors_30 = soso_card_M_35[soso_card_M_35.MCT_CAT_CD == 30]
soso_card_M_35_sectors_31 = soso_card_M_35[soso_card_M_35.MCT_CAT_CD == 31]
soso_card_M_35_sectors_32 = soso_card_M_35[soso_card_M_35.MCT_CAT_CD == 32]
soso_card_M_35_sectors_33 = soso_card_M_35[soso_card_M_35.MCT_CAT_CD == 33]
soso_card_M_35_sectors_34 = soso_card_M_35[soso_card_M_35.MCT_CAT_CD == 34]
soso_card_M_35_sectors_35 = soso_card_M_35[soso_card_M_35.MCT_CAT_CD == 35]
soso_card_M_35_sectors_40 = soso_card_M_35[soso_card_M_35.MCT_CAT_CD == 40]
soso_card_M_35_sectors_42 = soso_card_M_35[soso_card_M_35.MCT_CAT_CD == 42]
soso_card_M_35_sectors_43 = soso_card_M_35[soso_card_M_35.MCT_CAT_CD == 43]
soso_card_M_35_sectors_44 = soso_card_M_35[soso_card_M_35.MCT_CAT_CD == 44]
soso_card_M_35_sectors_50 = soso_card_M_35[soso_card_M_35.MCT_CAT_CD == 50]
soso_card_M_35_sectors_52 = soso_card_M_35[soso_card_M_35.MCT_CAT_CD == 52]
soso_card_M_35_sectors_60 = soso_card_M_35[soso_card_M_35.MCT_CAT_CD == 60]
soso_card_M_35_sectors_62 = soso_card_M_35[soso_card_M_35.MCT_CAT_CD == 62]
soso_card_M_35_sectors_70 = soso_card_M_35[soso_card_M_35.MCT_CAT_CD == 70]
soso_card_M_35_sectors_71 = soso_card_M_35[soso_card_M_35.MCT_CAT_CD == 71]
soso_card_M_35_sectors_80 = soso_card_M_35[soso_card_M_35.MCT_CAT_CD == 80]
soso_card_M_35_sectors_81 = soso_card_M_35[soso_card_M_35.MCT_CAT_CD == 81]
soso_card_M_35_sectors_92 = soso_card_M_35[soso_card_M_35.MCT_CAT_CD == 92]

result['soso_Man_35_Sectors_10'] = len(soso_card_M_35_sectors_10.index)
result['soso_Man_35_Sectors_20'] = len(soso_card_M_35_sectors_20.index)
result['soso_Man_35_Sectors_21'] = len(soso_card_M_35_sectors_21.index)
result['soso_Man_35_Sectors_22'] = len(soso_card_M_35_sectors_22.index)
result['soso_Man_35_Sectors_30'] = len(soso_card_M_35_sectors_30.index)
result['soso_Man_35_Sectors_31'] = len(soso_card_M_35_sectors_31.index)
result['soso_Man_35_Sectors_32'] = len(soso_card_M_35_sectors_32.index)
result['soso_Man_35_Sectors_33'] = len(soso_card_M_35_sectors_33.index)
result['soso_Man_35_Sectors_34'] = len(soso_card_M_35_sectors_34.index)
result['soso_Man_35_Sectors_35'] = len(soso_card_M_35_sectors_35.index)
result['soso_Man_35_Sectors_40'] = len(soso_card_M_35_sectors_40.index)
result['soso_Man_35_Sectors_42'] = len(soso_card_M_35_sectors_42.index)
result['soso_Man_35_Sectors_43'] = len(soso_card_M_35_sectors_43.index)
result['soso_Man_35_Sectors_44'] = len(soso_card_M_35_sectors_44.index)
result['soso_Man_35_Sectors_50'] = len(soso_card_M_35_sectors_50.index)
result['soso_Man_35_Sectors_52'] = len(soso_card_M_35_sectors_52.index)
result['soso_Man_35_Sectors_60'] = len(soso_card_M_35_sectors_60.index)
result['soso_Man_35_Sectors_62'] = len(soso_card_M_35_sectors_62.index)
result['soso_Man_35_Sectors_70'] = len(soso_card_M_35_sectors_70.index)
result['soso_Man_35_Sectors_71'] = len(soso_card_M_35_sectors_71.index)
result['soso_Man_35_Sectors_80'] = len(soso_card_M_35_sectors_80.index)
result['soso_Man_35_Sectors_81'] = len(soso_card_M_35_sectors_81.index)
result['soso_Man_35_Sectors_92'] = len(soso_card_M_35_sectors_92.index)
soso_card_M_40_sectors_10 = soso_card_M_40[soso_card_M_40.MCT_CAT_CD == 10]
soso_card_M_40_sectors_20 = soso_card_M_40[soso_card_M_40.MCT_CAT_CD == 20]
soso_card_M_40_sectors_21 = soso_card_M_40[soso_card_M_40.MCT_CAT_CD == 21]
soso_card_M_40_sectors_22 = soso_card_M_40[soso_card_M_40.MCT_CAT_CD == 22]
soso_card_M_40_sectors_30 = soso_card_M_40[soso_card_M_40.MCT_CAT_CD == 30]
soso_card_M_40_sectors_31 = soso_card_M_40[soso_card_M_40.MCT_CAT_CD == 31]
soso_card_M_40_sectors_32 = soso_card_M_40[soso_card_M_40.MCT_CAT_CD == 32]
soso_card_M_40_sectors_33 = soso_card_M_40[soso_card_M_40.MCT_CAT_CD == 33]
soso_card_M_40_sectors_34 = soso_card_M_40[soso_card_M_40.MCT_CAT_CD == 34]
soso_card_M_40_sectors_35 = soso_card_M_40[soso_card_M_40.MCT_CAT_CD == 35]
soso_card_M_40_sectors_40 = soso_card_M_40[soso_card_M_40.MCT_CAT_CD == 40]
soso_card_M_40_sectors_42 = soso_card_M_40[soso_card_M_40.MCT_CAT_CD == 42]
soso_card_M_40_sectors_43 = soso_card_M_40[soso_card_M_40.MCT_CAT_CD == 43]
soso_card_M_40_sectors_44 = soso_card_M_40[soso_card_M_40.MCT_CAT_CD == 44]
soso_card_M_40_sectors_50 = soso_card_M_40[soso_card_M_40.MCT_CAT_CD == 50]
soso_card_M_40_sectors_52 = soso_card_M_40[soso_card_M_40.MCT_CAT_CD == 52]
soso_card_M_40_sectors_60 = soso_card_M_40[soso_card_M_40.MCT_CAT_CD == 60]
soso_card_M_40_sectors_62 = soso_card_M_40[soso_card_M_40.MCT_CAT_CD == 62]
soso_card_M_40_sectors_70 = soso_card_M_40[soso_card_M_40.MCT_CAT_CD == 70]
soso_card_M_40_sectors_71 = soso_card_M_40[soso_card_M_40.MCT_CAT_CD == 71]
soso_card_M_40_sectors_80 = soso_card_M_40[soso_card_M_40.MCT_CAT_CD == 80]
soso_card_M_40_sectors_81 = soso_card_M_40[soso_card_M_40.MCT_CAT_CD == 81]
soso_card_M_40_sectors_92 = soso_card_M_40[soso_card_M_40.MCT_CAT_CD == 92]

result['soso_Man_40_Sectors_10'] = len(soso_card_M_40_sectors_10.index)
result['soso_Man_40_Sectors_20'] = len(soso_card_M_40_sectors_20.index)
result['soso_Man_40_Sectors_21'] = len(soso_card_M_40_sectors_21.index)
result['soso_Man_40_Sectors_22'] = len(soso_card_M_40_sectors_22.index)
result['soso_Man_40_Sectors_30'] = len(soso_card_M_40_sectors_30.index)
result['soso_Man_40_Sectors_31'] = len(soso_card_M_40_sectors_31.index)
result['soso_Man_40_Sectors_32'] = len(soso_card_M_40_sectors_32.index)
result['soso_Man_40_Sectors_33'] = len(soso_card_M_40_sectors_33.index)
result['soso_Man_40_Sectors_34'] = len(soso_card_M_40_sectors_34.index)
result['soso_Man_40_Sectors_35'] = len(soso_card_M_40_sectors_35.index)
result['soso_Man_40_Sectors_40'] = len(soso_card_M_40_sectors_40.index)
result['soso_Man_40_Sectors_42'] = len(soso_card_M_40_sectors_42.index)
result['soso_Man_40_Sectors_43'] = len(soso_card_M_40_sectors_43.index)
result['soso_Man_40_Sectors_44'] = len(soso_card_M_40_sectors_44.index)
result['soso_Man_40_Sectors_50'] = len(soso_card_M_40_sectors_50.index)
result['soso_Man_40_Sectors_52'] = len(soso_card_M_40_sectors_52.index)
result['soso_Man_40_Sectors_60'] = len(soso_card_M_40_sectors_60.index)
result['soso_Man_40_Sectors_62'] = len(soso_card_M_40_sectors_62.index)
result['soso_Man_40_Sectors_70'] = len(soso_card_M_40_sectors_70.index)
result['soso_Man_40_Sectors_71'] = len(soso_card_M_40_sectors_71.index)
result['soso_Man_40_Sectors_80'] = len(soso_card_M_40_sectors_80.index)
result['soso_Man_40_Sectors_81'] = len(soso_card_M_40_sectors_81.index)
result['soso_Man_40_Sectors_92'] = len(soso_card_M_40_sectors_92.index)

soso_card_M_45_sectors_10 = soso_card_M_45[soso_card_M_45.MCT_CAT_CD == 10]
soso_card_M_45_sectors_20 = soso_card_M_45[soso_card_M_45.MCT_CAT_CD == 20]
soso_card_M_45_sectors_21 = soso_card_M_45[soso_card_M_45.MCT_CAT_CD == 21]
soso_card_M_45_sectors_22 = soso_card_M_45[soso_card_M_45.MCT_CAT_CD == 22]
soso_card_M_45_sectors_30 = soso_card_M_45[soso_card_M_45.MCT_CAT_CD == 30]
soso_card_M_45_sectors_31 = soso_card_M_45[soso_card_M_45.MCT_CAT_CD == 31]
soso_card_M_45_sectors_32 = soso_card_M_45[soso_card_M_45.MCT_CAT_CD == 32]
soso_card_M_45_sectors_33 = soso_card_M_45[soso_card_M_45.MCT_CAT_CD == 33]
soso_card_M_45_sectors_34 = soso_card_M_45[soso_card_M_45.MCT_CAT_CD == 34]
soso_card_M_45_sectors_35 = soso_card_M_45[soso_card_M_45.MCT_CAT_CD == 35]
soso_card_M_45_sectors_40 = soso_card_M_45[soso_card_M_45.MCT_CAT_CD == 40]
soso_card_M_45_sectors_42 = soso_card_M_45[soso_card_M_45.MCT_CAT_CD == 42]
soso_card_M_45_sectors_43 = soso_card_M_45[soso_card_M_45.MCT_CAT_CD == 43]
soso_card_M_45_sectors_44 = soso_card_M_45[soso_card_M_45.MCT_CAT_CD == 44]
soso_card_M_45_sectors_50 = soso_card_M_45[soso_card_M_45.MCT_CAT_CD == 50]
soso_card_M_45_sectors_52 = soso_card_M_45[soso_card_M_45.MCT_CAT_CD == 52]
soso_card_M_45_sectors_60 = soso_card_M_45[soso_card_M_45.MCT_CAT_CD == 60]
soso_card_M_45_sectors_62 = soso_card_M_45[soso_card_M_45.MCT_CAT_CD == 62]
soso_card_M_45_sectors_70 = soso_card_M_45[soso_card_M_45.MCT_CAT_CD == 70]
soso_card_M_45_sectors_71 = soso_card_M_45[soso_card_M_45.MCT_CAT_CD == 71]
soso_card_M_45_sectors_80 = soso_card_M_45[soso_card_M_45.MCT_CAT_CD == 80]
soso_card_M_45_sectors_81 = soso_card_M_45[soso_card_M_45.MCT_CAT_CD == 81]
soso_card_M_45_sectors_92 = soso_card_M_45[soso_card_M_45.MCT_CAT_CD == 92]

result['soso_Man_45_Sectors_10'] = len(soso_card_M_45_sectors_10.index)
result['soso_Man_45_Sectors_20'] = len(soso_card_M_45_sectors_20.index)
result['soso_Man_45_Sectors_21'] = len(soso_card_M_45_sectors_21.index)
result['soso_Man_45_Sectors_22'] = len(soso_card_M_45_sectors_22.index)
result['soso_Man_45_Sectors_30'] = len(soso_card_M_45_sectors_30.index)
result['soso_Man_45_Sectors_31'] = len(soso_card_M_45_sectors_31.index)
result['soso_Man_45_Sectors_32'] = len(soso_card_M_45_sectors_32.index)
result['soso_Man_45_Sectors_33'] = len(soso_card_M_45_sectors_33.index)
result['soso_Man_45_Sectors_34'] = len(soso_card_M_45_sectors_34.index)
result['soso_Man_45_Sectors_35'] = len(soso_card_M_45_sectors_35.index)
result['soso_Man_45_Sectors_40'] = len(soso_card_M_45_sectors_40.index)
result['soso_Man_45_Sectors_42'] = len(soso_card_M_45_sectors_42.index)
result['soso_Man_45_Sectors_43'] = len(soso_card_M_45_sectors_43.index)
result['soso_Man_45_Sectors_44'] = len(soso_card_M_45_sectors_44.index)
result['soso_Man_45_Sectors_50'] = len(soso_card_M_45_sectors_50.index)
result['soso_Man_45_Sectors_52'] = len(soso_card_M_45_sectors_52.index)
result['soso_Man_45_Sectors_60'] = len(soso_card_M_45_sectors_60.index)
result['soso_Man_45_Sectors_62'] = len(soso_card_M_45_sectors_62.index)
result['soso_Man_45_Sectors_70'] = len(soso_card_M_45_sectors_70.index)
result['soso_Man_45_Sectors_71'] = len(soso_card_M_45_sectors_71.index)
result['soso_Man_45_Sectors_80'] = len(soso_card_M_45_sectors_80.index)
result['soso_Man_45_Sectors_81'] = len(soso_card_M_45_sectors_81.index)
result['soso_Man_45_Sectors_92'] = len(soso_card_M_45_sectors_92.index)

soso_card_M_50_sectors_10 = soso_card_M_50[soso_card_M_50.MCT_CAT_CD == 10]
soso_card_M_50_sectors_20 = soso_card_M_50[soso_card_M_50.MCT_CAT_CD == 20]
soso_card_M_50_sectors_21 = soso_card_M_50[soso_card_M_50.MCT_CAT_CD == 21]
soso_card_M_50_sectors_22 = soso_card_M_50[soso_card_M_50.MCT_CAT_CD == 22]
soso_card_M_50_sectors_30 = soso_card_M_50[soso_card_M_50.MCT_CAT_CD == 30]
soso_card_M_50_sectors_31 = soso_card_M_50[soso_card_M_50.MCT_CAT_CD == 31]
soso_card_M_50_sectors_32 = soso_card_M_50[soso_card_M_50.MCT_CAT_CD == 32]
soso_card_M_50_sectors_33 = soso_card_M_50[soso_card_M_50.MCT_CAT_CD == 33]
soso_card_M_50_sectors_34 = soso_card_M_50[soso_card_M_50.MCT_CAT_CD == 34]
soso_card_M_50_sectors_35 = soso_card_M_50[soso_card_M_50.MCT_CAT_CD == 35]
soso_card_M_50_sectors_40 = soso_card_M_50[soso_card_M_50.MCT_CAT_CD == 40]
soso_card_M_50_sectors_42 = soso_card_M_50[soso_card_M_50.MCT_CAT_CD == 42]
soso_card_M_50_sectors_43 = soso_card_M_50[soso_card_M_50.MCT_CAT_CD == 43]
soso_card_M_50_sectors_44 = soso_card_M_50[soso_card_M_50.MCT_CAT_CD == 44]
soso_card_M_50_sectors_50 = soso_card_M_50[soso_card_M_50.MCT_CAT_CD == 50]
soso_card_M_50_sectors_52 = soso_card_M_50[soso_card_M_50.MCT_CAT_CD == 52]
soso_card_M_50_sectors_60 = soso_card_M_50[soso_card_M_50.MCT_CAT_CD == 60]
soso_card_M_50_sectors_62 = soso_card_M_50[soso_card_M_50.MCT_CAT_CD == 62]
soso_card_M_50_sectors_70 = soso_card_M_50[soso_card_M_50.MCT_CAT_CD == 70]
soso_card_M_50_sectors_71 = soso_card_M_50[soso_card_M_50.MCT_CAT_CD == 71]
soso_card_M_50_sectors_80 = soso_card_M_50[soso_card_M_50.MCT_CAT_CD == 80]
soso_card_M_50_sectors_81 = soso_card_M_50[soso_card_M_50.MCT_CAT_CD == 81]
soso_card_M_50_sectors_92 = soso_card_M_50[soso_card_M_50.MCT_CAT_CD == 92]

result['soso_Man_50_Sectors_10'] = len(soso_card_M_50_sectors_10.index)
result['soso_Man_50_Sectors_20'] = len(soso_card_M_50_sectors_20.index)
result['soso_Man_50_Sectors_21'] = len(soso_card_M_50_sectors_21.index)
result['soso_Man_50_Sectors_22'] = len(soso_card_M_50_sectors_22.index)
result['soso_Man_50_Sectors_30'] = len(soso_card_M_50_sectors_30.index)
result['soso_Man_50_Sectors_31'] = len(soso_card_M_50_sectors_31.index)
result['soso_Man_50_Sectors_32'] = len(soso_card_M_50_sectors_32.index)
result['soso_Man_50_Sectors_33'] = len(soso_card_M_50_sectors_33.index)
result['soso_Man_50_Sectors_34'] = len(soso_card_M_50_sectors_34.index)
result['soso_Man_50_Sectors_35'] = len(soso_card_M_50_sectors_35.index)
result['soso_Man_50_Sectors_40'] = len(soso_card_M_50_sectors_40.index)
result['soso_Man_50_Sectors_42'] = len(soso_card_M_50_sectors_42.index)
result['soso_Man_50_Sectors_43'] = len(soso_card_M_50_sectors_43.index)
result['soso_Man_50_Sectors_44'] = len(soso_card_M_50_sectors_44.index)
result['soso_Man_50_Sectors_50'] = len(soso_card_M_50_sectors_50.index)
result['soso_Man_50_Sectors_52'] = len(soso_card_M_50_sectors_52.index)
result['soso_Man_50_Sectors_60'] = len(soso_card_M_50_sectors_60.index)
result['soso_Man_50_Sectors_62'] = len(soso_card_M_50_sectors_62.index)
result['soso_Man_50_Sectors_70'] = len(soso_card_M_50_sectors_70.index)
result['soso_Man_50_Sectors_71'] = len(soso_card_M_50_sectors_71.index)
result['soso_Man_50_Sectors_80'] = len(soso_card_M_50_sectors_80.index)
result['soso_Man_50_Sectors_81'] = len(soso_card_M_50_sectors_81.index)
result['soso_Man_50_Sectors_92'] = len(soso_card_M_50_sectors_92.index)

soso_card_M_55_sectors_10 = soso_card_M_55[soso_card_M_55.MCT_CAT_CD == 10]
soso_card_M_55_sectors_20 = soso_card_M_55[soso_card_M_55.MCT_CAT_CD == 20]
soso_card_M_55_sectors_21 = soso_card_M_55[soso_card_M_55.MCT_CAT_CD == 21]
soso_card_M_55_sectors_22 = soso_card_M_55[soso_card_M_55.MCT_CAT_CD == 22]
soso_card_M_55_sectors_30 = soso_card_M_55[soso_card_M_55.MCT_CAT_CD == 30]
soso_card_M_55_sectors_31 = soso_card_M_55[soso_card_M_55.MCT_CAT_CD == 31]
soso_card_M_55_sectors_32 = soso_card_M_55[soso_card_M_55.MCT_CAT_CD == 32]
soso_card_M_55_sectors_33 = soso_card_M_55[soso_card_M_55.MCT_CAT_CD == 33]
soso_card_M_55_sectors_34 = soso_card_M_55[soso_card_M_55.MCT_CAT_CD == 34]
soso_card_M_55_sectors_35 = soso_card_M_55[soso_card_M_55.MCT_CAT_CD == 35]
soso_card_M_55_sectors_40 = soso_card_M_55[soso_card_M_55.MCT_CAT_CD == 40]
soso_card_M_55_sectors_42 = soso_card_M_55[soso_card_M_55.MCT_CAT_CD == 42]
soso_card_M_55_sectors_43 = soso_card_M_55[soso_card_M_55.MCT_CAT_CD == 43]
soso_card_M_55_sectors_44 = soso_card_M_55[soso_card_M_55.MCT_CAT_CD == 44]
soso_card_M_55_sectors_50 = soso_card_M_55[soso_card_M_55.MCT_CAT_CD == 50]
soso_card_M_55_sectors_52 = soso_card_M_55[soso_card_M_55.MCT_CAT_CD == 52]
soso_card_M_55_sectors_60 = soso_card_M_55[soso_card_M_55.MCT_CAT_CD == 60]
soso_card_M_55_sectors_62 = soso_card_M_55[soso_card_M_55.MCT_CAT_CD == 62]
soso_card_M_55_sectors_70 = soso_card_M_55[soso_card_M_55.MCT_CAT_CD == 70]
soso_card_M_55_sectors_71 = soso_card_M_55[soso_card_M_55.MCT_CAT_CD == 71]
soso_card_M_55_sectors_80 = soso_card_M_55[soso_card_M_55.MCT_CAT_CD == 80]
soso_card_M_55_sectors_81 = soso_card_M_55[soso_card_M_55.MCT_CAT_CD == 81]
soso_card_M_55_sectors_92 = soso_card_M_55[soso_card_M_55.MCT_CAT_CD == 92]

result['soso_Man_55_Sectors_10'] = len(soso_card_M_55_sectors_10.index)
result['soso_Man_55_Sectors_20'] = len(soso_card_M_55_sectors_20.index)
result['soso_Man_55_Sectors_21'] = len(soso_card_M_55_sectors_21.index)
result['soso_Man_55_Sectors_22'] = len(soso_card_M_55_sectors_22.index)
result['soso_Man_55_Sectors_30'] = len(soso_card_M_55_sectors_30.index)
result['soso_Man_55_Sectors_31'] = len(soso_card_M_55_sectors_31.index)
result['soso_Man_55_Sectors_32'] = len(soso_card_M_55_sectors_32.index)
result['soso_Man_55_Sectors_33'] = len(soso_card_M_55_sectors_33.index)
result['soso_Man_55_Sectors_34'] = len(soso_card_M_55_sectors_34.index)
result['soso_Man_55_Sectors_35'] = len(soso_card_M_55_sectors_35.index)
result['soso_Man_55_Sectors_40'] = len(soso_card_M_55_sectors_40.index)
result['soso_Man_55_Sectors_42'] = len(soso_card_M_55_sectors_42.index)
result['soso_Man_55_Sectors_43'] = len(soso_card_M_55_sectors_43.index)
result['soso_Man_55_Sectors_44'] = len(soso_card_M_55_sectors_44.index)
result['soso_Man_55_Sectors_50'] = len(soso_card_M_55_sectors_50.index)
result['soso_Man_55_Sectors_52'] = len(soso_card_M_55_sectors_52.index)
result['soso_Man_55_Sectors_60'] = len(soso_card_M_55_sectors_60.index)
result['soso_Man_55_Sectors_62'] = len(soso_card_M_55_sectors_62.index)
result['soso_Man_55_Sectors_70'] = len(soso_card_M_55_sectors_70.index)
result['soso_Man_55_Sectors_71'] = len(soso_card_M_55_sectors_71.index)
result['soso_Man_55_Sectors_80'] = len(soso_card_M_55_sectors_80.index)
result['soso_Man_55_Sectors_81'] = len(soso_card_M_55_sectors_81.index)
result['soso_Man_55_Sectors_92'] = len(soso_card_M_55_sectors_92.index)

soso_card_M_60_sectors_10 = soso_card_M_60[soso_card_M_60.MCT_CAT_CD == 10]
soso_card_M_60_sectors_20 = soso_card_M_60[soso_card_M_60.MCT_CAT_CD == 20]
soso_card_M_60_sectors_21 = soso_card_M_60[soso_card_M_60.MCT_CAT_CD == 21]
soso_card_M_60_sectors_22 = soso_card_M_60[soso_card_M_60.MCT_CAT_CD == 22]
soso_card_M_60_sectors_30 = soso_card_M_60[soso_card_M_60.MCT_CAT_CD == 30]
soso_card_M_60_sectors_31 = soso_card_M_60[soso_card_M_60.MCT_CAT_CD == 31]
soso_card_M_60_sectors_32 = soso_card_M_60[soso_card_M_60.MCT_CAT_CD == 32]
soso_card_M_60_sectors_33 = soso_card_M_60[soso_card_M_60.MCT_CAT_CD == 33]
soso_card_M_60_sectors_34 = soso_card_M_60[soso_card_M_60.MCT_CAT_CD == 34]
soso_card_M_60_sectors_35 = soso_card_M_60[soso_card_M_60.MCT_CAT_CD == 35]
soso_card_M_60_sectors_40 = soso_card_M_60[soso_card_M_60.MCT_CAT_CD == 40]
soso_card_M_60_sectors_42 = soso_card_M_60[soso_card_M_60.MCT_CAT_CD == 42]
soso_card_M_60_sectors_43 = soso_card_M_60[soso_card_M_60.MCT_CAT_CD == 43]
soso_card_M_60_sectors_44 = soso_card_M_60[soso_card_M_60.MCT_CAT_CD == 44]
soso_card_M_60_sectors_50 = soso_card_M_60[soso_card_M_60.MCT_CAT_CD == 50]
soso_card_M_60_sectors_52 = soso_card_M_60[soso_card_M_60.MCT_CAT_CD == 52]
soso_card_M_60_sectors_60 = soso_card_M_60[soso_card_M_60.MCT_CAT_CD == 60]
soso_card_M_60_sectors_62 = soso_card_M_60[soso_card_M_60.MCT_CAT_CD == 62]
soso_card_M_60_sectors_70 = soso_card_M_60[soso_card_M_60.MCT_CAT_CD == 70]
soso_card_M_60_sectors_71 = soso_card_M_60[soso_card_M_60.MCT_CAT_CD == 71]
soso_card_M_60_sectors_80 = soso_card_M_60[soso_card_M_60.MCT_CAT_CD == 80]
soso_card_M_60_sectors_81 = soso_card_M_60[soso_card_M_60.MCT_CAT_CD == 81]
soso_card_M_60_sectors_92 = soso_card_M_60[soso_card_M_60.MCT_CAT_CD == 92]

result['soso_Man_60_Sectors_10'] = len(soso_card_M_60_sectors_10.index)
result['soso_Man_60_Sectors_20'] = len(soso_card_M_60_sectors_20.index)
result['soso_Man_60_Sectors_21'] = len(soso_card_M_60_sectors_21.index)
result['soso_Man_60_Sectors_22'] = len(soso_card_M_60_sectors_22.index)
result['soso_Man_60_Sectors_30'] = len(soso_card_M_60_sectors_30.index)
result['soso_Man_60_Sectors_31'] = len(soso_card_M_60_sectors_31.index)
result['soso_Man_60_Sectors_32'] = len(soso_card_M_60_sectors_32.index)
result['soso_Man_60_Sectors_33'] = len(soso_card_M_60_sectors_33.index)
result['soso_Man_60_Sectors_34'] = len(soso_card_M_60_sectors_34.index)
result['soso_Man_60_Sectors_35'] = len(soso_card_M_60_sectors_35.index)
result['soso_Man_60_Sectors_40'] = len(soso_card_M_60_sectors_40.index)
result['soso_Man_60_Sectors_42'] = len(soso_card_M_60_sectors_42.index)
result['soso_Man_60_Sectors_43'] = len(soso_card_M_60_sectors_43.index)
result['soso_Man_60_Sectors_44'] = len(soso_card_M_60_sectors_44.index)
result['soso_Man_60_Sectors_50'] = len(soso_card_M_60_sectors_50.index)
result['soso_Man_60_Sectors_52'] = len(soso_card_M_60_sectors_52.index)
result['soso_Man_60_Sectors_60'] = len(soso_card_M_60_sectors_60.index)
result['soso_Man_60_Sectors_62'] = len(soso_card_M_60_sectors_62.index)
result['soso_Man_60_Sectors_70'] = len(soso_card_M_60_sectors_70.index)
result['soso_Man_60_Sectors_71'] = len(soso_card_M_60_sectors_71.index)
result['soso_Man_60_Sectors_80'] = len(soso_card_M_60_sectors_80.index)
result['soso_Man_60_Sectors_81'] = len(soso_card_M_60_sectors_81.index)
result['soso_Man_60_Sectors_92'] = len(soso_card_M_60_sectors_92.index)

soso_card_M_65_sectors_10 = soso_card_M_65[soso_card_M_65.MCT_CAT_CD == 10]
soso_card_M_65_sectors_20 = soso_card_M_65[soso_card_M_65.MCT_CAT_CD == 20]
soso_card_M_65_sectors_21 = soso_card_M_65[soso_card_M_65.MCT_CAT_CD == 21]
soso_card_M_65_sectors_22 = soso_card_M_65[soso_card_M_65.MCT_CAT_CD == 22]
soso_card_M_65_sectors_30 = soso_card_M_65[soso_card_M_65.MCT_CAT_CD == 30]
soso_card_M_65_sectors_31 = soso_card_M_65[soso_card_M_65.MCT_CAT_CD == 31]
soso_card_M_65_sectors_32 = soso_card_M_65[soso_card_M_65.MCT_CAT_CD == 32]
soso_card_M_65_sectors_33 = soso_card_M_65[soso_card_M_65.MCT_CAT_CD == 33]
soso_card_M_65_sectors_34 = soso_card_M_65[soso_card_M_65.MCT_CAT_CD == 34]
soso_card_M_65_sectors_35 = soso_card_M_65[soso_card_M_65.MCT_CAT_CD == 35]
soso_card_M_65_sectors_40 = soso_card_M_65[soso_card_M_65.MCT_CAT_CD == 40]
soso_card_M_65_sectors_42 = soso_card_M_65[soso_card_M_65.MCT_CAT_CD == 42]
soso_card_M_65_sectors_43 = soso_card_M_65[soso_card_M_65.MCT_CAT_CD == 43]
soso_card_M_65_sectors_44 = soso_card_M_65[soso_card_M_65.MCT_CAT_CD == 44]
soso_card_M_65_sectors_50 = soso_card_M_65[soso_card_M_65.MCT_CAT_CD == 50]
soso_card_M_65_sectors_52 = soso_card_M_65[soso_card_M_65.MCT_CAT_CD == 52]
soso_card_M_65_sectors_60 = soso_card_M_65[soso_card_M_65.MCT_CAT_CD == 60]
soso_card_M_65_sectors_62 = soso_card_M_65[soso_card_M_65.MCT_CAT_CD == 62]
soso_card_M_65_sectors_70 = soso_card_M_65[soso_card_M_65.MCT_CAT_CD == 70]
soso_card_M_65_sectors_71 = soso_card_M_65[soso_card_M_65.MCT_CAT_CD == 71]
soso_card_M_65_sectors_80 = soso_card_M_65[soso_card_M_65.MCT_CAT_CD == 80]
soso_card_M_65_sectors_81 = soso_card_M_65[soso_card_M_65.MCT_CAT_CD == 81]
soso_card_M_65_sectors_92 = soso_card_M_65[soso_card_M_65.MCT_CAT_CD == 92]

result['soso_Man_65_Sectors_10'] = len(soso_card_M_65_sectors_10.index)
result['soso_Man_65_Sectors_20'] = len(soso_card_M_65_sectors_20.index)
result['soso_Man_65_Sectors_21'] = len(soso_card_M_65_sectors_21.index)
result['soso_Man_65_Sectors_22'] = len(soso_card_M_65_sectors_22.index)
result['soso_Man_65_Sectors_30'] = len(soso_card_M_65_sectors_30.index)
result['soso_Man_65_Sectors_31'] = len(soso_card_M_65_sectors_31.index)
result['soso_Man_65_Sectors_32'] = len(soso_card_M_65_sectors_32.index)
result['soso_Man_65_Sectors_33'] = len(soso_card_M_65_sectors_33.index)
result['soso_Man_65_Sectors_34'] = len(soso_card_M_65_sectors_34.index)
result['soso_Man_65_Sectors_35'] = len(soso_card_M_65_sectors_35.index)
result['soso_Man_65_Sectors_40'] = len(soso_card_M_65_sectors_40.index)
result['soso_Man_65_Sectors_42'] = len(soso_card_M_65_sectors_42.index)
result['soso_Man_65_Sectors_43'] = len(soso_card_M_65_sectors_43.index)
result['soso_Man_65_Sectors_44'] = len(soso_card_M_65_sectors_44.index)
result['soso_Man_65_Sectors_50'] = len(soso_card_M_65_sectors_50.index)
result['soso_Man_65_Sectors_52'] = len(soso_card_M_65_sectors_52.index)
result['soso_Man_65_Sectors_60'] = len(soso_card_M_65_sectors_60.index)
result['soso_Man_65_Sectors_62'] = len(soso_card_M_65_sectors_62.index)
result['soso_Man_65_Sectors_70'] = len(soso_card_M_65_sectors_70.index)
result['soso_Man_65_Sectors_71'] = len(soso_card_M_65_sectors_71.index)
result['soso_Man_65_Sectors_80'] = len(soso_card_M_65_sectors_80.index)
result['soso_Man_65_Sectors_81'] = len(soso_card_M_65_sectors_81.index)
result['soso_Man_65_Sectors_92'] = len(soso_card_M_65_sectors_92.index)

# %%
result
# Out:
# {'total': 1998575,
#  'bad_dust': 948118,
#  'soso_dust': 1050457,
#  'bad_Female': 478331,
#  'bad_Man': 469787,
#  'soso_Female': 531031,
#  'soso_Man': 519426,
#  'bad_Female_20': 47954,
#  'bad_Female_25': 48818,
#  'bad_Female_30': 47287,
#  'bad_Female_35': 48527,
#  'bad_Female_40': 50385,
#  'bad_Female_45': 54718,
#  'bad_Female_50': 52372,
#  'bad_Female_55': 47908,
#  'bad_Female_60': 40984,
#  'bad_Female_65': 39378,
#  'bad_Man_20': 45052,
#  'bad_Man_25': 51300,
#  'bad_Man_30': 49051,
#  'bad_Man_35': 49739,
#  'bad_Man_40': 48500,
#  'bad_Man_45': 51193,
#  'bad_Man_50': 49744,
#  'bad_Man_55': 45450,
#  'bad_Man_60': 39503,
#  'bad_Man_65': 40255,
#  'soso_Female_20': 53930,
#  'soso_Female_25': 54307,
#  'soso_Female_30': 52740,
#  'soso_Female_35': 54154,
#  'soso_Female_40': 55950,
#  'soso_Female_45': 60838,
#  'soso_Female_50': 57882,
#  'soso_Female_55': 52947,
#  'soso_Female_60': 45176,
#  'soso_Female_65': 43107,
#  'soso_Man_20': 50761,
# ...

# %%
df = pd.DataFrame.from_dict(result, orient='index')

# %%
df.to_csv('card_result.csv')
